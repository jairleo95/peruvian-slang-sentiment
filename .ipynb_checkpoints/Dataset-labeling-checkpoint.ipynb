# %%
# dataset labeling

# %%
import torch
import pandas as pd

# %%
pd.set_option("max_colwidth", 300)

# %%
pwd
# Out:
# 'D:\\Workspace\\ai\\nlp\\peruvian-slang-sentiment'

# %%
df = pd.read_excel(r'Sample_Final12012024.xlsx')

# %%
df = df.loc[df['ANNOTATOR'] == 'JAIR']

# %%
df = df.astype({'label':'string'})

# %%
df = df.loc[df['label'].isna()]

# %%
df['label']
# Out:
# 235      <NA>
# 236      <NA>
# 237      <NA>
# 240      <NA>
# 241      <NA>
#          ...
# 76878    <NA>
# 76888    <NA>
# 76889    <NA>
# 76895    <NA>
# 76898    <NA>
# Name: label, Length: 12549, dtype: string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12549 entries, 235 to 76898
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12549 non-null  int64
#  1   object_id                12549 non-null  int64
#  2   ID2                      12549 non-null  object
#  3   message                  12549 non-null  object
#  4   slangs                   12549 non-null  object
#  5   label                    0 non-null      string
#  6   slangs_char_count        12549 non-null  int64
#  7   conjunto                 12549 non-null  object
#  8   Polaridad_TENTATIVA      12549 non-null  object
#  9   TIENE_EMOJI_RECONOCIDO?  12549 non-null  object
#  10  En Muestra_FINAL_Manual  12549 non-null  int64
#  11  ANNOTATOR                12549 non-null  object
#  12  label.1                  0 non-null      float64
# dtypes: float64(1), int64(4), object(7), string(1)
# memory usage: 1.3+ MB

# %%
positive_emojis = ['😀', '😊', '🔥🔥🔥', '💯', '💪💪💪', '❤️', '💖💖','💖💖💖','💕💕','👏👏👏', '🌹🌹🌹', '👍👍👍', '✅', '😘😘😘','😘😘', '🤗🤗🤗', '😎😎', '😊😊😊', '😊😊']

# %%
negative_emojis = ['😡','👎','🤬', '😠', '🤮🤮', '💩💩💩','🐀🐀','😤😤']

# %%
def contains_positive_emoji(text):
    return '1' if any(emoji in text for emoji in positive_emojis) else ''

# %%
def contains_negative_emoji(text):
    return '3'if any(emoji in text for emoji in negative_emojis) else ''

# %%
df['positive'] = df['message'].apply(contains_positive_emoji)
#df = df[df['positive'] == True]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12549 entries, 235 to 76898
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12549 non-null  int64
#  1   object_id                12549 non-null  int64
#  2   ID2                      12549 non-null  object
#  3   message                  12549 non-null  object
#  4   slangs                   12549 non-null  object
#  5   label                    0 non-null      string
#  6   slangs_char_count        12549 non-null  int64
#  7   conjunto                 12549 non-null  object
#  8   Polaridad_TENTATIVA      12549 non-null  object
#  9   TIENE_EMOJI_RECONOCIDO?  12549 non-null  object
#  10  En Muestra_FINAL_Manual  12549 non-null  int64
#  11  ANNOTATOR                12549 non-null  object
#  12  label.1                  0 non-null      float64
#  13  positive                 12549 non-null  object
# dtypes: float64(1), int64(4), object(8), string(1)
# memory usage: 1.4+ MB

# %%
df['negative'] = df['message'].apply(contains_negative_emoji)
#df = df[df['negative'] == True]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12549 entries, 235 to 76898
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       12549 non-null  int64
#  1   object_id                12549 non-null  int64
#  2   ID2                      12549 non-null  object
#  3   message                  12549 non-null  object
#  4   slangs                   12549 non-null  object
#  5   label                    0 non-null      string
#  6   slangs_char_count        12549 non-null  int64
#  7   conjunto                 12549 non-null  object
#  8   Polaridad_TENTATIVA      12549 non-null  object
#  9   TIENE_EMOJI_RECONOCIDO?  12549 non-null  object
#  10  En Muestra_FINAL_Manual  12549 non-null  int64
#  11  ANNOTATOR                12549 non-null  object
#  12  label.1                  0 non-null      float64
#  13  positive                 12549 non-null  object
#  14  negative                 12549 non-null  object
# dtypes: float64(1), int64(4), object(9), string(1)
# memory usage: 1.5+ MB

# %%
df.sample(20)
# Out:
#            id         object_id                      ID2  \
# 13644    2692   962338271286601     2692-962338271286601
# 14422  178958   792382971690349   178958-792382971690349
# 9516   141533   458486128723135   141533-458486128723135
# 7544     1415   227842436527659     1415-227842436527659
# 26287  192751   453461103460178   192751-453461103460178
# 11220  146026  1424842094297110  146026-1424842094297110
# 4379    16364  1376270805802580   16364-1376270805802580
# 11263   16400   854474562342159    16400-854474562342159
# 4444    38304   823778785075123    38304-823778785075123
# 45771    4048  2011033479151730    4048-2011033479151730
# 57108    2526   879578982221438     2526-879578982221438
# 23813   10397  1109518383010010   10397-1109518383010010
# 28626   22649  1504768569604220   22649-1504768569604220
# 23740   13414  1675024389214320   13414-1675024389214320
# 72933   10086   690887478711245    10086-690887478711245
# 17617    3932   873038923388419     3932-873038923388419
# 38162    7308   885511271624934     7308-885511271624934
# 47854   24406   999028434793187    24406-999028434793187
# 50189  112522   801879203976487   112522-801879203976487
# 22986   15485   668688510547070    15485-668688510547070
#
#                                                                                                                                                                                                                                                                                                            message  \
# 13644                                                                                                                                                                                                              Rata, a la gente les llega ala punta de la pinga tus invitadas, has especial de 24 horas mrd 😃😃
# 14422                   Que coincidencia que vuelvas a hacer Periodismo Politico justo en las elecciones, seguro después de abril vuelves a la farándula haciendo payasadas con el Chino Aldo o en el valor de la verdad. Increíble que exista gente que cree que haces Periodismo serio, encima estas en WillAJ 😃
# 9516   Por eso JAMAS ENGAÑES AL PUEBLO....👨‍🎤🇵🇪🇵🇪🇵🇪 ❗AHORA PUES❗ ✏Arequipa 93% ✏Puno_Juliaca 90%✏Lima 60% ✏Ancash 97%✏ Apurímac 94%✏ Ayacucho 93% ✏Cajamarca 89%✏ Callao 65%✏Cusco 94% ✏Callo 57%✏ Huancavelica 91%✏Huánuco 92% ✏ Ica 87%✏Junín 75% ✏Trujillo 75%✏Lambayeque 76% ✏Lima 57%✏Loreto 70% ✏Madre de...
# 7544                                                                                                                                                                                                           Mi mami 🤭🤭si havia premio ella se apunta a al toque, y yo 🤦‍♀️🤦‍♀️🤣🤣lo bueno es q ganaba como sea🤣🤣
# 26287                                                                                                                                                                                                                                                                                   Periodista guácala!!! 🤮🤮🤮🤮
# 11220                                                                                                                                                                                                        eres recontra travieso manolito !!!!! como habras sido de chibolo!!!!! jajajz genio y figura men👍👍👍😜😜
# 47854              cacha,  <NA>                  6   Chunk0
# 50189              chico,  <NA>                  6   Chunk0
# 22986           huarique,  <NA>                  9   Chunk0
#
#       Polaridad_TENTATIVA TIENE_EMOJI_RECONOCIDO?  En Muestra_FINAL_Manual  \
# 13644            POSITIVO                      SI                        1
# 14422            POSITIVO                      SI                        1
# 9516             POSITIVO                      SI                        1
# 7544             NEGATIVO                      SI                        1
# 26287            NEGATIVO                      SI                        1
# 11220            POSITIVO                      SI                        1
# 4379             POSITIVO                      SI                        1
# 11263            POSITIVO                      SI                        1
# 4444             POSITIVO                      SI                        1
# 45771             NEUTRAL                      SI                        1
# 57108             NEUTRAL                      SI                        1
# 23813            NEGATIVO                      SI                        1
# 28626             NEUTRAL                      SI                        1
# 23740             NEUTRAL                      SI                        1
# 72933            POSITIVO                      SI                        1
# 17617            POSITIVO                      SI                        1
# 38162            POSITIVO                      SI                        1
# 47854            POSITIVO                      SI                        1
# 50189             NEUTRAL                      SI                        1
# 22986            NEGATIVO                      SI                        1
#
#       ANNOTATOR  label.1 positive negative
# 13644      JAIR      NaN
# 14422      JAIR      NaN
# 9516       JAIR      NaN
# 7544       JAIR      NaN
# 26287      JAIR      NaN                 3
# 11220      JAIR      NaN        1
# 4379       JAIR      NaN
# 11263      JAIR      NaN        1
# 4444       JAIR      NaN
# 45771      JAIR      NaN
# 57108      JAIR      NaN
# 23813      JAIR      NaN
# 28626      JAIR      NaN
# 23740      JAIR      NaN
# 72933      JAIR      NaN
# 17617      JAIR      NaN
# 38162      JAIR      NaN
# 47854      JAIR      NaN
# 50189      JAIR      NaN
# 22986      JAIR      NaN

# %%
df['message'].sample(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28148\152207735.py in <module>
# ----> 1 df_negative['message'].sample(20)
#
# NameError: name 'df_negative' is not defined

# %%
df_filter = df.loc[df['message'].str.contains( '🤣')]

# %%
df_filter.info()

# %%
df_filter['message'].sample(30)

# %%
df_filter.info()

# %%
import pandas as pd
import regex as re

def extract_emojis(dataframe, column_name):
    emojis_dict = {}
    
    # Function to extract emojis from text
    def extract_emojis_from_text(text):
        return re.findall(r'\p{So}', text)
    
    # Apply the function to each row in the specified column
    emojis_lists = dataframe[column_name].apply(extract_emojis_from_text)
    
    # Iterate through each list of emojis and count their occurrences
    for emojis_list in emojis_lists:
        for emoji in emojis_list:
            if emoji in emojis_dict:
                emojis_dict[emoji] += 1
            else:
                emojis_dict[emoji] = 1
    
    # Create a DataFrame from the dictionary of emojis and their frequencies
    emojis_df = pd.DataFrame(list(emojis_dict.items()), columns=['Emoji', 'Frequency'])
    
    # Sort the DataFrame by frequency in descending order
    emojis_df = emojis_df.sort_values(by='Frequency', ascending=False).reset_index(drop=True)
    
    return emojis_df

# Example usage:
# data = {'text': ['Hello 😊', 'How are you? 👍', 'I love it 🥰👋', 'No emojis here', 'Another combination 👋😃']}
# df = pd.DataFrame(data)

emojis_df = extract_emojis(df, 'message')
print(emojis_df)

# %%
emojis_df.head(20)
