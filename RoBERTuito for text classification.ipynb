# %% [markdown]
# ## RoBERTuito for Text Classification
#
# This notebook shows how to use [RoBERTuito](https://huggingface.co/pysentimiento/robertuito-base-uncased) for text classification tasks.
#
# First, let's install some packages

# %%
# !pip install pysentimiento transformers datasets accelerate evaluate
# Out:
# Collecting pysentimiento
#   Downloading pysentimiento-0.7.1-py3-none-any.whl (38 kB)
# Requirement already satisfied: transformers in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (4.30.2)
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 39.5 MB/s eta 0:00:00
# Collecting accelerate
#   Using cached accelerate-0.20.3-py3-none-any.whl (227 kB)
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 44.7 MB/s eta 0:00:00
# Collecting torch>=2.0.0
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Collecting emoji<2.0.0,>=1.6.1
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 58.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting spacy<4.0.0,>=3.5.0
#   Downloading spacy-3.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 24.5 MB/s eta 0:00:0031m23.0 MB/s eta 0:00:01
# Requirement already satisfied: requests in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (2.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from transformers) (23.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 66.0 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 80.2 MB/s eta 0:00:00
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 54.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from datasets) (1.5.3)
# Collecting pyarrow>=8.0.0
#   Downloading pyarrow-12.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 12.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: psutil in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 kB 93.3 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.0 MB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 kB 61.7 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Requirement already satisfied: setuptools in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (67.8.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (913 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.3/913.3 kB 96.7 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 52.2 MB/s eta 0:00:00
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 18.9 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (3.1.2)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.2-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 19.8 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 22.2 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.7.91)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (10.2.10.91)
# Requirement already satisfied: triton==2.0.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (2.0.0)
# Requirement already satisfied: networkx in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (2.8.4)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.7.99)
# Requirement already satisfied: sympy in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (1.11.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.10.3.66)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.4.0.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.7.101)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (2.14.3)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from torch>=2.0.0->pysentimiento) (11.7.99)
# Requirement already satisfied: wheel in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=2.0.0->pysentimiento) (0.38.4)
# Requirement already satisfied: lit in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from triton==2.0.0->torch>=2.0.0->pysentimiento) (16.0.6)
# Requirement already satisfied: cmake in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from triton==2.0.0->torch>=2.0.0->pysentimiento) (3.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 20.2 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0.0,>=3.5.0->pysentimiento) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from jinja2->spacy<4.0.0,>=3.5.0->pysentimiento) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=2.0.0->pysentimiento) (1.2.1)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171032 sha256=9d50cef2dceabadff6cf19ebad25c28d6c8d93b4d9715a62cbd6593dc79ce132
#   Stored in directory: /home/darkstar/.cache/pip/wheels/37/b1/70/d87e2dddea71a019314970e3ea065b63e27b9be29e4a579b13
# Successfully built emoji
# Installing collected packages: emoji, cymem, xxhash, wasabi, typer, spacy-loggers, spacy-legacy, smart-open, pydantic, pyarrow, murmurhash, langcodes, dill, catalogue, blis, srsly, responses, preshed, pathy, multiprocess, confection, thinc, datasets, spacy, evaluate, torch, pysentimiento, accelerate
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 2.0.1 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 2.0.1 which is incompatible.
# Successfully installed accelerate-0.20.3 blis-0.7.9 catalogue-2.0.8 confection-0.1.0 cymem-2.0.7 datasets-2.13.1 dill-0.3.6 emoji-1.7.0 evaluate-0.4.0 langcodes-3.3.0 multiprocess-0.70.14 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pyarrow-12.0.1 pydantic-1.10.11 pysentimiento-0.7.1 responses-0.18.0 smart-open-6.3.0 spacy-3.6.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 thinc-8.1.10 torch-2.0.1 typer-0.9.0 wasabi-1.1.2 xxhash-3.2.0

# %% [markdown]
# Let's load a dataset -- in this case, a Spanish sentiment analysis dataset from CardiffNLP.

# %%
from datasets import load_dataset

ds = load_dataset("cardiffnlp/tweet_sentiment_multilingual", "spanish")

ds
# Out:
# Downloading builder script:   0%|          | 0.00/4.14k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/5.28k [00:00<?, ?B/s]
# Downloading and preparing dataset tweet_sentiment_multilingual/spanish to /home/darkstar/.cache/huggingface/datasets/cardiffnlp___tweet_sentiment_multilingual/spanish/0.1.0/936afd3cde120393429606f681b3b48d526873c45114068973f71e296ce80605...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/103k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/216k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/38.4k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset tweet_sentiment_multilingual downloaded and prepared to /home/darkstar/.cache/huggingface/datasets/cardiffnlp___tweet_sentiment_multilingual/spanish/0.1.0/936afd3cde120393429606f681b3b48d526873c45114068973f71e296ce80605. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1839
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 324
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 870
#     })
# })

# %%
ds["train"].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'neutral', 'positive'], id=None)}

# %%
ds["test"]["text"][:10]
# Out:
# ['@user jajajaja dale, hacete la boluda vos jajaja igual a vos nunca se te puede tomar en serio te mando un abrazo desde Perú!',
#  'cada vez que cito un tweet se va la ubicación sin tampoco poder ponerla en el momento a uds les pasa? TE VEO Y ME PICA VICICONTE',
#  '@user MAAAAE RAJADO! Pero lo bueno es q uno se va independizando!y logrando metas',
#  'Bueno hoy fui a almorzar a Nanay con otras 3 dras xq la capacitación mal organizada no nos dió almuerzo y encima nos mandan a comer 2pm',
#  'Necesito seguir a mas cuentas camren shippers y fans de las armonías. Me recomendais alguna?',
#  '@user ¡Hola Tomás! ¿Habéis visto los nuevos #dinos de #TierraMagna? Es normal que haya colas antes de que comience el espectáculo',
#  '@user la hijueputa tela se me salió. yo quería volver a quedar acostada.',
#  'Parce yo estoy igual @user',
#  '@user pues no está nada mal',
#  '@user quizá para profesionales no sea mucho,pero hay no remunerados principalmente femenino para quienes es un sueño, pasa en mi país']

# %%
ds["test"]["label"][:10]
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2, 0]

# %% [markdown]
# ## Load models
#
# For this task, we use `robertuito-base-uncased` (there are other two versions: `robertuito-base-uncased`, and `robertuito-base-deacc`)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_name = "pysentimiento/robertuito-base-uncased"

model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=3
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.model_max_length = 128
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# 2023-07-10 17:00:31.032223: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Downloading model.safetensors:   0%|          | 0.00/435M [00:00<?, ?B/s]
# Some weights of the model checkpoint at pysentimiento/robertuito-base-uncased were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at pysentimiento/robertuito-base-uncased and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/323 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/858k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %% [markdown]
# ## Preprocessing
#
# Before tokenizing our model, we have to run the `preprocess_tweet` function to our data.

# %%
from pysentimiento.preprocessing import preprocess_tweet
preprocessed_ds = ds.map(lambda ex: {"text": preprocess_tweet(ex["text"], lang="es")})
# Out:
# Map:   0%|          | 0/1839 [00:00<?, ? examples/s]
# Map:   0%|          | 0/324 [00:00<?, ? examples/s]
# Map:   0%|          | 0/870 [00:00<?, ? examples/s]

# %% [markdown]
# ## Tokenization

# %%
tokenized_ds = preprocessed_ds.map(
    lambda batch: tokenizer(batch["text"], padding=False, truncation=True),
    batched=True, batch_size=32
)
# Out:
# Map:   0%|          | 0/1839 [00:00<?, ? examples/s]
# Map:   0%|          | 0/324 [00:00<?, ? examples/s]
# Map:   0%|          | 0/870 [00:00<?, ? examples/s]

# %%
tokenized_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 1839
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 324
#     })
#     test: Dataset({
#         features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 870
#     })
# })

# %% [markdown]
# ## Training

# %%
# !pip install ipdb
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting ipdb
#   Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Requirement already satisfied: decorator in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipdb) (5.1.1)
# Requirement already satisfied: ipython>=7.31.1 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipdb) (8.12.0)
# Requirement already satisfied: tomli in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipdb) (2.0.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (2.15.1)
# Requirement already satisfied: pexpect>4.3 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (3.0.36)
# Requirement already satisfied: traitlets>=5 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (5.7.1)
# Requirement already satisfied: pickleshare in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.7.5)
# Requirement already satisfied: stack-data in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.2.0)
# Requirement already satisfied: backcall in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.31.1->ipdb) (0.2.5)
# Requirement already satisfied: executing in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from stack-data->ipython>=7.31.1->ipdb) (0.8.3)
# Requirement already satisfied: asttokens in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from stack-data->ipython>=7.31.1->ipdb) (2.0.5)
# Requirement already satisfied: pure-eval in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from stack-data->ipython>=7.31.1->ipdb) (0.2.2)
# Requirement already satisfied: six in /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages (from asttokens->stack-data->ipython>=7.31.1->ipdb) (1.16.0)
# Installing collected packages: ipdb
# Successfully installed ipdb-0.13.13

# %%
import numpy as np
import evaluate

f1_metric = evaluate.load("f1")
recall_metric = evaluate.load("recall")

def compute_metrics (eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis = -1)

    results = {}
    results.update(f1_metric.compute(predictions=preds, references = labels, average="macro"))
    results.update(recall_metric.compute(predictions=preds, references = labels, average="macro"))
    return results
# Out:
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.36k [00:00<?, ?B/s]

# %%
from transformers import TrainingArguments, Trainer, DataCollatorWithPadding

training_args = TrainingArguments(
    per_device_train_batch_size=32,
    output_dir="test_trainer",
    do_eval=True,
    evaluation_strategy="epoch",
    num_train_epochs=5,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds["train"],
    eval_dataset=tokenized_ds["validation"],
    compute_metrics=compute_metrics,
    data_collator=DataCollatorWithPadding(tokenizer=tokenizer),
)
trainer.train()
# Out:
# /home/darkstar/anaconda3/envs/nlp-pytorch-gpu/lib/python3.10/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# {'eval_loss': 0.671050488948822, 'eval_f1': 0.6597503202507132, 'eval_recall': 0.6790123456790123, 'eval_runtime': 0.4678, 'eval_samples_per_second': 692.612, 'eval_steps_per_second': 87.645, 'epoch': 1.0}
# {'eval_loss': 0.6977064609527588, 'eval_f1': 0.7134784152105151, 'eval_recall': 0.7129629629629631, 'eval_runtime': 0.4844, 'eval_samples_per_second': 668.871, 'eval_steps_per_second': 84.641, 'epoch': 2.0}
# {'eval_loss': 0.7892211675643921, 'eval_f1': 0.7138250101586121, 'eval_recall': 0.7160493827160493, 'eval_runtime': 0.4714, 'eval_samples_per_second': 687.288, 'eval_steps_per_second': 86.972, 'epoch': 3.0}
# {'eval_loss': 0.8946099281311035, 'eval_f1': 0.7191358024691358, 'eval_recall': 0.7191358024691358, 'eval_runtime': 0.497, 'eval_samples_per_second': 651.944, 'eval_steps_per_second': 82.499, 'epoch': 4.0}
# {'eval_loss': 0.9800084233283997, 'eval_f1': 0.7125949478890655, 'eval_recall': 0.7160493827160495, 'eval_runtime': 0.4876, 'eval_samples_per_second': 664.442, 'eval_steps_per_second': 84.081, 'epoch': 5.0}
# {'train_runtime': 46.6246, 'train_samples_per_second': 197.214, 'train_steps_per_second': 6.22, 'train_loss': 0.34459494229020743, 'epoch': 5.0}
# TrainOutput(global_step=290, training_loss=0.34459494229020743, metrics={'train_runtime': 46.6246, 'train_samples_per_second': 197.214, 'train_steps_per_second': 6.22, 'train_loss': 0.34459494229020743, 'epoch': 5.0})

# %%
trainer.evaluate(tokenized_ds["test"])
# Out:
# {'eval_loss': 0.9861928820610046, 'eval_f1': 0.7190584342944698, 'eval_recall': 0.7218390804597701, 'eval_runtime': 1.2913, 'eval_samples_per_second': 673.723, 'eval_steps_per_second': 84.409, 'epoch': 5.0}
# {'eval_loss': 0.9861928820610046,
#  'eval_f1': 0.7190584342944698,
#  'eval_recall': 0.7218390804597701,
#  'eval_runtime': 1.2913,
#  'eval_samples_per_second': 673.723,
#  'eval_steps_per_second': 84.409,
#  'epoch': 5.0}
