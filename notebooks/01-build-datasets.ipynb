# %%
import torch
import pandas as pd

# %%
pd.set_option("max_colwidth", 300)

# %% [markdown]
# ## Read Annotated Dataset

# %%
#df = pd.read_csv(r'../text-extraction/[labeled]dataset-01.csv', encoding='latin-1')
# df = pd.read_csv(r'../text-extraction/[labeling]dataset-02_500.csv', dtype={
#     'slang': 'string',
#     'text': 'string',
#     'label': 'string'}, encoding='utf-8')
# df = pd.read_excel(r'../Sample_Final12012024_sergiovr01.xlsx', dtype={
#     'slangs': 'string',
#     'text': 'string',
#     'label': 'string'
# })
# df = pd.read_excel(r'../Sample_Final12012024_v2.xlsx', dtype={
#     'slangs': 'string',
#     'text': 'string',
#     'label': 'string'
# })
# df_no_neutrals = pd.read_excel(r'../annotation/Sample_Final12012024_sergiovr01[excluding-neutrals].xlsx', dtype={
#     'slangs': 'string',
#     'text': 'string',
#     'label': 'string'
# })
dfa = pd.read_excel(r'../annotation/6-dataset_2900_comentarios_vr4.xlsx', dtype={
    'slangs': 'string',
    'text': 'string',
    'label': 'string'
})
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3089 entries, 0 to 3088
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nro                      3089 non-null   int64
#  1   id                       3089 non-null   int64
#  2   object_id                3089 non-null   int64
#  3   ID2                      3089 non-null   object
#  4   text                     3089 non-null   string
#  5   slangs                   3089 non-null   string
#  6   label                    3089 non-null   string
#  7   slangs_char_count        3089 non-null   int64
#  8   conjunto                 3089 non-null   object
#  9   En Muestra_FINAL_Manual  3089 non-null   int64
#  10  ANNOTATOR                3080 non-null   float64
# dtypes: float64(1), int64(5), object(2), string(3)
# memory usage: 265.6+ KB

# %%
dfa[['id','text', 'slangs', 'label']].sample(20)
# Out:
#          id  \
# 705   16080
# 1274  72128
# 274     698
# 2583  64500
# 1607  39136
# 802    6375
# 493   30697
# 1908   4111
# 1850  71133
# 43    97235
# 568   21727
# 1358  11443
# 736   15621
# 1057    618
# 293    3956
# 2839   5753
# 2377  43640
# 1621  13920
# 3084    286
# 482   27418
#
#                                                                                                                                                                         text  \
# 705                                                                          Juanita Tacza tú dos cesareassss miss respetooooos amiga!!! La mrrrrr😭 yo con una ahí nomas...
# 1274                                                                                                  Cesar H'c una moto torito pa q no te hagan torito🔥 solo falta el chuzo
# 274   A mi me robaron en San Isidro y cuando pedí cámaras me dijeron que no funcionaban, que las tenia la Municipalidad de Lima. Pero en el vídeo si funcionan las cámaras 🤣
# 2583                                                                                                          No pensé que "el tobi" era el rinoceronte verde de Liveman 🤣🤣🤣
# 1607                                                                                                             Me hiciste el día, al otaku lo destruiste en segundos... 🤣🤣
# 802                                                                                         Qué palta!!! No estamos en México, no se pasen con éstas fusiones pues Luciano 😒
# 493                                                                        Toma tu repuestas ratatuin esas palabras pueden ser realidad infeliz 🤣🤣🤣bien respondido el tito👏👏
# 1908                                           Si recuerdo haber jugado con fríjoles de colores, les llamábamos chunguitas, y también con pallares de colores en Cajabamba 😄
# 1850                                                                                                                                              Ay porfavor Beto somos 3 😂
# 43                                    Csm una vez estuve estuve intimamente con un travesti y ni cuenta me di hasta que me lo dijo, deberian tener ya su DNI personalizado 😢
# 568              Feliz cumpleaños Beto🥳🥳, gracias por tu lucha por nuestro pais🤗🇵🇪 lindo el regalito de la osita hecha con una tela del vestido de tu mami 💗 felicidades!!!!
# 1358                                                                                                                    Jajajajajajaja tmr como lo lanzan mas frio Cobos 😂😂😂
# 736                                                                                                                                Esta haciendo efecto la pichicateadaa😁😁😁😁
# 1057                                                                                                             Lisbeth Castillo Vargas conosco a unos  tóxicos  😂😂  asi !?
# 293                                                                                                                                    Diana CarolinaCielo Alvarez siempre😂🙃
# 2839                                                                               Señora es su problema de ellos  o esta envidiosa por el departamento que se ve de lujo. 😏
# 2377                                                                                                                  Gloria Esal Enrique Marley tamalitoooo chinchanooooo 😭
# 1621                                                                Genial! Me encanto! Que belleza de pato asado! En el minuto 4:10 literalmente se me hizo agua la boca! 😋
# 3084                                                                                                                                                    Estara con la resaca
# 482                                                                                                Con la misma vara que midas serás medido hasta con la más grande  todavía
#
#        slangs label
# 705    nomas,     1
# 1274   chuzo,     2
# 274     muni,     3
# 2583   verde,     3
# 1607   otaku,     1
# 802    palta,     3
# 493     rata,     3
# 1908   palla,     2
# 1850   porfa,     2
# 43      inti,     3
# 568     tela,     1
# 1358   lanza,     3
# 736    pichi,     3
# 1057   conos,     3
# 293     caro,     0
# 2839    depa,     2
# 2377   tamal,     1
# 1621   asado,     1
# 3084  resaca,     2
# 482     vara,     2

# %%
len(dfa)
# Out:
# 3089

# %%
# df = df[df.ANNOTATOR.isin(["0"])]
dfa = dfa[dfa.label.isin(["1","2","3"])]
#new_df = new_df.loc[:, ['id_slang','slang', 'sentence', 'label']]
dfa = dfa.loc[:, ['text', 'label']]
dfa = dfa.reset_index(drop=True)
dfa = dfa.astype({'label':'int'})
dfa
# Out:
#                                                                                                                                                                              text  \
# 0                                                                                                                                                        BRAVO bravo 👍  dale duro
# 1                                                                                                                    Hoy es un día muy duro de trabajo pero gratificante. 🥰🤗🫶👍👏🇵🇪
# 2                                                                                                                        Así hubieran publicado sus músicas cuando estaba vivo  😒
# 3                                                                                                                                ,Mabel Milla 🤣🤣 Tanto Tu en los Tonos 🤣 JAJAJA 😎
# 4     Pueden ver los monumentos, galerias de Arte, casas históricas y los huequitos de música... esos lugarcitos bizarros donde el tono termina a las 8 de la mañana. Averiguen😘🤣
# ...                                                                                                                                                                           ...
# 2765                                                                                                                                   Estas salado igual que yo en tus sorteos🤣😅
# 2766                                                                                                                                               De seguro ya le paso la resaca
# 2767                                                                                                                                                         Estara con la resaca
# 2768                                                                                                                                     Buena frase , sin salado no hay dulce 🤟🏻
# 2769                                                                                                                   Estar en la cima de la cordillera blanca es espectacular 😁
#
#       label
# 0         1
# 1         1
# 2         3
# 3         1
# 4         2
# ...     ...
# 2765      3
# 2766      2
# 2767      2
# 2768      1
# 2769      1
#
# [2770 rows x 2 columns]

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2770 entries, 0 to 2769
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2770 non-null   string
#  1   label   2770 non-null   int64
# dtypes: int64(1), string(1)
# memory usage: 43.4 KB

# %%
# label encode
def label_encode(x):
    if x == 1:#positive
        return 2
    if x == 2:#neutral
        return 1
    if x == 3:#negative
        return 0
# label to name
def label2name(x):
    if x == 0:
        return "negative"
    if x == 1:
        return "neutral"
    if x == 2:
        return "positive"

# %%
dfa["label"] = dfa["label"].apply(lambda x: label_encode(x))

# %%
dfa.sample(n = 15)
# Out:
#                                                                                                                                                                                                                                                                                                              text  \
# 1777                                                                                                                                                                                                                                                           Chelsy Otero Chafalote jajajaajajajajjaajajaj 😂😂😂😂
# 2239                                                                                                                                                                                                                                                        Aldair Borda Salas chola... Todo pasa en la disco 😂😂😂
# 1864                                                                                                                                                                                                                                                   Luciana Su Grimaldo ya pe vamos, prometo no desmayarme 🤣🤣🤣
# 2224                                                                                                                                                                                                                                                                MeGan HB 😅😅 ven al cumpleaños de mi Chipiripi
# 977                                                                                                                                                                                                                                                                                          Bien feo es cachoo😁😁
# 1172                                                                                                                                                                                  Belen Mp Yarixza Ochoa Trujillo Stefanny Yparraguirre Wendy Cardenas Reyes Magaly Pilar Machaca Ari Alison Angela Auccasi 🤣
# 498                                                                                                                                                                                                                                                                      Gerardo comes y comes y estás tela 😂😂😂😂😂
# 114                                                                                                                                                                                                                                                           Eso pasa por bailar danzas que no conoces pataaa 🤣🤣
# 137                                                                                                                                                                                     Es una 💩 después que va hacer un balón con wifi que con una patada se neta automáticamente, el mejor balón es el jabulani
# 1936                                                                                                                                                                                                                    Alguien mas se dio cuenta que dafonseka tiene  2 globos y solo se ve 1 globo lanzado? 🤔😂😂
# 559                                                                                                                                                                                                                            se me tío con Pedro Castillo n la madrugada .. a meterse un polvo . 🐸 de mierda ..
# 293                                                                                                                                                         Santo Dios tu ves la nesecidad de tu hijos 😥😥😥😥ayudemos a los que lo necesitan 😔 Y dejen de ver la paja ajena miren el tronco que llevan en sus ojos.
# 1136  la que piensa solo en tomar : obiooo yoo 😝                                             la que solo va a buscar flaco : Vargas Rupay Luciana Camila👫      la mala influencia : Mirian Limascca 😈                                                                                la santa: La xiomara alv :v😇
# 1385                                                                                                                                                                                                                                        Claudia González Cantoral le falta conocer como unos 300 huecos más 😉
# 2571                                                                                                                                                                                                                                          que ricoooo!!! 😍😍😍 que viva el departamento de Lambayequeeee 💃🏽💃🏽💃🏽
#
#       label
# 1777      2
# 2239      0
# 1864      2
# 2224      1
# 977       0
# 1172      2
# 498       0
# 114       1
# 137       0
# 1936      1
# 559       0
# 293       1
# 1136      0
# 1385      0
# 2571      2

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2770 entries, 0 to 2769
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2770 non-null   string
#  1   label   2770 non-null   int64
# dtypes: int64(1), string(1)
# memory usage: 43.4 KB

# %%
dfa.groupby('label').count()
# Out:
#        text
# label
# 0       983
# 1       783
# 2      1004

# %%
dfa.to_csv('../data/raw_dataset-06.csv', index=False)

# %%
len(dfa)
# Out:
# 2770

# %% [markdown]
# ## Load Raw Dataset

# %%
# merging two csv files 
dataset_path = '../data/'
df = pd.concat( 
    map(pd.read_csv, [dataset_path + 'raw_dataset-01.csv',
                      dataset_path + 'raw_dataset-02.csv',
                      dataset_path + 'raw_dataset-03.csv',
                      dataset_path + 'raw_dataset-04.csv',
                      dataset_path + 'raw_dataset-05.csv',
                      dataset_path + 'raw_dataset-06.csv']), ignore_index=True)
# print(df) 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14605 entries, 0 to 14604
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    14605 non-null  object
#  1   label   14605 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 228.3+ KB

# %%
df["label_name"] = df["label"].apply(lambda x: label2name(x))

# %%
df.sample(15)
# Out:
#                                                                                                                                                                                                                                                                                                               text  \
# 6122                                                                                                                                                                                                                                                      K tiernos de la mano👐🏼todo sea Por amor a la chamba Jiji
# 4819                                                                                                                                                                                                                                                    Esta  federica va en busca  si tienen   grande o chipi😀😀😀😀
# 5995                                                                                                                                                                                                                                                                                  Tiene huevos un súper like 👍
# 14561                                                                                                                                                                                        Después cuando nos veamos jodidos , q salgan todos los imbéciles q votaron por el ✏️ con sus caras de yo no fui...tmr
# 11438  Jacqueline Aponte es la ganadora de la lonchera de TIENDAS FERCO, ella estuvo conectada en la transmisión y además compartió la publicación.   Disculpen la demora he tenido que verificar que todas las personas concursantes sean las que estuvieron conectados en vivo.   Gracias a todos por partici...
# 14175                                                                                                                                                                                                                                                       El tallarin verde del PILOTO 😋 es para comer entre 2 😅
# 10149                                                                                                                                                                      Beto por q no le preguntas a la señora como fue en su gobierno del japones cuanto te pagan desgraciado con la coima vaila el mono  🤮🤥🤮🤮
# 9068                                                                                                                                                                                                        A la firme ya está parca asu mareé ya no le basto con asu mare uno al pastrulo horroroso de machín 🤣🤣🤣
# 11360                                                                                                                                                                                                                                         Cesar Fuentes  ahí sale el mañoso conocido como "el chato puchos" 🤣🤣
# 11635                                                                                                                        Benavente y zambrano esta esperando hasta ahora y en vez de llamarlo lo llaman a corzo y otros cojos mas q clase de profe es Este para mi q no Pasa de octubre ya fuiste gareca 😂🤣😂🤣😂
# 8620   Mi apoyo total para ti campeona, Sofía Mulanovich... Todos los deportistas deberían solidarizarse contigo plantando esa convocatoria al mundial a la FENTA y a la comisión olímpica. Directivos corruptos que se subieron al coche de los logros alcanzados hasta ahora en tu  carrera deportiva de surf...
# 1809                                                                                                                             Espero que nunca viajes a la sierra esperemos que con un caballo bien al palo y verga de toro bien seco te van a darar x tu culo por burlón,  hay que saber perder y ganar,  ✏✏☝️
# 4605                                                                                                                                                                                                                                                  Un genio el tigre. No te vayas nunca!!!! Perú te necesita. 🤩
# 8251                                                                                                                                  En un duelo su padre lo haría polvo en todo sentido al hijo, lo único bueno en sus conciertos son los efectos de luz q le ponen al divo. Bueno cada quien con su gusto 🤷🏻‍♀️
# 6063                                                                                                                                                          Me has hecho emocionar, maldito barbón. 😢 Mi viejita, que en paz descanse, preparaba el mejor shámbar. La sopa de mi niñez. La sopa de toda mi vida.
#
#        label label_name
# 6122       2   positive
# 4819       0   negative
# 5995       2   positive
# 14561      0   negative
# 11438      1    neutral
# 14175      2   positive
# 10149      0   negative
# 9068       0   negative
# 11360      0   negative
# 11635      0   negative
# 8620       0   negative
# 1809       0   negative
# 4605       2   positive
# 8251       1    neutral
# 6063       2   positive

# %% [markdown]
# # Split Train, Test and Validaiton

# %%
from sklearn.model_selection import train_test_split


random_state=1
train_df_, val_df = train_test_split(df, 
                                    test_size=0.20, 
                                    random_state=random_state, 
                            stratify=df.label.values)

# %%
train_df, test_df = train_test_split(train_df_, 
                                    test_size=0.20, 
                                    random_state=42, 
                            stratify=train_df_.label.values)

# %%
# !ls -l ../data/test.csv ../data/train.csv ../data/val.csv
# Out:
# -rw-rw-r-- 1 darkstar darkstar  340317 Aug 13 23:07 ../data/test.csv
# -rw-rw-r-- 1 darkstar darkstar 1421831 Aug 13 23:07 ../data/train.csv
# -rw-rw-r-- 1 darkstar darkstar  440604 Aug 13 23:07 ../data/val.csv

# %%
len(train_df)
# Out:
# 9347

# %%
len(val_df)
# Out:
# 2921

# %%
len(test_df)
# Out:
# 2337

# %%
train_df.to_csv('../data/train.csv', index=False)
val_df.to_csv('../data/val.csv', index=False)
test_df.to_csv('../data/test.csv', index=False)

# %%
# !ls -l ../data/test.csv ../data/train.csv ../data/val.csv
# Out:
# -rw-rw-r-- 1 darkstar darkstar  335788 Aug 14 22:35 ../data/test.csv
# -rw-rw-r-- 1 darkstar darkstar 1425926 Aug 14 22:35 ../data/train.csv
# -rw-rw-r-- 1 darkstar darkstar  443623 Aug 14 22:35 ../data/val.csv

# %% [markdown]
# # Push to Hugging Face

# %%
from datasets import load_dataset
data_files = {"train": "../data/train.csv", "validation": "../data/val.csv", "test": "../data/test.csv"}
ds = load_dataset("csv", data_files=data_files)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'label_name'],
#         num_rows: 9347
#     })
#     validation: Dataset({
#         features: ['text', 'label', 'label_name'],
#         num_rows: 2921
#     })
#     test: Dataset({
#         features: ['text', 'label', 'label_name'],
#         num_rows: 2337
#     })
# })

# %%
#push to hugging face
#https://huggingface.co/settings/tokens
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# ds.push_to_hub("pyupeu/social-media-peruvian-sentiment")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/10 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/745 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/pyupeu/social-media-peruvian-sentiment/commit/79df5b09ec53e739ddbdf8f95ce1384b525162e2', commit_message='Upload dataset', commit_description='', oid='79df5b09ec53e739ddbdf8f95ce1384b525162e2', pr_url=None, pr_revision=None, pr_num=None)
