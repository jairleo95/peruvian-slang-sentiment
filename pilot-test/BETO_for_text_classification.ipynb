# %% [markdown]
# ## BETO for Text Classification
#
# This notebook shows how to use [RoBERTuito](https://huggingface.co/pysentimiento/robertuito-base-uncased) for text classification tasks.
#
# First, let's install some packages

# %%
# !pip install pysentimiento transformers datasets accelerate evaluate
# Out:
# Requirement already satisfied: pysentimiento in /home/darkstar/.local/lib/python3.10/site-packages (0.7.2)
# Requirement already satisfied: transformers in /home/darkstar/.local/lib/python3.10/site-packages (4.34.0)
# Requirement already satisfied: datasets in /home/darkstar/.local/lib/python3.10/site-packages (2.14.5)
# Requirement already satisfied: accelerate in /home/darkstar/.local/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: evaluate in /home/darkstar/.local/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: emoji<2.0.0,>=1.6.1 in /home/darkstar/.local/lib/python3.10/site-packages (from pysentimiento) (1.7.0)
# Requirement already satisfied: spacy<4.0.0,>=3.5.0 in /home/darkstar/.local/lib/python3.10/site-packages (from pysentimiento) (3.7.0)
# Requirement already satisfied: torch!=2.0.1,>=2.0.0 in /home/darkstar/.local/lib/python3.10/site-packages (from pysentimiento) (2.1.2)
# Requirement already satisfied: filelock in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /home/darkstar/.local/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/darkstar/.local/lib/python3.10/site-packages (from datasets) (3.8.5)
# Requirement already satisfied: psutil in /home/darkstar/.local/lib/python3.10/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: responses<0.19 in /home/darkstar/.local/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/darkstar/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/darkstar/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (0.3.2)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (2.4.2)
# Requirement already satisfied: jinja2 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (3.1.2)
# Requirement already satisfied: setuptools in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/darkstar/.local/lib/python3.10/site-packages (from spacy<4.0.0,>=3.5.0->pysentimiento) (3.3.0)
# Requirement already satisfied: sympy in /home/darkstar/.local/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (1.12)
# Requirement already satisfied: networkx in /home/darkstar/.local/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/darkstar/.local/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/darkstar/.local/lib/python3.10/site-packages (from torch!=2.0.1,>=2.0.0->pysentimiento) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/darkstar/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=2.0.1,>=2.0.0->pysentimiento) (12.2.140)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/darkstar/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/darkstar/.local/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/darkstar/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.5.0->pysentimiento) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /home/darkstar/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.5.0->pysentimiento) (2.10.1)
# Requirement already satisfied: six>=1.5 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/darkstar/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4.0.0,>=3.5.0->pysentimiento) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/darkstar/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4.0.0,>=3.5.0->pysentimiento) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0.0,>=3.5.0->pysentimiento) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.16.0,>=0.7.0 in /home/darkstar/.local/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0.0,>=3.5.0->pysentimiento) (0.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/darkstar/.local/lib/python3.10/site-packages (from jinja2->spacy<4.0.0,>=3.5.0->pysentimiento) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/darkstar/.local/lib/python3.10/site-packages (from sympy->torch!=2.0.1,>=2.0.0->pysentimiento) (1.3.0)

# %% [markdown]
# Let's load a dataset -- in this case, a Spanish sentiment analysis dataset from CardiffNLP.

# %%
from datasets import load_dataset

ds = load_dataset("cardiffnlp/tweet_sentiment_multilingual", "spanish")

ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 1839
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 324
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 870
#     })
# })

# %%
ds["train"].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['negative', 'neutral', 'positive'], id=None)}

# %%
ds["test"]["text"][:10]
# Out:
# ['@user jajajaja dale, hacete la boluda vos jajaja igual a vos nunca se te puede tomar en serio te mando un abrazo desde Perú!',
#  'cada vez que cito un tweet se va la ubicación sin tampoco poder ponerla en el momento a uds les pasa? TE VEO Y ME PICA VICICONTE',
#  '@user MAAAAE RAJADO! Pero lo bueno es q uno se va independizando!y logrando metas',
#  'Bueno hoy fui a almorzar a Nanay con otras 3 dras xq la capacitación mal organizada no nos dió almuerzo y encima nos mandan a comer 2pm',
#  'Necesito seguir a mas cuentas camren shippers y fans de las armonías. Me recomendais alguna?',
#  '@user ¡Hola Tomás! ¿Habéis visto los nuevos #dinos de #TierraMagna? Es normal que haya colas antes de que comience el espectáculo',
#  '@user la hijueputa tela se me salió. yo quería volver a quedar acostada.',
#  'Parce yo estoy igual @user',
#  '@user pues no está nada mal',
#  '@user quizá para profesionales no sea mucho,pero hay no remunerados principalmente femenino para quienes es un sueño, pasa en mi país']

# %%
ds["test"]["label"][:10]
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2, 0]

# %% [markdown]
# ## Load models
#
# For this task, we use `robertuito-base-uncased` (there are other two versions: `robertuito-base-uncased`, and `robertuito-base-deacc`)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model_name = "dccuchile/bert-base-spanish-wwm-uncased"

model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=3
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.model_max_length = 128
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:174, in _load_global_deps()
#     173 try:
# --> 174     ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#     175 except OSError as err:
#     176     # Can only happen for wheel with cuda libs as PYPI deps
#     177     # As PyTorch is not purelib, but nvidia-*-cu12 is
#
# File ~/anaconda3/envs/robertuito-env/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#
# OSError: libcufft.so.11: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:1282, in _LazyModule._get_module(self, module_name)
#    1281 try:
# -> 1282     return importlib.import_module("." + module_name, self.__name__)
#    1283 except Exception as e:
#
# File ~/anaconda3/envs/robertuito-env/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/bert/modeling_bert.py:25
#      23 from typing import List, Optional, Tuple, Union
# ---> 25 import torch
#      26 import torch.utils.checkpoint
#
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:234
#     233 if USE_GLOBAL_DEPS:
# --> 234     _load_global_deps()
#     235 from torch._C import *  # noqa: F403
#
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:195, in _load_global_deps()
#     194 for lib_folder, lib_name in cuda_libs.items():
# --> 195     _preload_cuda_deps(lib_folder, lib_name)
#     196 ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#
# File ~/.local/lib/python3.10/site-packages/torch/__init__.py:161, in _preload_cuda_deps(lib_folder, lib_name)
#     160     raise ValueError(f"{lib_name} not found in the system path {sys.path}")
# --> 161 ctypes.CDLL(lib_path)
#
# File ~/anaconda3/envs/robertuito-env/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#
# OSError: libnvJitLink.so.12: cannot open shared object file: No such file or directory
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       1 from transformers import AutoModelForSequenceClassification, AutoTokenizer
#       3 model_name = "dccuchile/bert-base-spanish-wwm-uncased"
# ----> 5 model = AutoModelForSequenceClassification.from_pretrained(
#       6     model_name,
#       7     num_labels=3
#       8 )
#       9 tokenizer = AutoTokenizer.from_pretrained(model_name)
#      10 tokenizer.model_max_length = 128
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     560     return model_class.from_pretrained(
#     561         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     562     )
#     563 elif type(config) in cls._model_mapping.keys():
# --> 564     model_class = _get_model_class(config, cls._model_mapping)
#     565     return model_class.from_pretrained(
#     566         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     567     )
#     568 raise ValueError(
#     569     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     570     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     571 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:387, in _get_model_class(config, model_mapping)
#     386 def _get_model_class(config, model_mapping):
# --> 387     supported_models = model_mapping[type(config)]
#     388     if not isinstance(supported_models, (list, tuple)):
#     389         return supported_models
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:739, in _LazyAutoMapping.__getitem__(self, key)
#     737 if model_type in self._model_mapping:
#     738     model_name = self._model_mapping[model_type]
# --> 739     return self._load_attr_from_module(model_type, model_name)
#     741 # Maybe there was several model types associated with this config.
#     742 model_types = [k for k, v in self._config_mapping.items() if v == key.__name__]
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:753, in _LazyAutoMapping._load_attr_from_module(self, model_type, attr)
#     751 if module_name not in self._modules:
#     752     self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 753 return getattribute_from_module(self._modules[module_name], attr)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:697, in getattribute_from_module(module, attr)
#     695 if isinstance(attr, tuple):
#     696     return tuple(getattribute_from_module(module, a) for a in attr)
# --> 697 if hasattr(module, attr):
#     698     return getattr(module, attr)
#     699 # Some of the mappings have entries model_type -> object of another model type. In that case we try to grab the
#     700 # object at the top level.
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:1272, in _LazyModule.__getattr__(self, name)
#    1270     value = self._get_module(name)
#    1271 elif name in self._class_to_module.keys():
# -> 1272     module = self._get_module(self._class_to_module[name])
#    1273     value = getattr(module, name)
#    1274 else:
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:1284, in _LazyModule._get_module(self, module_name)
#    1282     return importlib.import_module("." + module_name, self.__name__)
#    1283 except Exception as e:
# -> 1284     raise RuntimeError(
#    1285         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1286         f" traceback):\n{e}"
#    1287     ) from e
#
# RuntimeError: Failed to import transformers.models.bert.modeling_bert because of the following error (look up to see its traceback):
# libnvJitLink.so.12: cannot open shared object file: No such file or directory

# %% [markdown]
# ## Preprocessing
#
# Before tokenizing our model, we have to run the `preprocess_tweet` function to our data.

# %%
from pysentimiento.preprocessing import preprocess_tweet
preprocessed_ds = ds.map(lambda ex: {"text": preprocess_tweet(ex["text"], lang="es")})

# %% [markdown]
# ## Tokenization

# %%
tokenized_ds = preprocessed_ds.map(
    lambda batch: tokenizer(batch["text"], padding=False, truncation=True),
    batched=True, batch_size=32
)

# %%
tokenized_ds

# %% [markdown]
# ## Training

# %%
# !pip install ipdb

# %%
import numpy as np
import evaluate

f1_metric = evaluate.load("f1")
recall_metric = evaluate.load("recall")

def compute_metrics (eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis = -1)

    results = {}
    results.update(f1_metric.compute(predictions=preds, references = labels, average="macro"))
    results.update(recall_metric.compute(predictions=preds, references = labels, average="macro"))
    return results

# %%
from transformers import TrainingArguments, Trainer, DataCollatorWithPadding

training_args = TrainingArguments(
    per_device_train_batch_size=32,
    output_dir="beto_test_trainer",
    do_eval=True,
    evaluation_strategy="epoch",
    num_train_epochs=5,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds["train"],
    eval_dataset=tokenized_ds["validation"],
    compute_metrics=compute_metrics,
    data_collator=DataCollatorWithPadding(tokenizer=tokenizer),
)
trainer.train()

# %%
trainer.evaluate(tokenized_ds["test"])
