# %% [markdown]
# ## Inference Robertuit SA Peruvian Slangs

# %%
import torch
from datasets import load_dataset
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from tqdm.notebook import tqdm
import numpy as np
import pandas as pd

# %%
pd.set_option("max_colwidth", 300)

# %%
df = pd.read_excel(r'../Sample_Final12012024_sergiovr01.xlsx', dtype={
    'slangs': 'string',
    'text': 'string',
    'label': 'string'
})
df
# Out:
#           id         object_id                     ID2  \
# 0       6609   818357438368658    6609-818357438368658
# 1      18894   653935986794869   18894-653935986794869
# 2      23057   166951283038651   23057-166951283038651
# 3      65586   624101801451478   65586-624101801451478
# 4        152  1322849097815100    152-1322849097815100
# ...      ...               ...                     ...
# 9197   36945   747297622507130   36945-747297622507130
# 9198   84658  1319112772263570  84658-1319112772263570
# 9199  185373   269660851242985  185373-269660851242985
# 9200  172500   458655262784358  172500-458655262784358
# 9201   53889   224576233446754   53889-224576233446754
#
#                                                                                                                                         text  \
# 0                                                                               Estoy  cerca a la molina 😊.. que xvre ..   Para mis pequeñas
# 1                                                                                                  Decidamos todo! ❤ = Ing y 2k 👍= Vago y 7k
# 2                                                             Edyth J. Gamarra 😊 ahí nos vemos...siempre cansadas pero para el tono nooooooo
# 3     Gente así fue el tono en Huaraz Carlos Gamboa Tati Kispe Jose V León Kevin Limaylla apunta esos tips para fin de mes Elaine Abril 😁😁🍺🍺
# 4                                                                                              Elizabeth escucha donde fue el tono jajaja 🤣🤣
# ...                                                                                                                                      ...
# 9197                    Igual a ellos también le vas tirar m... cuando no funciona bien. Tu sabes las primeras citas son así de buena onda 😆
# 9198                                                              Chinito un saludo para mi hijo LUCAS Y LUIGUI en Chimbote 21 de abril ✌✌❤❤
# 9199                                                                                                   Que te dije Lucas..tu y yo estamos.🤭😂
# 9200                                            Este monistro es tan parecido al tio lucas , en la cara y en el cerebro, hsbla huev....as🤮🤮🤮
# 9201                                                        Eric Saludos para mi hijo Lucas Adriano una entradita p fuerza cristal tlv csm💙💙
#
#            slangs  slangs_char_count conjunto Polaridad_TENTATIVA  \
# 0           xvre,                  5   Chunk1            POSITIVO
# 1           vago,                  5   Chunk1            POSITIVO
# 2           tono,                  5   Chunk1            POSITIVO
# 3           tono,                  5   Chunk1            POSITIVO
# 4           tono,                  5   Chunk1            NEGATIVO
# ...           ...                ...      ...                 ...
# 9197  tira,tirar,                 11   chunk3            POSITIVO
# 9198  lucas,luca,                 11   chunk3            POSITIVO
# 9199  lucas,luca,                 11   chunk3             NEUTRAL
# 9200  lucas,luca,                 11   chunk3            NEGATIVO
# 9201  lucas,luca,                 11   chunk3            POSITIVO
#
#      TIENE_EMOJI_RECONOCIDO?  En Muestra_FINAL_Manual ANNOTATOR label
# 0                         SI                        1    SERGIO     1
# 1                         SI                        1    SERGIO     0
# 2                         SI                        1    SERGIO     2
# 3                         SI                        1    SERGIO     0
# 4                         SI                        1    SERGIO     1
# ...                      ...                      ...       ...   ...
# 9197                      SI                        1    SERGIO     3
# 9198                      SI                        1    SERGIO     1
# 9199                      SI                        1    SERGIO     2
# 9200                      SI                        1    SERGIO     3
# 9201                      SI                        1    SERGIO     1
#
# [9202 rows x 12 columns]

# %%
df = df[df.label.isin(["2"])]
df = df.astype({'label':'int'})

# %%
def label_encode(x):
    if x == 1:#positive
        return 2
    if x == 2:#neutral
        return 1
    if x == 3:#negative
        return 0

# label to name
def label2name(x):
    if x == 0:
        return "Negative"
    if x == 1:
        return "Neutral"
    if x == 2:
        return "Positive"
        
def label_decode(x):
    if x == 2:#positive
        return 1
    if x == 1:#neutral
        return 2
    if x == 0:#negative
        return 3

# %%
df["label"] = df["label"].apply(lambda x: label_encode(x))
df["label_name"] = df["label"].apply(lambda x: label2name(x))

# %%
df
# Out:
#           id         object_id                     ID2  \
# 2      23057   166951283038651   23057-166951283038651
# 10      6102   526474777813957    6102-526474777813957
# 19     39470  5388274867901020  39470-5388274867901020
# 22     87430  3587570224801810  87430-3587570224801810
# 35     59827   427622817959508   59827-427622817959508
# ...      ...               ...                     ...
# 9179   35285   340255308328201   35285-340255308328201
# 9180   72690   907019600716037   72690-907019600716037
# 9191   22623  1577509765705500  22623-1577509765705500
# 9195  170412   436557564064958  170412-436557564064958
# 9199  185373   269660851242985  185373-269660851242985
#
#                                                                                                 text  \
# 2                     Edyth J. Gamarra 😊 ahí nos vemos...siempre cansadas pero para el tono nooooooo
# 10                                                         Amor Eduardo Pacheco Lecaros agendalo!! 😉
# 19                                                           Valentin Lobato nose porq pensé en ti 🤔
# 22                        ...Loba estas, juguemos a la ronda mientras la loba esta, loba estas??🤣🤣🤣🤣
# 35                              Rafa Nancay Huillca hay una loza que se parece a la jato de tu ex 🤣🤣
# ...                                                                                              ...
# 9179                                                                     Quien es la gordita 😅🤌🏼🤌🏼😂😂
# 9180                           😂jajaja  la gordita  de mostró  Conoce a todos de la empresa genecis.
# 9191           Milagros Reyes Mitchell  fuguemos a Cabo Blanco, pasaje sin retorno, Lucas, tú y yo 😍
# 9195  Tanta gente te ve que tienes que publicarlo aqui por el face tus entrevista mi querido lucas 🙃
# 9199                                                           Que te dije Lucas..tu y yo estamos.🤭😂
#
#            slangs  slangs_char_count conjunto Polaridad_TENTATIVA  \
# 2           tono,                  5   Chunk1            POSITIVO
# 10          leca,                  5   Chunk1            POSITIVO
# 19          loba,                  5   Chunk1            NEGATIVO
# 22          loba,                  5   Chunk1            NEGATIVO
# 35          jato,                  5   Chunk1            NEGATIVO
# ...           ...                ...      ...                 ...
# 9179  la gordita,                 11   chunk3             NEUTRAL
# 9180  la gordita,                 11   chunk3             NEUTRAL
# 9191  lucas,luca,                 11   chunk3            POSITIVO
# 9195  lucas,luca,                 11   chunk3            NEGATIVO
# 9199  lucas,luca,                 11   chunk3             NEUTRAL
#
#      TIENE_EMOJI_RECONOCIDO?  En Muestra_FINAL_Manual ANNOTATOR  label  \
# 2                         SI                        1    SERGIO      1
# 10                        SI                        1    SERGIO      1
# 19                        SI                        1    SERGIO      1
# 22                        SI                        1    SERGIO      1
# 35                        SI                        1    SERGIO      1
# ...                      ...                      ...       ...    ...
# 9179                      SI                        1    SERGIO      1
# 9180                      SI                        1    SERGIO      1
# 9191                      SI                        1    SERGIO      1
# 9195                      SI                        1    SERGIO      1
# 9199                      SI                        1    SERGIO      1
#
#      label_name
# 2       Neutral
# 10      Neutral
# 19      Neutral
# 22      Neutral
# 35      Neutral
# ...         ...
# 9179    Neutral
# 9180    Neutral
# 9191    Neutral
# 9195    Neutral
# 9199    Neutral
#
# [2651 rows x 13 columns]

# %%
# model_name = "pyupeu/robertuito-peruvian-sentiment"
model_name = "pysentimiento/robertuito-sentiment-analysis"
max_length = 128
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=3
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.model_max_length = max_length
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from pysentimiento.preprocessing import preprocess_tweet
# test_df = ds['test'].to_pandas()
df['text_original'] = df['text'] 
df["text"] = df["text"].apply(lambda x: preprocess_tweet(x, lang="es"))
test_df = df
# Out:
# 2024-04-25 14:24:00.076094: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-25 14:24:00.112168: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-25 14:24:00.112194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-25 14:24:00.113321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-25 14:24:00.119547: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-25 14:24:00.808702: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
test_df.sample(10)
# Out:
#           id         object_id                      ID2  \
# 3272   62210  1545330855601660   62210-1545330855601660
# 4040  120362  4382265671844300  120362-4382265671844300
# 8633   25533   804730454387157    25533-804730454387157
# 4689   11674   764654267072309    11674-764654267072309
# 5577   61220   571495367154094    61220-571495367154094
# 1035   14689  1314468239030880   14689-1314468239030880
# 6211     473  1157451784658850     473-1157451784658850
# 5999   11861   764654267072309    11861-764654267072309
# 7368   47492   606449768157598    47492-606449768157598
# 5316    1655  1681778055669150    1655-1681778055669150
#
#                                                                                                                                                                                                                                                                                       text  \
# 3272                                                                                                                                                                                                                       BtoRoman estamos miércoles  emoji cara con ojos en blanco emoji
# 4040                                                                                                                                               No Brotherhood una tabla cantando   Por cierto Gracias por las clases  emoji mano con señal de victoria emoji  PAZ   Me ban a Funar ^-^
# 8633                  Churra cruda tiene razón pa asarse con perro flaco alias Jimy  emoji cara llorando de risa emoji  emoji cara revolviéndose de la risa emoji  emoji cara llorando de risa emoji  emoji cara revolviéndose de la risa emoji  emoji cara revolviéndose de la risa emoji
# 4689                                                                                                                                         Ohhh por faaa pásame el dato de la tienda donde puedo adquirir las muñequitas de Bella y Bestia que sale casi al principio del video. Gracias
# 5577                                                                                                                                                                        Maiden, la debilidad de todo otaku ?  emoji cara revolviéndose de la risa emoji  emoji cara de por favor emoji
# 1035                                                                                                                                     PRIMERO QUE NADA ESTA EL BIENESTAR DE LOS NIÑOS  ESOS CABEZA DE POLLOS NO PENSARON NI ESO!! INCREIBLE SALUDOS IWOO  emoji manos aplaudiendo emoji
# 6211                                                                            Jjaja Cristian, te pasaste, eres de lo peor jaja, pobre China, se estaba ahogando  emoji cara sonriendo con sudor frío emoji  la próxima avísale no?... mínimo  emoji cara feliz con ojos sonrientes emoji
# 5999                                                                                                                                                                                                        Wilfredo Cruz Narro varios d nuestros points  emoji cara guiñando el ojo emoji
# 7368  Una vez le pregunté a una cebra si era blanca con rayas negras o negra con rayas blancas, me respondió: "¿¿Tú Eres Feliz Con Momentos Tristes O Triste Con Momentos Felices??", ahí decidí dejar de andar preguntando pendejadas y menos a los animales que se supone que no hablan.
# 5316                          Los primeros chicharrones de mi vida los probé en Lurin, pero realmente este es el de los mejores,  que recuerdo Arnaldo y  Miguel,  del Perú  emoji bandera perú emoji  para el mundo   emoji globo terráqueo mostrando américa emoji  . El mejor Sándwich.
#
#                                  slangs  slangs_char_count conjunto  \
# 3272                         miércoles,                 10   chunk2
# 4040                           brother,                  8   chunk2
# 8633                      asarse,flaco,                 13   chunk3
# 4689                            bestia,                  7   chunk2
# 5577                             otaku,                  6   chunk2
# 1035             cabeza de pollo,pollo,                 22   chunk2
# 6211                             china,                  6   chunk2
# 5999                             point,                  6   chunk2
# 7368  anda,pendejada,raya,blanca,habla,                 33   chunk3
# 5316                            chicha,                  7   chunk2
#
#      Polaridad_TENTATIVA TIENE_EMOJI_RECONOCIDO?  En Muestra_FINAL_Manual  \
# 3272            NEGATIVO                      SI                        1
# 4040            POSITIVO                      SI                        1
# 8633             NEUTRAL                      SI                        1
# 4689            POSITIVO                      SI                        1
# 5577            POSITIVO                      SI                        1
# 1035            POSITIVO                      SI                        1
# 6211            POSITIVO                      SI                        1
# 5999            POSITIVO                      SI                        1
# 7368            NEGATIVO                      SI                        1
# 5316            POSITIVO                      SI                        1
#
#      ANNOTATOR  label label_name  \
# 3272    SERGIO      1    Neutral
# 4040    SERGIO      1    Neutral
# 8633    SERGIO      1    Neutral
# 4689    SERGIO      1    Neutral
# 5577    SERGIO      1    Neutral
# 1035    SERGIO      1    Neutral
# 6211    SERGIO      1    Neutral
# 5999    SERGIO      1    Neutral
# 7368    SERGIO      1    Neutral
# 5316    SERGIO      1    Neutral
#
#                                                                                                                                                                                                                                                                                 text_original  \
# 3272                                                                                                                                                                                                                                                             BtoRoman estamos miércoles 🙄
# 4040                                                                                                                                                                                        No Brotherhood una tabla cantando   Por cierto Gracias por las clases ✌ PAZ   Me ban a Funar ^-^
# 8633                                                                                                                                                                                                                      Churra cruda tiene razón pa asarse con perro flaco alias Jimy 😂🤣😂🤣🤣
# 4689                                                                                                                                        Ohhhh por faaa pásame el dato de la tienda donde puedo adquirir las muñequitas de Bella y Bestia que sale casi al principio del video. Gracias ☺️
# 5577                                                                                                                                                                                                                                                  Maiden, la debilidad de todo otaku ? 🤣🥺
# 1035                                                                                                                                                                     PRIMERO QUE NADA ESTA EL BIENESTAR DE LOS NIÑOS  ESOS CABEZA DE POLLOS NO PENSARON NI ESO!! INCREIBLE SALUDOS IWOO 👏
# 6211                                                                                                                                                                Jajaja Cristian, te pasaste, eres de lo peor jajaja, pobre China, se estaba ahogando 😅 la próxima avísale no?... mínimo 😊
# 5999                                                                                                                                                                                                                                           Wilfredo Cruz Narro varios d nuestros points 😉
# 7368  Una vez le pregunté a una cebra si era blanca con rayas negras o negra con rayas blancas, me respondió: "¿¿Tú Eres Feliz Con Momentos Tristes O Triste Con Momentos Felices??", ahí decidí dejar de andar preguntando pendejadas y menos a los animales que se supone que no hablan. ☹️
# 5316                                                                                                   Los primeros chicharrones de mi vida los probé en Lurin, pero realmente este es el de los mejores,  que recuerdo Arnaldo y  Miguel,  del Perú 🇵🇪 para el mundo  🌎 . El mejor Sándwich.
#
#       pred pred_name
# 3272     0  Negative
# 4040     1   Neutral
# 8633     0  Negative
# 4689     1   Neutral
# 5577     1   Neutral
# 1035     2  Positive
# 6211     0  Negative
# 5999     2  Positive
# 7368     0  Negative
# 5316     2  Positive

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model.cuda()
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(30002, 768, padding_idx=1)
#       (position_embeddings): Embedding(130, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=3, bias=True)
#   )
# )

# %%
# We do this to view predictions in the pandas dataframe and easily filter them and perform error analysis.
pred_test_final = []

for i, row in tqdm(test_df.iterrows(), total=test_df.shape[0]):
    predictions = []

    text = row["text"]
    encoded_data_test_single = tokenizer.batch_encode_plus([text], 
    # add_special_tokens=config.add_special_tokens, 
    # return_attention_mask=config.return_attention_mask, 
    # pad_to_max_length=config.pad_to_max_length, 
    max_length=128,
    # return_tensors=config.return_tensors
    return_tensors="pt"
    )
    input_ids_test = encoded_data_test_single['input_ids']
    attention_masks_test = encoded_data_test_single['attention_mask']

    
    inputs = {'input_ids':      input_ids_test.to(device),
              'attention_mask':attention_masks_test.to(device),
             }

    with torch.no_grad():        
        outputs = model(**inputs)
    
    logits = outputs[0]
    logits = logits.detach().cpu().numpy()
    predictions.append(logits)
    predictions = np.concatenate(predictions, axis=0)
    pred_test_final.append(np.argmax(predictions, axis=1).flatten()[0])
# Out:
#   0%|          | 0/2651 [00:00<?, ?it/s]

# %%
# add pred into val_df
test_df["pred"] = pred_test_final
# label to intent mapping
name2label = {"Negative":0,
              "Neutral":1,
             "Positive":2
             }
label2name = {v: k for k, v in name2label.items()}

test_df["pred_name"] = test_df.pred.apply(lambda x: label2name.get(x))

# %%
len(test_df)
# Out:
# 2651

# %%
df["label"] = df["label"].apply(lambda x: label_decode(x))
df["pred"] = df["pred"].apply(lambda x: label_decode(x))

# %%
# test_df.to_excel('../Sample_final_neutales_corregidos.xlsx', index=False)

# %%
test_df.sample(20)
# Out:
#           id         object_id                     ID2  \
# 293     2905   387599299189259    2905-387599299189259
# 4344   43232  1313086139106630  43232-1313086139106630
# 1202  208654   731285401274716  208654-731285401274716
# 1768   39425   644658356073993   39425-644658356073993
# 4901   26665  8910042552403230  26665-8910042552403230
# 5064   11457  1691960471192130  11457-1691960471192130
# 2631    4106  2011033479151730   4106-2011033479151730
# 2951   21402  1514107845305980  21402-1514107845305980
# 4781    7685  1564655590648220   7685-1564655590648220
# 3744   73060  1171515626970960  73060-1171515626970960
# 1025   20002   636126677174526   20002-636126677174526
# 5854   61463   682215342204304   61463-682215342204304
# 2350     183  2072468166300920    183-2072468166300920
# 5522   64094   294725264479810   64094-294725264479810
# 421     3961  1693898353972860   3961-1693898353972860
# 6160     264   720757133399757     264-720757133399757
# 971    85035  1319112772263570  85035-1319112772263570
# 634    22978  1295324757230520  22978-1295324757230510
# 8170  150987   453144512621198  150987-453144512621198
# 5541   33725  1398367743619700  33725-1398367743619700
#
#                                                                                                                                                                                                                                                                                                              text  \
# 293                                                                                                                                     Dany Darko Darkles   emoji cara llorando de risa emoji  emoji cara llorando de risa emoji   cualquier parecido con la realidad es pura coincidencia  emoji fantasma emoji
# 4344                                                                                                                                                                                                                   William Kevin Marez Charles  como que los pokemon son japoneses?  emoji cara neutral emoji
# 1202                                                                    Para bronquios neumonia es BUENAZO EL WITO. es un remedio casero una primita nació cn bronquios neumonia y se sano cn WITO. En realidad los hijos no tienen la culpa d nada, la culpa son d los padres  emoji cara de desaprobación emoji
# 1768                                                                                                                                         Danniela Rivers Rivers mira todo lo que había por tu casa y de monces solo comiendo lo mismo en el delivery o centro comercial...  emoji cara de desaprobación emoji
# 4901                                                                                                                                                                                                                                                  Kaiser , tenías que pechar  emoji cara con sudor frío emoji
# 5064                                                                                                                                     Jjaja.!! Pero para que gente pituca si ellos se pueden ir del país.  Tu Pedrito, es cambio la solución y igualdad ante todo  emoji cara revolviéndose de la risa emoji .
# 2631                                                                                                                                                                                                             Edson ya sabes con nuestro arroz con pollo y ceviche  emoji cara feliz con ojos sonrientes emoji
# 2951                                                                                                                                                                                        Yo también me chupe !  emoji mono con los ojos tapados emoji  la próxima - si me vuelven a invitar jijiji - me acerco
# 4781                                                                                                                                                                                                          La gente bien patera como la engañan,si Soraya se robo el show  emoji cara con ojos en blanco emoji
# 3744                                                                                                                                                     Mñn vendo el auto y vuelvo ala mototaxi  emoji cara babeando emoji  emoji cara revolviéndose de la risa emoji  emoji cara revolviéndose de la risa emoji
# 1025                               CAUSA NO SE PERO CUANDO ESCUCHE TU VOS DIJE . ESTE ES LALO LA LOCURA  DE 1000 OFICIOS  emoji cara llorando de risa emoji  emoji cara llorando de risa emoji .   Y como  que el cacharro y tu físico  acompaña . Saludos  Psdt. Es la primera vez que veo un video tuyo . Genio
# 5854                                                                                                          Bro cómo es que comes tanto y no engordas... Yo comiera todo eso estuviera cómo tongo jaja. Viaja y prueba deben ir al nororiente del Perú  emoji manos en oración emoji  Jaén, Bagua, Bagua grande
# 2350                                                                                                                                          Estaría perfecto para mi gordo  emoji cara guiñando el ojo emoji  Mirella Cortez Gladys Guerra Nancy Huamani Participen  emoji cara feliz con ojos sonrientes emoji
# 5522                                                                                                                                                                                                                             Felicidades Misias . comprare sus polos y  revender al misio tacaño de mi esposo
# 421                                                                                                                                                  Asi será Alexandra Piña Sanchez nada de cursilerias  emoji cara llorando de risa emoji  emoji cara llorando de risa emoji  emoji cara llorando de risa emoji
# 6160                                                                                                                                                                                                                         Porque Mr choco se escucha tan claro  emoji gato sonriendo con ojos sonrientes emoji
# 971                                                                                                                                                                                      Naim Iarhel Merino Jara  sta de vuelta chino risas manda su saludos a mi bro emoji cara sonriendo con gafas de sol emoji
# 634   una buena picanteria tiene canchita serrana para matar el rato como ustedes, su chicha de jora en poto, su batán para una buena comida obvio y su rocoto picante...como dijo el tio melcocha ese aji pica cuando entra y cuando sale  emoji cara sonriendo con cuernos emoji  emoji cara sonriendo con c...
# 8170                                                                                                                                                                                                                              Cuidao Beto que agarran a chicotazos  emoji cara sonriendo con sudor frío emoji
# 5541                                                                                                                                                                                                                             Alejo Saldarriaga no están monse, como dicen  emoji cara saboreando comida emoji
#
#                                           slangs  slangs_char_count conjunto  \
# 293                                        dark,                  5   Chunk1
# 4344                                    pokemon,                  8   chunk2
# 1202                        casero,buenazo,sano,                 20   chunk2
# 1768                            comercial,monce,                 16   chunk2
# 4901                                     pechar,                  7   chunk2
# 5064                                     pituca,                  7   chunk2
# 2631                                arroz,pollo,                 12   chunk2
# 2951                                 chup,chupe,                 11   chunk2
# 4781                                     patera,                  7   chunk2
# 3744                                   mototaxi,                  9   chunk2
# 1025                      cacha,cachar,cacharro,                 22   chunk2
# 5854                                      tongo,                  6   chunk2
# 2350                               huaman,nancy,                 13   chunk2
# 5522                                      misio,                  6   chunk2
# 421                                        piña,                  5   Chunk1
# 6160                                      choco,                  6   chunk2
# 971                      chino,de vuelta,vuelta,                 23   chunk2
# 634   batán,canchita,colorado,suave,poto,chicha,                 42   chunk2
# 8170                            chico,chicotazo,                 16   chunk3
# 5541                                      monse,                  6   chunk2
#
#      Polaridad_TENTATIVA TIENE_EMOJI_RECONOCIDO?  En Muestra_FINAL_Manual  \
# 293              NEUTRAL                      SI                        1
# 4344            NEGATIVO                      SI                        1
# 1202            NEGATIVO                      SI                        1
# 1768            NEGATIVO                      SI                        1
# 4901             NEUTRAL                      SI                        1
# 5064            NEGATIVO                      SI                        1
# 2631            POSITIVO                      SI                        1
# 2951            POSITIVO                      SI                        1
# 4781            NEGATIVO                      SI                        1
# 3744            NEGATIVO                      SI                        1
# 1025             NEUTRAL                      SI                        1
# 5854            POSITIVO                      SI                        1
# 2350            POSITIVO                      SI                        1
# 5522            POSITIVO                      SI                        1
# 421              NEUTRAL                      SI                        1
# 6160            POSITIVO                      SI                        1
# 971             POSITIVO                      SI                        1
# 634             POSITIVO                      SI                        1
# 8170             NEUTRAL                      SI                        1
# 5541            POSITIVO                      SI                        1
#
#      ANNOTATOR  label label_name  \
# 293     SERGIO      2    Neutral
# 4344    SERGIO      2    Neutral
# 1202    SERGIO      2    Neutral
# 1768    SERGIO      2    Neutral
# 4901    SERGIO      2    Neutral
# 5064    SERGIO      2    Neutral
# 2631    SERGIO      2    Neutral
# 2951    SERGIO      2    Neutral
# 4781    SERGIO      2    Neutral
# 3744    SERGIO      2    Neutral
# 1025    SERGIO      2    Neutral
# 5854    SERGIO      2    Neutral
# 2350    SERGIO      2    Neutral
# 5522    SERGIO      2    Neutral
# 421     SERGIO      2    Neutral
# 6160    SERGIO      2    Neutral
# 971     SERGIO      2    Neutral
# 634     SERGIO      2    Neutral
# 8170    SERGIO      2    Neutral
# 5541    SERGIO      2    Neutral
#
#                                                                                                                                                                                                                                                            text_original  \
# 293                                                                                                                                                                                    Dany Darko Darkles  😂😂  cualquier parecido con la realidad es pura coincidencia 👻
# 4344                                                                                                                                                                                                  William Kevin Marez Charles  como que los pokemon son japoneses? 😐
# 1202                                                            Para bronquios neumonia es BUENAZO EL WITO. es un remedio casero una primita nació cn bronquios neumonia y se sano cn WITO. En realidad los hijos no tienen la culpa d nada, la culpa son d los padres 😒
# 1768                                                                                                                                 Danniela Rivers Rivers mira todo lo que había por tu casa y de monces solo comiendo lo mismo en el delivery o centro comercial... 😒
# 4901                                                                                                                                                                                                                                        Kaiser , tenías que pechar 😓
# 5064                                                                                                                                     Jajaja.!! Pero para que gente pituca si ellos se pueden ir del país.  Tu Pedrito, es cambio la solución y igualdad ante todo 🤣.
# 2631                                                                                                                                                                                                              Edson ya sabes con nuestro arroz con pollo y ceviche 😊
# 2951                                                                                                                                                                                     Yo también me chupe ! 🙈 la próxima - si me vuelven a invitar jijiji - me acerco
# 4781                                                                                                                                                                                                    La gente bien patera como la engañan,si Soraya se robo el show 🙄
# 3744                                                                                                                                                                                                                         Mñn vendo el auto y vuelvo ala mototaxi 🤤🤣🤣
# 1025                                                          CAUSA NO SE PERO CUANDO ESCUCHE TU VOS DIJE . ESTE ES LALO LA LOCURA  DE 1000 OFICIOS 😂😂.   Y como  que el cacharro y tu físico  acompaña . Saludos  Psdt. Es la primera vez que veo un video tuyo . Genio
# 5854                                                                                         Bro cómo es que comes tanto y no engordas... Yo comiera todo eso estuviera cómo tongo jajajajaj. Viaja y prueba deben ir al nororiente del Perú 🙏 Jaén, Bagua, Bagua grande
# 2350                                                                                                                                                                            Estaría perfecto para mi gordo 😉 Mirella Cortez Gladys Guerra Nancy Huamani Participen 😊
# 5522                                                                                                                                                                                Felicidades Misias❤ . comprare sus polos y  revender al misio tacaño de mi esposo ❤❤
# 421                                                                                                                                                                                                             Asi será Alexandra Piña Sanchez nada de cursilerias 😂😂😂😂
# 6160                                                                                                                                                                                                                              Porque Mr choco se escucha tan claro 😸
# 971                                                                                                                                                                                        Naim Iarhel Merino Jara  sta de vuelta chino risas manda su saludos a mi bro😎
# 634   una buena picanteria tiene canchita serrana para matar el rato como ustedes, su chicha de jora en poto, su batán para una buena comida obvio y su rocoto picante....como dijo el tio melcocha ese aji pica cuando entra y cuando sale 😈😈 asi que suave colorado 😛😜
# 8170                                                                                                                                                                                                                              Cuidao Beto que agarran a chicotazos 😅
# 5541                                                                                                                                                                                                                      Alejo Saldarriaga no están monse, como dicen 😋
#
#       pred pred_name
# 293      2   Neutral
# 4344     3  Negative
# 1202     2   Neutral
# 1768     3  Negative
# 4901     3  Negative
# 5064     2   Neutral
# 2631     1  Positive
# 2951     2   Neutral
# 4781     3  Negative
# 3744     2   Neutral
# 1025     1  Positive
# 5854     2   Neutral
# 2350     1  Positive
# 5522     3  Negative
# 421      2   Neutral
# 6160     1  Positive
# 971      1  Positive
# 634      1  Positive
# 8170     3  Negative
# 5541     2   Neutral

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

pred_name_values = test_df.pred_name.values
label_values = test_df.label_name.values
cm = confusion_matrix(label_values, pred_name_values)
cm_df = pd.DataFrame(cm,
                     index = ['Negative','Neutral','Positive'], 
                     columns = ['Negative','Neutral','Positive'])
plt.figure(figsize=(8,7))
sns.heatmap(cm_df, annot=True,fmt=".0f")
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
from sklearn.metrics import classification_report
classification_rep = classification_report(label_values, pred_name_values, digits=5)

print(classification_rep)
# Out:
#               precision    recall  f1-score   support
#
#     Negative    0.00000   0.00000   0.00000         0
#      Neutral    1.00000   0.61713   0.76324      2651
#     Positive    0.00000   0.00000   0.00000         0
#
#     accuracy                        0.61713      2651
#    macro avg    0.33333   0.20571   0.25441      2651
# weighted avg    1.00000   0.61713   0.76324      2651
# /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
