# %%
import sys
import pandas as pd 
import os 
import glob

# %%
csv_files = glob.glob(os.path.join(r"facebook/extraction-*/", "*.csv"))

# %%
csv_files
# Out:
# ['facebook\\extraction-1\\Accel_01-09.csv',
#  'facebook\\extraction-1\\Antaurus_01.csv',
#  'facebook\\extraction-1\\Antaurus_02.csv',
#  'facebook\\extraction-1\\Antaurus_03.csv',
#  'facebook\\extraction-1\\Antaurus_04.csv',
#  'facebook\\extraction-1\\Antaurus_05.csv',
#  'facebook\\extraction-1\\AntonellaAservi_01.csv',
#  'facebook\\extraction-1\\AntonellaLeon1.csv',
#  'facebook\\extraction-1\\AntonellaLeon10.csv',
#  'facebook\\extraction-1\\AntonellaLeon11.csv',
#  'facebook\\extraction-1\\AntonellaLeon12.csv',
#  'facebook\\extraction-1\\AntonellaLeon13.csv',
#  'facebook\\extraction-1\\AntonellaLeon14.csv',
#  'facebook\\extraction-1\\AntonellaLeon15.csv',
#  'facebook\\extraction-1\\AntonellaLeon16.csv',
#  'facebook\\extraction-1\\AntonellaLeon17.csv',
#  'facebook\\extraction-1\\AntonellaLeon18.csv',
#  'facebook\\extraction-1\\AntonellaLeon19.csv',
#  'facebook\\extraction-1\\AntonellaLeon2.csv',
#  'facebook\\extraction-1\\AntonellaLeon20.csv',
#  'facebook\\extraction-1\\AntonellaLeon21.csv',
#  'facebook\\extraction-1\\AntonellaLeon3.csv',
#  'facebook\\extraction-1\\AntonellaLeon4.csv',
#  'facebook\\extraction-1\\AntonellaLeon5.csv',
#  'facebook\\extraction-1\\AntonellaLeon6.csv',
#  'facebook\\extraction-1\\AntonellaLeon7.csv',
#  'facebook\\extraction-1\\AntonellaLeon8.csv',
#  'facebook\\extraction-1\\AntonellaLeon9.csv',
#  'facebook\\extraction-1\\BrunoPinasco_01.csv',
#  'facebook\\extraction-1\\ChiaraPinasco_01.csv',
#  'facebook\\extraction-1\\ChinoRisas1.csv',
#  'facebook\\extraction-1\\ChinoRisas2.csv',
#  'facebook\\extraction-1\\ChinoRisas3.csv',
#  'facebook\\extraction-1\\ChinoRisas4.csv',
#  'facebook\\extraction-1\\ChinoRisas5.csv',
#  'facebook\\extraction-1\\ChinoRisas6.csv',
#  'facebook\\extraction-1\\ChinoRisas7.csv',
#  'facebook\\extraction-1\\CristianBravo_01.csv',
#  'facebook\\extraction-1\\CristianBravo_02.csv',
#  'facebook\\extraction-1\\CristianRivero1.csv',
#  'facebook\\extraction-1\\CristianRivero2.csv',
#  'facebook\\extraction-1\\CristianRivero3.csv',
#  'facebook\\extraction-1\\CristianRivero4.csv',
#  'facebook\\extraction-1\\CristianRivero5.csv',
#  'facebook\\extraction-1\\CristianRivero6.csv',
#  'facebook\\extraction-1\\DamianyElToyo1.csv',
#  'facebook\\extraction-1\\DamianyElToyo2.csv',
#  'facebook\\extraction-1\\DamianyElToyo3.csv',
#  'facebook\\extraction-1\\DamianyElToyo4.csv',
#  'facebook\\extraction-1\\DamianyElToyo5.csv',
#  'facebook\\extraction-1\\DamianyElToyo6.csv',
#  'facebook\\extraction-1\\DamianyElToyo7.csv',
#  'facebook\\extraction-1\\FrancoNoriega_01.csv',
#  'facebook\\extraction-1\\GastonAcurio_01.csv',
#  'facebook\\extraction-1\\GastonAcurio_02.csv',
#  'facebook\\extraction-1\\GastonAcurio_03.csv',
#  'facebook\\extraction-1\\GianellaClavijo1.csv',
#  'facebook\\extraction-1\\GianellaClavijo10.csv',
#  'facebook\\extraction-1\\GianellaClavijo11.csv',
#  'facebook\\extraction-1\\GianellaClavijo12.csv',
#  'facebook\\extraction-1\\GianellaClavijo13.csv',
#  'facebook\\extraction-1\\GianellaClavijo14.csv',
#  'facebook\\extraction-1\\GianellaClavijo15.csv',
#  'facebook\\extraction-1\\GianellaClavijo16.csv',
#  'facebook\\extraction-1\\GianellaClavijo17.csv',
#  'facebook\\extraction-1\\GianellaClavijo2.csv',
#  'facebook\\extraction-1\\GianellaClavijo3.csv',
#  'facebook\\extraction-1\\GianellaClavijo4.csv',
#  'facebook\\extraction-1\\GianellaClavijo5.csv',
#  'facebook\\extraction-1\\GianellaClavijo6.csv',
#  'facebook\\extraction-1\\GianellaClavijo7.csv',
#  'facebook\\extraction-1\\GianellaClavijo8.csv',
#  'facebook\\extraction-1\\GianellaClavijo9.csv',
#  'facebook\\extraction-1\\Infamus1a19.csv',
#  'facebook\\extraction-1\\Iwo1al21.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides1.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides2.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides3.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides4.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides5.csv',
#  'facebook\\extraction-1\\JBJorgeBenavides6.csv',
#  'facebook\\extraction-1\\JesusAlzamora1.csv',
#  'facebook\\extraction-1\\JesusAlzamora2.csv',
#  'facebook\\extraction-1\\JesusAlzamora3.csv',
#  'facebook\\extraction-1\\JesusAlzamora4.csv',
#  'facebook\\extraction-1\\JesusAlzamora5.csv',
#  'facebook\\extraction-1\\JesusAlzamora6.csv',
#  'facebook\\extraction-1\\JesusAlzamora7.csv',
#  'facebook\\extraction-1\\JesusAlzamora8.csv',
#  'facebook\\extraction-1\\JorgeTalavera1.csv',
#  'facebook\\extraction-1\\JorgeTalavera2.csv',
#  'facebook\\extraction-1\\JorgeTalavera3.csv',
#  'facebook\\extraction-1\\JorgeTalavera4.csv',
#  'facebook\\extraction-1\\JorgeTalavera5.csv',
#  'facebook\\extraction-1\\JorgeTalavera6.csv',
#  'facebook\\extraction-1\\JorgeTalavera7.csv',
#  'facebook\\extraction-1\\JorgeTalavera8.csv',
#  'facebook\\extraction-1\\JorgeTalavera9.csv',
#  'facebook\\extraction-1\\JulianZucchi1.csv',
#  'facebook\\extraction-1\\JulianZucchi2.csv',
#  'facebook\\extraction-1\\JulianZucchi3.csv',
#  'facebook\\extraction-1\\JulianZucchi4.csv',
#  'facebook\\extraction-1\\JulianZucchi5.csv',
#  'facebook\\extraction-1\\LauraSpoya1.csv',
#  'facebook\\extraction-1\\LauraSpoya2.csv',
#  'facebook\\extraction-1\\LauraSpoya3.csv',
#  'facebook\\extraction-1\\LauraSpoya4.csv',
#  'facebook\\extraction-1\\LauraSpoya5.csv',
#  'facebook\\extraction-1\\LucianoMazzetti_01.csv',
#  'facebook\\extraction-1\\LucyWeird1a14.csv',
#  'facebook\\extraction-1\\MarlonMax1a15.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca1.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca10.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca11.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca12.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca2.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca3.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca4.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca5.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca6.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca7.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca8.csv',
#  'facebook\\extraction-1\\MateoGarridoLecca9.csv',
#  'facebook\\extraction-1\\MrChoco1a53.csv',
#  'facebook\\extraction-1\\PhilipChuJoy_01.csv',
#  'facebook\\extraction-1\\Random1.csv',
#  'facebook\\extraction-1\\rebecaScribens1.csv',
#  'facebook\\extraction-1\\RicardoMendoza1a15.csv',
#  'facebook\\extraction-1\\SmashSina1a39.csv',
#  'facebook\\extraction-1\\UmiHyu1a5.csv',
#  'facebook\\extraction-1\\XimenaGaliano1.csv',
#  'facebook\\extraction-1\\XimenaGaliano10.csv',
#  'facebook\\extraction-1\\XimenaGaliano11.csv',
#  'facebook\\extraction-1\\XimenaGaliano12.csv',
#  'facebook\\extraction-1\\XimenaGaliano13.csv',
#  'facebook\\extraction-1\\XimenaGaliano14.csv',
#  'facebook\\extraction-1\\XimenaGaliano15.csv',
#  'facebook\\extraction-1\\XimenaGaliano16.csv',
#  'facebook\\extraction-1\\XimenaGaliano2.csv',
#  'facebook\\extraction-1\\XimenaGaliano3.csv',
#  'facebook\\extraction-1\\XimenaGaliano4.csv',
#  'facebook\\extraction-1\\XimenaGaliano5.csv',
#  'facebook\\extraction-1\\XimenaGaliano6.csv',
#  'facebook\\extraction-1\\XimenaGaliano7.csv',
#  'facebook\\extraction-1\\XimenaGaliano8.csv',
#  'facebook\\extraction-1\\XimenaGaliano9.csv',
#  'facebook\\extraction-2\\Accel_01-09.csv',
#  'facebook\\extraction-2\\AldoCorzo_01.csv',
#  'facebook\\extraction-2\\AleCaminoSmileBaker_01.csv',
#  'facebook\\extraction-2\\AlessandraFuller_01.csv',
#  'facebook\\extraction-2\\AlondraGarciaMiro_01.csv',
#  'facebook\\extraction-2\\Antaurus_01.csv',
#  'facebook\\extraction-2\\Antaurus_02.csv',
#  'facebook\\extraction-2\\Antaurus_03.csv',
#  'facebook\\extraction-2\\Antaurus_04.csv',
#  'facebook\\extraction-2\\Antaurus_05.csv',
#  'facebook\\extraction-2\\AntonellaAservi_01.csv',
#  'facebook\\extraction-2\\AntonellaLeon1.csv',
#  'facebook\\extraction-2\\AntonellaLeon10.csv',
#  'facebook\\extraction-2\\AntonellaLeon11.csv',
#  'facebook\\extraction-2\\AntonellaLeon12.csv',
#  'facebook\\extraction-2\\AntonellaLeon13.csv',
#  'facebook\\extraction-2\\AntonellaLeon14.csv',
#  'facebook\\extraction-2\\AntonellaLeon15.csv',
#  'facebook\\extraction-2\\AntonellaLeon16.csv',
#  'facebook\\extraction-2\\AntonellaLeon17.csv',
#  'facebook\\extraction-2\\AntonellaLeon18.csv',
#  'facebook\\extraction-2\\AntonellaLeon19.csv',
#  'facebook\\extraction-2\\AntonellaLeon2.csv',
#  'facebook\\extraction-2\\AntonellaLeon20.csv',
#  'facebook\\extraction-2\\AntonellaLeon21.csv',
#  'facebook\\extraction-2\\AntonellaLeon3.csv',
#  'facebook\\extraction-2\\AntonellaLeon4.csv',
#  'facebook\\extraction-2\\AntonellaLeon5.csv',
#  'facebook\\extraction-2\\AntonellaLeon6.csv',
#  'facebook\\extraction-2\\AntonellaLeon7.csv',
#  'facebook\\extraction-2\\AntonellaLeon8.csv',
#  'facebook\\extraction-2\\AntonellaLeon9.csv',
#  'facebook\\extraction-2\\BrunoPinasco_01.csv',
#  'facebook\\extraction-2\\ChiaraPinasco_01.csv',
#  'facebook\\extraction-2\\ChinoRisas1.csv',
#  'facebook\\extraction-2\\ChinoRisas2.csv',
#  'facebook\\extraction-2\\ChinoRisas3.csv',
#  'facebook\\extraction-2\\ChinoRisas4.csv',
#  'facebook\\extraction-2\\ChinoRisas5.csv',
#  'facebook\\extraction-2\\ChinoRisas6.csv',
#  'facebook\\extraction-2\\ChinoRisas7.csv',
#  'facebook\\extraction-2\\CinnamonStyle_01.csv',
#  'facebook\\extraction-2\\CristianBravo_01.csv',
#  'facebook\\extraction-2\\CristianBravo_02.csv',
#  'facebook\\extraction-2\\CristianRivero1.csv',
#  'facebook\\extraction-2\\CristianRivero2.csv',
#  'facebook\\extraction-2\\CristianRivero3.csv',
#  'facebook\\extraction-2\\CristianRivero4.csv',
#  'facebook\\extraction-2\\CristianRivero5.csv',
#  'facebook\\extraction-2\\CristianRivero6.csv',
#  'facebook\\extraction-2\\DamianyElToyo1.csv',
#  'facebook\\extraction-2\\DamianyElToyo2.csv',
#  'facebook\\extraction-2\\DamianyElToyo3.csv',
#  'facebook\\extraction-2\\DamianyElToyo4.csv',
#  'facebook\\extraction-2\\DamianyElToyo5.csv',
#  'facebook\\extraction-2\\DamianyElToyo6.csv',
#  'facebook\\extraction-2\\DamianyElToyo7.csv',
#  'facebook\\extraction-2\\DaniellaFernandezVasallo_01.csv',
#  'facebook\\extraction-2\\DiegoRebagliati_01.csv',
#  'facebook\\extraction-2\\ElTankeAriasOficial_01.csv',
#  'facebook\\extraction-2\\ElTankeAriasOficial_02.csv',
#  'facebook\\extraction-2\\EmiliaDrago_01.csv',
#  'facebook\\extraction-2\\ErikOsoresCorreccion_01.csv',
#  'facebook\\extraction-2\\Fashaddicti_01.csv',
#  'facebook\\extraction-2\\FrancoCabrera_01.csv',
#  'facebook\\extraction-2\\FrancoNoriega_01.csv',
#  'facebook\\extraction-2\\GabrielVillaran_01.csv',
#  'facebook\\extraction-2\\GastonAcurio_01.csv',
#  'facebook\\extraction-2\\GastonAcurio_02.csv',
#  'facebook\\extraction-2\\GastonAcurio_03.csv',
#  'facebook\\extraction-2\\GianellaClavijo1.csv',
#  'facebook\\extraction-2\\GianellaClavijo10.csv',
#  'facebook\\extraction-2\\GianellaClavijo11.csv',
#  'facebook\\extraction-2\\GianellaClavijo12.csv',
#  'facebook\\extraction-2\\GianellaClavijo13.csv',
#  'facebook\\extraction-2\\GianellaClavijo14.csv',
#  'facebook\\extraction-2\\GianellaClavijo15.csv',
#  'facebook\\extraction-2\\GianellaClavijo16.csv',
#  'facebook\\extraction-2\\GianellaClavijo17.csv',
#  'facebook\\extraction-2\\GianellaClavijo2.csv',
#  'facebook\\extraction-2\\GianellaClavijo3.csv',
#  'facebook\\extraction-2\\GianellaClavijo4.csv',
#  'facebook\\extraction-2\\GianellaClavijo5.csv',
#  'facebook\\extraction-2\\GianellaClavijo6.csv',
#  'facebook\\extraction-2\\GianellaClavijo7.csv',
#  'facebook\\extraction-2\\GianellaClavijo8.csv',
#  'facebook\\extraction-2\\GianellaClavijo9.csv',
#  'facebook\\extraction-2\\Infamus1a19.csv',
#  'facebook\\extraction-2\\Iwo1al21.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides1.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides2.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides3.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides4.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides5.csv',
#  'facebook\\extraction-2\\JBJorgeBenavides6.csv',
#  'facebook\\extraction-2\\JesusAlzamora1.csv',
#  'facebook\\extraction-2\\JesusAlzamora2.csv',
#  'facebook\\extraction-2\\JesusAlzamora3.csv',
#  'facebook\\extraction-2\\JesusAlzamora4.csv',
#  'facebook\\extraction-2\\JesusAlzamora5.csv',
#  'facebook\\extraction-2\\JesusAlzamora6.csv',
#  'facebook\\extraction-2\\JesusAlzamora7.csv',
#  'facebook\\extraction-2\\JesusAlzamora8.csv',
#  'facebook\\extraction-2\\JorgeTalavera1.csv',
#  'facebook\\extraction-2\\JorgeTalavera2.csv',
#  'facebook\\extraction-2\\JorgeTalavera3.csv',
#  'facebook\\extraction-2\\JorgeTalavera4.csv',
#  'facebook\\extraction-2\\JorgeTalavera5.csv',
#  'facebook\\extraction-2\\JorgeTalavera6.csv',
#  'facebook\\extraction-2\\JorgeTalavera7.csv',
#  'facebook\\extraction-2\\JorgeTalavera8.csv',
#  'facebook\\extraction-2\\JorgeTalavera9.csv',
#  'facebook\\extraction-2\\JulianZucchi1.csv',
#  'facebook\\extraction-2\\JulianZucchi2.csv',
#  'facebook\\extraction-2\\JulianZucchi3.csv',
#  'facebook\\extraction-2\\JulianZucchi4.csv',
#  'facebook\\extraction-2\\JulianZucchi5.csv',
#  'facebook\\extraction-2\\LaEspatulaVerde_01.csv',
#  'facebook\\extraction-2\\LaEspatulaVerde_02.csv',
#  'facebook\\extraction-2\\LaGastronauta_01.csv',
#  'facebook\\extraction-2\\LaTata_01.csv',
#  'facebook\\extraction-2\\LauraSpoya1.csv',
#  'facebook\\extraction-2\\LauraSpoya2.csv',
#  'facebook\\extraction-2\\LauraSpoya3.csv',
#  'facebook\\extraction-2\\LauraSpoya4.csv',
#  'facebook\\extraction-2\\LauraSpoya5.csv',
#  'facebook\\extraction-2\\LuanaBarron_01.csv',
#  'facebook\\extraction-2\\LuchoMedozaJr_01.csv',
#  'facebook\\extraction-2\\LucianaFuster_01.csv',
#  'facebook\\extraction-2\\LucianoMazzetti_01.csv',
#  'facebook\\extraction-2\\LucyWeird1a14.csv',
#  'facebook\\extraction-2\\MadeInPeru_01.csv',
#  'facebook\\extraction-2\\MamiDientes_01.csv',
#  'facebook\\extraction-2\\ManuelaGarridoLecca_01.csv',
#  'facebook\\extraction-2\\MariaPiaCopello_01.csv',
#  'facebook\\extraction-2\\MariaPiaCopello_02.csv',
#  'facebook\\extraction-2\\MariaPiaCopello_03.csv',
#  'facebook\\extraction-2\\MarlonMax1a15.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca1.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca10.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca11.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca12.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca2.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca3.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca4.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca5.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca6.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca7.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca8.csv',
#  'facebook\\extraction-2\\MateoGarridoLecca9.csv',
#  'facebook\\extraction-2\\MichaelSuccar_01.csv',
#  'facebook\\extraction-2\\MitsuharoMaido_01.csv',
#  'facebook\\extraction-2\\MiVidaConMaca_01.csv',
#  'facebook\\extraction-2\\MrChoco1a53.csv',
#  'facebook\\extraction-2\\NataliaMalaga_01.csv',
#  'facebook\\extraction-2\\NataliaMalaga_02.csv',
#  'facebook\\extraction-2\\OnceUponAMom_01.csv',
#  'facebook\\extraction-2\\OscarDelPortalOliveri_01.csv',
#  'facebook\\extraction-2\\OscarDelPortalOliveri_02.csv',
#  'facebook\\extraction-2\\PaolaChiappinaDiPaola_01.csv',
#  'facebook\\extraction-2\\PhilipChuJoy_01.csv',
#  'facebook\\extraction-2\\RaffaellaCamet_01.csv',
#  'facebook\\extraction-2\\Random1.csv',
#  'facebook\\extraction-2\\Random2.csv',
#  'facebook\\extraction-2\\rebecaScribens1.csv',
#  'facebook\\extraction-2\\RicardoMendoza1a15.csv',
#  'facebook\\extraction-2\\SmashSina1a39.csv',
#  'facebook\\extraction-2\\TaliaAzcarate_01.csv',
#  'facebook\\extraction-2\\TwoSidesBlog_01.csv',
#  'facebook\\extraction-2\\UmiHyu1a5.csv',
#  'facebook\\extraction-2\\VanessaTello_01.csv',
#  'facebook\\extraction-2\\Whatthechic_01.csv',
#  'facebook\\extraction-2\\Whatthechic_02.csv',
#  'facebook\\extraction-2\\XimenaGaliano1.csv',
#  'facebook\\extraction-2\\XimenaGaliano10.csv',
#  'facebook\\extraction-2\\XimenaGaliano11.csv',
#  'facebook\\extraction-2\\XimenaGaliano12.csv',
#  'facebook\\extraction-2\\XimenaGaliano13.csv',
#  'facebook\\extraction-2\\XimenaGaliano14.csv',
#  'facebook\\extraction-2\\XimenaGaliano15.csv',
#  'facebook\\extraction-2\\XimenaGaliano16.csv',
#  'facebook\\extraction-2\\XimenaGaliano2.csv',
#  'facebook\\extraction-2\\XimenaGaliano3.csv',
#  'facebook\\extraction-2\\XimenaGaliano4.csv',
#  'facebook\\extraction-2\\XimenaGaliano5.csv',
#  'facebook\\extraction-2\\XimenaGaliano6.csv',
#  'facebook\\extraction-2\\XimenaGaliano7.csv',
#  'facebook\\extraction-2\\XimenaGaliano8.csv',
#  'facebook\\extraction-2\\XimenaGaliano9.csv',
#  'facebook\\extraction-2\\XimenaMoral_01.csv',
#  'facebook\\extraction-2\\YiddaEslava_01.csv',
#  'facebook\\extraction-2\\YiddaEslava_02.csv']

# %%
df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
big_df = pd.concat(df_list, ignore_index=True)
# Out:
# C:\Users\JairL\AppData\Local\Temp\ipykernel_10140\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
df = big_df.dropna(subset=['message'])

# %%
df = df[df['message'].str.len()>15]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1093679 entries, 6 to 1601756
# Data columns (total 11 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   level         1093679 non-null  object
#  1   id            1093679 non-null  object
#  2   parent_id     1093679 non-null  object
#  3   object_id     1093679 non-null  object
#  4   object_type   1093679 non-null  object
#  5   object_key    1093679 non-null  object
#  6   query_status  1093679 non-null  object
#  7   query_time    1093679 non-null  object
#  8   query_type    1093679 non-null  object
#  9   name          0 non-null        object
#  10  message       1093679 non-null  object
# dtypes: object(11)
# memory usage: 100.1+ MB

# %%
df = df.drop_duplicates(subset=['message'], keep='first')

# %%
df
# Out:
#         level     id parent_id        object_id object_type object_key  \
# 6           1     14         2  630750614924803        data     data.*
# 7           1     15         2  630750614924803        data     data.*
# 8           1     16         2  630750614924803        data     data.*
# 10          1     18         2  630750614924803        data     data.*
# 13          1     21         2  630750614924803        data     data.*
# ...       ...    ...       ...              ...         ...        ...
# 1601716     1  18509         3  580243363258960        data     data.*
# 1601737     1  18530         3  580243363258960        data     data.*
# 1601739     1  18532         3  580243363258960        data     data.*
# 1601744     1  18537         3  580243363258960        data     data.*
# 1601756     1  18549         3  580243363258960        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 13       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 1601716  fetched (200)  2023-10-10 22:24:10.746875
# 1601737  fetched (200)  2023-10-10 22:24:11.059672
# 1601739  fetched (200)  2023-10-10 22:24:11.059672
# 1601744  fetched (200)  2023-10-10 22:24:11.059672
# 1601756  fetched (200)  2023-10-10 22:24:11.059672
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 13       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 1601716  Facebook:/<comment-id>/comments  NaN
# 1601737  Facebook:/<comment-id>/comments  NaN
# 1601739  Facebook:/<comment-id>/comments  NaN
# 1601744  Facebook:/<comment-id>/comments  NaN
# 1601756  Facebook:/<comment-id>/comments  NaN
#
#                                                    message
# 6             Las hijas de kingteka tienen buena coreo. GA
# 7                                     estas en pasta causa
# 8        Puedo ver este video un millón de veces y no m...
# 10       Valerie Nj  que fue con tu show? tas facturand...
# 13                                       solo apsa en Perú
# ...                                                    ...
# 1601716                        Edith Ana Quispe  mira esto
# 1601737                                  Saludame ♥️♥️♥️♥️
# 1601739                            Holaa yifda un saludito
# 1601744                      Holiii.. Yo quiero tu libro 😍
# 1601756  Yidda me recomiendas al neurópediatra para la ...
#
# [681221 rows x 11 columns]

# %%
#exclude words
words = ['jaja','jajaja', 'jajajajajajaja','jajajajjajajajaja','Jajajajajajajajaja','jajajaja','jajajajjajajajaja', 'jajajajja','jijiji', 'saludo', 'saluda', 'xd', 'hola', 'zzz']
min_length = 20

def remove_words(text):
    for x in words:
        text = text.lower().replace(x, '')
    if len(text)>min_length:
        return True
    return False

# %%
print(remove_words('Belén Sánchez Castillo jajajajaja'))
# Out:
# True

# %%
df
# Out:
#         level     id parent_id        object_id object_type object_key  \
# 6           1     14         2  630750614924803        data     data.*
# 7           1     15         2  630750614924803        data     data.*
# 8           1     16         2  630750614924803        data     data.*
# 10          1     18         2  630750614924803        data     data.*
# 13          1     21         2  630750614924803        data     data.*
# ...       ...    ...       ...              ...         ...        ...
# 1601716     1  18509         3  580243363258960        data     data.*
# 1601737     1  18530         3  580243363258960        data     data.*
# 1601739     1  18532         3  580243363258960        data     data.*
# 1601744     1  18537         3  580243363258960        data     data.*
# 1601756     1  18549         3  580243363258960        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 13       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 1601716  fetched (200)  2023-10-10 22:24:10.746875
# 1601737  fetched (200)  2023-10-10 22:24:11.059672
# 1601739  fetched (200)  2023-10-10 22:24:11.059672
# 1601744  fetched (200)  2023-10-10 22:24:11.059672
# 1601756  fetched (200)  2023-10-10 22:24:11.059672
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 13       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 1601716  Facebook:/<comment-id>/comments  NaN
# 1601737  Facebook:/<comment-id>/comments  NaN
# 1601739  Facebook:/<comment-id>/comments  NaN
# 1601744  Facebook:/<comment-id>/comments  NaN
# 1601756  Facebook:/<comment-id>/comments  NaN
#
#                                                    message
# 6             Las hijas de kingteka tienen buena coreo. GA
# 7                                     estas en pasta causa
# 8        Puedo ver este video un millón de veces y no m...
# 10       Valerie Nj  que fue con tu show? tas facturand...
# 13                                       solo apsa en Perú
# ...                                                    ...
# 1601716                        Edith Ana Quispe  mira esto
# 1601737                                  Saludame ♥️♥️♥️♥️
# 1601739                            Holaa yifda un saludito
# 1601744                      Holiii.. Yo quiero tu libro 😍
# 1601756  Yidda me recomiendas al neurópediatra para la ...
#
# [681221 rows x 11 columns]

# %%
#remove rows that are too small when excluding the list.
df['valid'] = df['message'].apply(lambda row: remove_words(row))
df
# Out:
#         level     id parent_id        object_id object_type object_key  \
# 6           1     14         2  630750614924803        data     data.*
# 7           1     15         2  630750614924803        data     data.*
# 8           1     16         2  630750614924803        data     data.*
# 10          1     18         2  630750614924803        data     data.*
# 13          1     21         2  630750614924803        data     data.*
# ...       ...    ...       ...              ...         ...        ...
# 1601716     1  18509         3  580243363258960        data     data.*
# 1601737     1  18530         3  580243363258960        data     data.*
# 1601739     1  18532         3  580243363258960        data     data.*
# 1601744     1  18537         3  580243363258960        data     data.*
# 1601756     1  18549         3  580243363258960        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 13       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 1601716  fetched (200)  2023-10-10 22:24:10.746875
# 1601737  fetched (200)  2023-10-10 22:24:11.059672
# 1601739  fetched (200)  2023-10-10 22:24:11.059672
# 1601744  fetched (200)  2023-10-10 22:24:11.059672
# 1601756  fetched (200)  2023-10-10 22:24:11.059672
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 13       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 1601716  Facebook:/<comment-id>/comments  NaN
# 1601737  Facebook:/<comment-id>/comments  NaN
# 1601739  Facebook:/<comment-id>/comments  NaN
# 1601744  Facebook:/<comment-id>/comments  NaN
# 1601756  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   True
# 7                                     estas en pasta causa  False
# 8        Puedo ver este video un millón de veces y no m...   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   True
# 13                                       solo apsa en Perú  False
# ...                                                    ...    ...
# 1601716                        Edith Ana Quispe  mira esto   True
# 1601737                                  Saludame ♥️♥️♥️♥️  False
# 1601739                            Holaa yifda un saludito  False
# 1601744                      Holiii.. Yo quiero tu libro 😍   True
# 1601756  Yidda me recomiendas al neurópediatra para la ...   True
#
# [681221 rows x 12 columns]

# %%
df_false = df[df['valid']== False]
df_false
# Out:
#         level     id parent_id        object_id object_type object_key  \
# 7           1     15         2  630750614924803        data     data.*
# 13          1     21         2  630750614924803        data     data.*
# 25          1     33         2  630750614924803        data     data.*
# 33          1     41         2  630750614924803        data     data.*
# 39          1     47         2  630750614924803        data     data.*
# ...       ...    ...       ...              ...         ...        ...
# 1601704     1  18497         3  580243363258960        data     data.*
# 1601706     1  18499         3  580243363258960        data     data.*
# 1601714     1  18507         3  580243363258960        data     data.*
# 1601737     1  18530         3  580243363258960        data     data.*
# 1601739     1  18532         3  580243363258960        data     data.*
#
#           query_status                  query_time  \
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 13       fetched (200)  2023-10-03 20:29:29.755992
# 25       fetched (200)  2023-10-03 20:29:29.755992
# 33       fetched (200)  2023-10-03 20:29:30.272841
# 39       fetched (200)  2023-10-03 20:29:30.272841
# ...                ...                         ...
# 1601704  fetched (200)  2023-10-10 22:24:10.746875
# 1601706  fetched (200)  2023-10-10 22:24:10.746875
# 1601714  fetched (200)  2023-10-10 22:24:10.746875
# 1601737  fetched (200)  2023-10-10 22:24:11.059672
# 1601739  fetched (200)  2023-10-10 22:24:11.059672
#
#                               query_type name                  message  valid
# 7        Facebook:/<comment-id>/comments  NaN     estas en pasta causa  False
# 13       Facebook:/<comment-id>/comments  NaN        solo apsa en Perú  False
# 25       Facebook:/<comment-id>/comments  NaN       Prende ps MOSCASOR  False
# 33       Facebook:/<comment-id>/comments  NaN      Anderson Lombardixd  False
# 39       Facebook:/<comment-id>/comments  NaN     Adriana Mejia jaaaaa  False
# ...                                  ...  ...                      ...    ...
# 1601704  Facebook:/<comment-id>/comments  NaN     Hola comadre 😄 👑✨💐👋😘  False
# 1601706  Facebook:/<comment-id>/comments  NaN      Holaaaa  lindaaa😍😍😍  False
# 1601714  Facebook:/<comment-id>/comments  NaN    Holaaaaa ❤️❤️❤️❤️❤️❤️  False
# 1601737  Facebook:/<comment-id>/comments  NaN        Saludame ♥️♥️♥️♥️  False
# 1601739  Facebook:/<comment-id>/comments  NaN  Holaa yifda un saludito  False
#
# [115847 rows x 12 columns]

# %%
df =df[df['valid']== True]

# %%
df
# Out:
#         level     id parent_id        object_id object_type object_key  \
# 6           1     14         2  630750614924803        data     data.*
# 8           1     16         2  630750614924803        data     data.*
# 10          1     18         2  630750614924803        data     data.*
# 14          1     22         2  630750614924803        data     data.*
# 15          1     23         2  630750614924803        data     data.*
# ...       ...    ...       ...              ...         ...        ...
# 1601705     1  18498         3  580243363258960        data     data.*
# 1601709     1  18502         3  580243363258960        data     data.*
# 1601716     1  18509         3  580243363258960        data     data.*
# 1601744     1  18537         3  580243363258960        data     data.*
# 1601756     1  18549         3  580243363258960        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# 15       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 1601705  fetched (200)  2023-10-10 22:24:10.746875
# 1601709  fetched (200)  2023-10-10 22:24:10.746875
# 1601716  fetched (200)  2023-10-10 22:24:10.746875
# 1601744  fetched (200)  2023-10-10 22:24:11.059672
# 1601756  fetched (200)  2023-10-10 22:24:11.059672
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# 15       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 1601705  Facebook:/<comment-id>/comments  NaN
# 1601709  Facebook:/<comment-id>/comments  NaN
# 1601716  Facebook:/<comment-id>/comments  NaN
# 1601744  Facebook:/<comment-id>/comments  NaN
# 1601756  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   True
# 8        Puedo ver este video un millón de veces y no m...   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   True
# 14       Dicen que se vió esos pasitos Skeres en el ton...   True
# 15                              Greys Sajami que haces ahí   True
# ...                                                    ...    ...
# 1601705  Hola toda me podrías mandar saludos soy Yarexs...   True
# 1601709                   Desde Argentina un beso te mando   True
# 1601716                        Edith Ana Quispe  mira esto   True
# 1601744                      Holiii.. Yo quiero tu libro 😍   True
# 1601756  Yidda me recomiendas al neurópediatra para la ...   True
#
# [565374 rows x 12 columns]

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565374 entries, 0 to 565373
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         565374 non-null  int64
#  1   level         565374 non-null  object
#  2   id            565374 non-null  object
#  3   parent_id     565374 non-null  object
#  4   object_id     565374 non-null  object
#  5   object_type   565374 non-null  object
#  6   object_key    565374 non-null  object
#  7   query_status  565374 non-null  object
#  8   query_time    565374 non-null  object
#  9   query_type    565374 non-null  object
#  10  name          0 non-null       object
#  11  message       565374 non-null  object
#  12  valid         565374 non-null  bool
# dtypes: bool(1), int64(1), object(11)
# memory usage: 52.3+ MB

# %%
df.sample(30)
# Out:
#           index level     id parent_id          object_id object_type  \
# 319080   723096     1  11131        31    169421651571526        data
# 124025   231893     1  36815        21    613643633303283        data
# 193488   364446     1   1706      1228   2551123125043845        data
# 158499   293437     1   6056      5978    740642803421644        data
# 407429  1002443     1  19894       141   1532409923475770        data
# 510543  1315224     1   7304      5743    900999303984821        data
# 168846   311397     1   8754        17    107174894058988        data
# 520204  1438242     1    651        25  10155180677088470        data
# 435454  1099651     1  14489        27    487823580081505        data
# 176958   325163     1   1111         1   1371947492905264        data
# 263373   499406     1     68         1    885511271624934        data
# 228626   436556     1   2598        17   3539348339679525        data
# 39860     76561     1    371         4   1187071834727002        data
# 273795   513510     1  14172         1    885511271624934        data
# 50354     95049     1   5680        40   1427962047383521        data
# 243751   466517     1  32559        39    295871859624196        data
# 436328  1101332     1  16170        27    487823580081505        data
# 55794    104042     1    870         1   1157451784658852        data
# 544309  1567311     1  17196        44    415179433782631        data
# 556516  1587830     1   4623         1   3190410627909197        data
# 420281  1070846     1   1599         7   2030585993977285        data
# 128400   243050     1   2769         1    294803338490146        data
# 246803   473244     1    714         1    864259313750130        data
# 12934     35952     1   5298        14    318608992496789        data
# 61116    116598     1    138         1    770813240684006        data
# 93490    168787     1     88         1   2575053722793424        data
# 152020   277632     1  18446         1   1693898353972863        data
# 213100   410066     1    323         1    677698826086798        data
# 312706   713729     1   1764         4    738170560675638        data
# 269822   507507     1   8169         1    885511271624934        data
#
#        object_key   query_status                  query_time  \
# 319080     data.*  fetched (200)  2023-10-08 11:35:27.610783
# 124025     data.*  fetched (200)  2023-10-02 21:51:03.011457
# 193488     data.*  fetched (200)  2023-10-04 20:13:57.867581
# 158499     data.*  fetched (200)  2023-10-04 21:24:41.600459
# 407429     data.*  fetched (200)  2023-10-11 22:38:09.692373
# 510543     data.*  fetched (200)  2023-10-08 08:15:58.594548
# 168846     data.*  fetched (200)  2023-10-01 16:40:16.867618
# 520204     data.*  fetched (200)  2023-10-10 22:36:02.883051
# 435454     data.*  fetched (200)  2023-10-10 20:27:37.883070
# 176958     data.*  fetched (200)  2023-10-01 11:46:26.549536
# 263373     data.*  fetched (200)  2023-09-29 15:25:00.036698
# 228626     data.*  fetched (200)  2023-10-01 17:39:16.922002
# 39860      data.*  fetched (200)  2023-10-04 19:25:15.564702
# 273795     data.*  fetched (200)  2023-09-29 15:29:25.115307
# 50354      data.*  fetched (200)  2023-10-05 20:47:09.398217
# 243751     data.*  fetched (200)  2023-10-01 17:47:08.320285
# 436328     data.*  fetched (200)  2023-10-10 20:28:07.351710
# 55794      data.*  fetched (200)  2023-09-25 20:45:19.955974
# 544309     data.*  fetched (200)  2023-10-10 22:12:23.333690
# 556516     data.*  fetched (200)  2023-10-10 22:20:18.608341
# 420281     data.*  fetched (200)  2023-10-10 19:54:40.660374
# 128400     data.*  fetched (200)  2023-09-24 16:40:54.746327
# 246803     data.*  fetched (200)  2023-09-29 15:17:04.459494
# 12934      data.*  fetched (200)  2023-10-03 21:43:23.333709
# 61116      data.*  fetched (200)  2023-09-25 21:27:32.652965
# 93490      data.*  fetched (200)  2023-09-29 17:09:45.758295
# 152020     data.*  fetched (200)  2023-09-28 22:46:27.909020
# 213100     data.*  fetched (200)  2023-10-01 21:40:08.034712
# 312706     data.*  fetched (200)  2023-10-08 11:30:38.629941
# 269822     data.*  fetched (200)  2023-09-29 15:27:28.858811
#
#                              query_type name  \
# 319080  Facebook:/<comment-id>/comments  NaN
# 124025  Facebook:/<comment-id>/comments  NaN
# 193488  Facebook:/<comment-id>/comments  NaN
# 158499  Facebook:/<comment-id>/comments  NaN
# 407429  Facebook:/<comment-id>/comments  NaN
# 510543  Facebook:/<comment-id>/comments  NaN
# 168846  Facebook:/<comment-id>/comments  NaN
# 520204  Facebook:/<comment-id>/comments  NaN
# 435454  Facebook:/<comment-id>/comments  NaN
# 176958     Facebook:/<post-id>/comments  NaN
# 263373     Facebook:/<post-id>/comments  NaN
# 228626  Facebook:/<comment-id>/comments  NaN
# 39860   Facebook:/<comment-id>/comments  NaN
# 273795     Facebook:/<post-id>/comments  NaN
# 50354   Facebook:/<comment-id>/comments  NaN
# 243751  Facebook:/<comment-id>/comments  NaN
# 436328  Facebook:/<comment-id>/comments  NaN
# 55794      Facebook:/<post-id>/comments  NaN
# 544309  Facebook:/<comment-id>/comments  NaN
# 556516  Facebook:/<comment-id>/comments  NaN
# 420281  Facebook:/<comment-id>/comments  NaN
# 128400     Facebook:/<post-id>/comments  NaN
# 246803     Facebook:/<post-id>/comments  NaN
# 12934   Facebook:/<comment-id>/comments  NaN
# 61116      Facebook:/<post-id>/comments  NaN
# 93490      Facebook:/<post-id>/comments  NaN
# 152020     Facebook:/<post-id>/comments  NaN
# 213100  Facebook:/<comment-id>/comments  NaN
# 312706  Facebook:/<comment-id>/comments  NaN
# 269822     Facebook:/<post-id>/comments  NaN
#
#                                                   message  valid
# 319080  Jajja agradecer dice Farfan cuando estaba por ...   True
# 124025  YA IWO YA SABEMOS QUE TU ESTAS DEPOSITANDO MEN...   True
# 193488                              Cómo puedo participar   True
# 158499            Cada día pierdo más la fe en el Perú...   True
# 407429    Si los vi escalando! Fer un trome y nacho tb 😙😙   True
# 510543  Q tal raza q tal raza q tal raza ami nadie me ...   True
# 168846          Victor Manuel Ticona Siempre te pasa bro!   True
# 520204  Feliz dia vanesita que Dios te siga bendiciend...   True
# 435454                          La trilogía de las marías   True
# 176958                         Anderson Benavente Zegarra   True
# 263373                     Cuando tenga auto Diana Blanco   True
# 228626  Ni dendi que es su promoción, ya jubilese pros...   True
# 39860   Perdona si la descongelo una noche antes en el...   True
# 273795                      Miguel Tapia ya no quiero ya😂   True
# 50354                            Felicidades ...lo máximo   True
# 243751           Profe de donde te rebanaste para cocinar   True
# 436328         Jajajajajjaja que linda!!!. Me encanta 😊☺️   True
# 55794   Jaja lo repeti como 10 veces, que divertido er...   True
# 544309  Cuando lo sorprendo con un baile sensual…… lo ...   True
# 556516                          Alejandro Becerra Tasayco   True
# 420281             Linda actuación María Pía te felicito.   True
# 128400         Aron Nicolas Mora Morante Alessandro Costa   True
# 246803  Diana Tatiana Ubillus Abad jajajaja tú de comp...   True
# 12934        Holaaa Dejen de molestar ala chica.  Trotel    True
# 61116   Xdddd que sería que se encuentre un loco de ve...   True
# 93490   Jajaja Juli Ayala  nose cual seria si fuese asi 🤣   True
# 152020                          😂😂😂 David Montero Hurtado   True
# 213100                          Alexander hahahhahahahaha   True
# 312706                    Arturo vidal lo celebro 😀😀😀....   True
# 269822  Jajajajajajajajaja ptm .... Lefteris Ch tu que...   True

# %%
#https://towardsdatascience.com/emojis-aid-social-media-sentiment-analysis-stop-cleaning-them-out-bb32a1e5fc8e
