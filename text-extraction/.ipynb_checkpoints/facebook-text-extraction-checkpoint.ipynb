# %%
import sys
import pandas as pd 
import os 
import glob

# %%
csv_files = glob.glob(os.path.join(r"facebook/extraction-*/", "*.csv"))

# %%
df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
big_df = pd.concat(df_list, ignore_index=True)

# %%
df = big_df.dropna(subset=['message'])

# %%
df = df[df['message'].str.len()>15]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 385569 entries, 6 to 557999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   level         385569 non-null  object
#  1   id            385569 non-null  object
#  2   parent_id     385569 non-null  object
#  3   object_id     385569 non-null  object
#  4   object_type   385569 non-null  object
#  5   object_key    385569 non-null  object
#  6   query_status  385569 non-null  object
#  7   query_time    385569 non-null  object
#  8   query_type    385569 non-null  object
#  9   name          0 non-null       object
#  10  message       385569 non-null  object
# dtypes: object(11)
# memory usage: 35.3+ MB

# %%
df = df.drop_duplicates(subset=['message'], keep='first')

# %%
df
# Out:
#        level    id parent_id         object_id object_type object_key  \
# 6          1    14         2   630750614924803        data     data.*
# 7          1    15         2   630750614924803        data     data.*
# 8          1    16         2   630750614924803        data     data.*
# 10         1    18         2   630750614924803        data     data.*
# 13         1    21         2   630750614924803        data     data.*
# ...      ...   ...       ...               ...         ...        ...
# 557995     1  4435         1  1628545270582504        data     data.*
# 557996     1  4436         1  1628545270582504        data     data.*
# 557997     1  4437         1  1628545270582504        data     data.*
# 557998     1  4438         1  1628545270582504        data     data.*
# 557999     1  4439         1  1628545270582504        data     data.*
#
#          query_status                  query_time  \
# 6       fetched (200)  2023-10-03 20:29:29.755992
# 7       fetched (200)  2023-10-03 20:29:29.755992
# 8       fetched (200)  2023-10-03 20:29:29.755992
# 10      fetched (200)  2023-10-03 20:29:29.755992
# 13      fetched (200)  2023-10-03 20:29:29.755992
# ...               ...                         ...
# 557995  fetched (200)  2023-09-29 15:58:11.142217
# 557996  fetched (200)  2023-09-29 15:58:11.142217
# 557997  fetched (200)  2023-09-29 15:58:11.142217
# 557998  fetched (200)  2023-09-29 15:58:11.142217
# 557999  fetched (200)  2023-09-29 15:58:11.142217
#
#                              query_type name  \
# 6       Facebook:/<comment-id>/comments  NaN
# 7       Facebook:/<comment-id>/comments  NaN
# 8       Facebook:/<comment-id>/comments  NaN
# 10      Facebook:/<comment-id>/comments  NaN
# 13      Facebook:/<comment-id>/comments  NaN
# ...                                 ...  ...
# 557995     Facebook:/<post-id>/comments  NaN
# 557996     Facebook:/<post-id>/comments  NaN
# 557997     Facebook:/<post-id>/comments  NaN
# 557998     Facebook:/<post-id>/comments  NaN
# 557999     Facebook:/<post-id>/comments  NaN
#
#                                                   message
# 6            Las hijas de kingteka tienen buena coreo. GA
# 7                                    estas en pasta causa
# 8       Puedo ver este video un millón de veces y no m...
# 10      Valerie Nj  que fue con tu show? tas facturand...
# 13                                      solo apsa en Perú
# ...                                                   ...
# 557995                    Alondra Aguilar Caldas xdeeeeee
# 557996                         Karina Canelo me escuchas?
# 557997                     Williams el fantasma del ex XD
# 557998       Jonatan Ferre Verastegui reacciona basura :v
# 557999  Karen Tatiana jajajajajajaja esto se gana su o...
#
# [369623 rows x 11 columns]

# %%
#exclude words
words = ['jaja','jajaja', 'jajajajajajaja','jajajajjajajajaja','Jajajajajajajajaja','jajajaja','jajajajjajajajaja', 'jajajajja','jijiji', 'saludo', 'saluda', 'xd', 'hola', 'zzz']
min_length = 20

def remove_words(text):
    for x in words:
        text = text.lower().replace(x, '')
    if len(text)>min_length:
        return True
    return False

# %%
print(remove_words('Belén Sánchez Castillo jajajajaja'))
# Out:
# True

# %%
df
# Out:
#        level    id parent_id         object_id object_type object_key  \
# 6          1    14         2   630750614924803        data     data.*
# 7          1    15         2   630750614924803        data     data.*
# 8          1    16         2   630750614924803        data     data.*
# 10         1    18         2   630750614924803        data     data.*
# 13         1    21         2   630750614924803        data     data.*
# ...      ...   ...       ...               ...         ...        ...
# 557995     1  4435         1  1628545270582504        data     data.*
# 557996     1  4436         1  1628545270582504        data     data.*
# 557997     1  4437         1  1628545270582504        data     data.*
# 557998     1  4438         1  1628545270582504        data     data.*
# 557999     1  4439         1  1628545270582504        data     data.*
#
#          query_status                  query_time  \
# 6       fetched (200)  2023-10-03 20:29:29.755992
# 7       fetched (200)  2023-10-03 20:29:29.755992
# 8       fetched (200)  2023-10-03 20:29:29.755992
# 10      fetched (200)  2023-10-03 20:29:29.755992
# 13      fetched (200)  2023-10-03 20:29:29.755992
# ...               ...                         ...
# 557995  fetched (200)  2023-09-29 15:58:11.142217
# 557996  fetched (200)  2023-09-29 15:58:11.142217
# 557997  fetched (200)  2023-09-29 15:58:11.142217
# 557998  fetched (200)  2023-09-29 15:58:11.142217
# 557999  fetched (200)  2023-09-29 15:58:11.142217
#
#                              query_type name  \
# 6       Facebook:/<comment-id>/comments  NaN
# 7       Facebook:/<comment-id>/comments  NaN
# 8       Facebook:/<comment-id>/comments  NaN
# 10      Facebook:/<comment-id>/comments  NaN
# 13      Facebook:/<comment-id>/comments  NaN
# ...                                 ...  ...
# 557995     Facebook:/<post-id>/comments  NaN
# 557996     Facebook:/<post-id>/comments  NaN
# 557997     Facebook:/<post-id>/comments  NaN
# 557998     Facebook:/<post-id>/comments  NaN
# 557999     Facebook:/<post-id>/comments  NaN
#
#                                                   message
# 6            Las hijas de kingteka tienen buena coreo. GA
# 7                                    estas en pasta causa
# 8       Puedo ver este video un millón de veces y no m...
# 10      Valerie Nj  que fue con tu show? tas facturand...
# 13                                      solo apsa en Perú
# ...                                                   ...
# 557995                    Alondra Aguilar Caldas xdeeeeee
# 557996                         Karina Canelo me escuchas?
# 557997                     Williams el fantasma del ex XD
# 557998       Jonatan Ferre Verastegui reacciona basura :v
# 557999  Karen Tatiana jajajajajajaja esto se gana su o...
#
# [369623 rows x 11 columns]

# %%
#remove rows that are too small when excluding the list.
df['valid'] = df['message'].apply(lambda row: remove_words(row))
df
# Out:
#        level    id parent_id         object_id object_type object_key  \
# 6          1    14         2   630750614924803        data     data.*
# 7          1    15         2   630750614924803        data     data.*
# 8          1    16         2   630750614924803        data     data.*
# 10         1    18         2   630750614924803        data     data.*
# 13         1    21         2   630750614924803        data     data.*
# ...      ...   ...       ...               ...         ...        ...
# 557995     1  4435         1  1628545270582504        data     data.*
# 557996     1  4436         1  1628545270582504        data     data.*
# 557997     1  4437         1  1628545270582504        data     data.*
# 557998     1  4438         1  1628545270582504        data     data.*
# 557999     1  4439         1  1628545270582504        data     data.*
#
#          query_status                  query_time  \
# 6       fetched (200)  2023-10-03 20:29:29.755992
# 7       fetched (200)  2023-10-03 20:29:29.755992
# 8       fetched (200)  2023-10-03 20:29:29.755992
# 10      fetched (200)  2023-10-03 20:29:29.755992
# 13      fetched (200)  2023-10-03 20:29:29.755992
# ...               ...                         ...
# 557995  fetched (200)  2023-09-29 15:58:11.142217
# 557996  fetched (200)  2023-09-29 15:58:11.142217
# 557997  fetched (200)  2023-09-29 15:58:11.142217
# 557998  fetched (200)  2023-09-29 15:58:11.142217
# 557999  fetched (200)  2023-09-29 15:58:11.142217
#
#                              query_type name  \
# 6       Facebook:/<comment-id>/comments  NaN
# 7       Facebook:/<comment-id>/comments  NaN
# 8       Facebook:/<comment-id>/comments  NaN
# 10      Facebook:/<comment-id>/comments  NaN
# 13      Facebook:/<comment-id>/comments  NaN
# ...                                 ...  ...
# 557995     Facebook:/<post-id>/comments  NaN
# 557996     Facebook:/<post-id>/comments  NaN
# 557997     Facebook:/<post-id>/comments  NaN
# 557998     Facebook:/<post-id>/comments  NaN
# 557999     Facebook:/<post-id>/comments  NaN
#
#                                                   message  valid
# 6            Las hijas de kingteka tienen buena coreo. GA   True
# 7                                    estas en pasta causa  False
# 8       Puedo ver este video un millón de veces y no m...   True
# 10      Valerie Nj  que fue con tu show? tas facturand...   True
# 13                                      solo apsa en Perú  False
# ...                                                   ...    ...
# 557995                    Alondra Aguilar Caldas xdeeeeee   True
# 557996                         Karina Canelo me escuchas?   True
# 557997                     Williams el fantasma del ex XD   True
# 557998       Jonatan Ferre Verastegui reacciona basura :v   True
# 557999  Karen Tatiana jajajajajajaja esto se gana su o...   True
#
# [369623 rows x 12 columns]

# %%
df_false = df[df['valid']== False]
df_false
# Out:
#        level    id parent_id         object_id object_type object_key  \
# 7          1    15         2   630750614924803        data     data.*
# 13         1    21         2   630750614924803        data     data.*
# 25         1    33         2   630750614924803        data     data.*
# 33         1    41         2   630750614924803        data     data.*
# 39         1    47         2   630750614924803        data     data.*
# ...      ...   ...       ...               ...         ...        ...
# 557970     1  4410         1  1628545270582504        data     data.*
# 557984     1  4424         1  1628545270582504        data     data.*
# 557985     1  4425         1  1628545270582504        data     data.*
# 557986     1  4426         1  1628545270582504        data     data.*
# 557993     1  4433         1  1628545270582504        data     data.*
#
#          query_status                  query_time  \
# 7       fetched (200)  2023-10-03 20:29:29.755992
# 13      fetched (200)  2023-10-03 20:29:29.755992
# 25      fetched (200)  2023-10-03 20:29:29.755992
# 33      fetched (200)  2023-10-03 20:29:30.272841
# 39      fetched (200)  2023-10-03 20:29:30.272841
# ...               ...                         ...
# 557970  fetched (200)  2023-09-29 15:58:11.142217
# 557984  fetched (200)  2023-09-29 15:58:11.142217
# 557985  fetched (200)  2023-09-29 15:58:11.142217
# 557986  fetched (200)  2023-09-29 15:58:11.142217
# 557993  fetched (200)  2023-09-29 15:58:11.142217
#
#                              query_type name  \
# 7       Facebook:/<comment-id>/comments  NaN
# 13      Facebook:/<comment-id>/comments  NaN
# 25      Facebook:/<comment-id>/comments  NaN
# 33      Facebook:/<comment-id>/comments  NaN
# 39      Facebook:/<comment-id>/comments  NaN
# ...                                 ...  ...
# 557970     Facebook:/<post-id>/comments  NaN
# 557984     Facebook:/<post-id>/comments  NaN
# 557985     Facebook:/<post-id>/comments  NaN
# 557986     Facebook:/<post-id>/comments  NaN
# 557993     Facebook:/<post-id>/comments  NaN
#
#                                                   message  valid
# 7                                    estas en pasta causa  False
# 13                                      solo apsa en Perú  False
# 25                                     Prende ps MOSCASOR  False
# 33                                    Anderson Lombardixd  False
# 39                                   Adriana Mejia jaaaaa  False
# ...                                                   ...    ...
# 557970                               Frank Barja Valdivia  False
# 557984                              Yaki Lyu ajjajajajaja  False
# 557985  JAJAJAJAJJAJAJAJAJAJAJAJJAJAJAJAJAJAJAJAJAJAJA...  False
# 557986                               Mayra Aracelli Taron  False
# 557993                              Alejandro Sosa JAJAJA  False
#
# [69340 rows x 12 columns]

# %%
df =df[df['valid']== True]

# %%
df
# Out:
#        level    id parent_id         object_id object_type object_key  \
# 6          1    14         2   630750614924803        data     data.*
# 8          1    16         2   630750614924803        data     data.*
# 10         1    18         2   630750614924803        data     data.*
# 14         1    22         2   630750614924803        data     data.*
# 15         1    23         2   630750614924803        data     data.*
# ...      ...   ...       ...               ...         ...        ...
# 557995     1  4435         1  1628545270582504        data     data.*
# 557996     1  4436         1  1628545270582504        data     data.*
# 557997     1  4437         1  1628545270582504        data     data.*
# 557998     1  4438         1  1628545270582504        data     data.*
# 557999     1  4439         1  1628545270582504        data     data.*
#
#          query_status                  query_time  \
# 6       fetched (200)  2023-10-03 20:29:29.755992
# 8       fetched (200)  2023-10-03 20:29:29.755992
# 10      fetched (200)  2023-10-03 20:29:29.755992
# 14      fetched (200)  2023-10-03 20:29:29.755992
# 15      fetched (200)  2023-10-03 20:29:29.755992
# ...               ...                         ...
# 557995  fetched (200)  2023-09-29 15:58:11.142217
# 557996  fetched (200)  2023-09-29 15:58:11.142217
# 557997  fetched (200)  2023-09-29 15:58:11.142217
# 557998  fetched (200)  2023-09-29 15:58:11.142217
# 557999  fetched (200)  2023-09-29 15:58:11.142217
#
#                              query_type name  \
# 6       Facebook:/<comment-id>/comments  NaN
# 8       Facebook:/<comment-id>/comments  NaN
# 10      Facebook:/<comment-id>/comments  NaN
# 14      Facebook:/<comment-id>/comments  NaN
# 15      Facebook:/<comment-id>/comments  NaN
# ...                                 ...  ...
# 557995     Facebook:/<post-id>/comments  NaN
# 557996     Facebook:/<post-id>/comments  NaN
# 557997     Facebook:/<post-id>/comments  NaN
# 557998     Facebook:/<post-id>/comments  NaN
# 557999     Facebook:/<post-id>/comments  NaN
#
#                                                   message  valid
# 6            Las hijas de kingteka tienen buena coreo. GA   True
# 8       Puedo ver este video un millón de veces y no m...   True
# 10      Valerie Nj  que fue con tu show? tas facturand...   True
# 14      Dicen que se vió esos pasitos Skeres en el ton...   True
# 15                             Greys Sajami que haces ahí   True
# ...                                                   ...    ...
# 557995                    Alondra Aguilar Caldas xdeeeeee   True
# 557996                         Karina Canelo me escuchas?   True
# 557997                     Williams el fantasma del ex XD   True
# 557998       Jonatan Ferre Verastegui reacciona basura :v   True
# 557999  Karen Tatiana jajajajajajaja esto se gana su o...   True
#
# [300283 rows x 12 columns]

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300283 entries, 0 to 300282
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         300283 non-null  int64
#  1   level         300283 non-null  object
#  2   id            300283 non-null  object
#  3   parent_id     300283 non-null  object
#  4   object_id     300283 non-null  object
#  5   object_type   300283 non-null  object
#  6   object_key    300283 non-null  object
#  7   query_status  300283 non-null  object
#  8   query_time    300283 non-null  object
#  9   query_type    300283 non-null  object
#  10  name          0 non-null       object
#  11  message       300283 non-null  object
#  12  valid         300283 non-null  bool
# dtypes: bool(1), int64(1), object(11)
# memory usage: 27.8+ MB

# %%
df.sample(30)
# Out:
#          index level     id parent_id          object_id object_type  \
# 298802  555260     1   1700         1   1628545270582504        data
# 60898   115422     1  12250         1   1157451784658852        data
# 217365  415327     1   5584         5    526474777813957        data
# 43240    81982     1    347         1    612959580735330        data
# 15136    39013     1   1467         1   1875520425853885        data
# 250171  475501     1   2971         1    864259313750130        data
# 126085  236612     1  41534        21    613643633303283        data
# 179156  326849     1   1189         1   1332004113566269        data
# 239193  454049     1  20091        31   1337645530164864        data
# 99690   177302     1   3340         1   2334818063253175        data
# 14507    38273     1    727         1   1875520425853885        data
# 145214  265500     1   6314         1   1693898353972863        data
# 11045    31375     1    721         7   1648975761968217        data
# 4652     11549     1  10754        30   4439348062821112        data
# 165899  304700     1   2057         7    413246616663058        data
# 20937    47940     1    575         1   1794688017270460        data
# 249313  474358     1   1828         1    864259313750130        data
# 183335  335430     1   3158        13    337720931932166        data
# 2067      6006     1   5211        21    667793451045826        data
# 64533   121178     1   1313         1    779267716640417        data
# 48266    90912     1   1543        13    300020484393831        data
# 87855   158328     1  18561        29  10154064221328130        data
# 158406  290810     1   3429         5    440517183577304        data
# 197383  372402     1   9662      7636   1300726950551350        data
# 70693   131631     1   6890        22    177418586902052        data
# 100462  178983     1   5021         1   2334818063253175        data
# 6663     16581     1   4067         1    933348817255912        data
# 101041  179785     1    368         1   2410449119203551        data
# 297626  553556     1   1595         1    236451993887837        data
# 98876   175786     1   1824         1   2334818063253175        data
#
#        object_key   query_status                  query_time  \
# 298802     data.*  fetched (200)  2023-09-29 15:57:21.349021
# 60898      data.*  fetched (200)  2023-09-25 20:49:46.817683
# 217365     data.*  fetched (200)  2023-10-01 21:41:27.267309
# 43240      data.*  fetched (200)  2023-09-25 21:51:14.211031
# 15136      data.*  fetched (200)  2023-10-01 16:00:22.706592
# 250171     data.*  fetched (200)  2023-09-29 15:17:47.052742
# 126085     data.*  fetched (200)  2023-10-02 21:57:15.749883
# 179156     data.*  fetched (200)  2023-10-01 11:51:08.820100
# 239193     data.*  fetched (200)  2023-10-01 17:43:48.322904
# 99690      data.*  fetched (200)  2023-09-29 16:48:04.446379
# 14507      data.*  fetched (200)  2023-10-01 16:00:07.423096
# 145214     data.*  fetched (200)  2023-09-28 22:42:59.910759
# 11045      data.*  fetched (200)  2023-10-03 21:42:10.840044
# 4652       data.*  fetched (200)  2023-10-03 20:52:00.086758
# 165899     data.*  fetched (200)  2023-10-01 16:38:27.911505
# 20937      data.*  fetched (200)  2023-10-01 16:05:33.901645
# 249313     data.*  fetched (200)  2023-09-29 15:17:25.387908
# 183335     data.*  fetched (200)  2023-10-01 18:08:22.756985
# 2067       data.*  fetched (200)  2023-10-03 20:50:37.960731
# 64533      data.*  fetched (200)  2023-09-25 21:40:58.321378
# 48266      data.*  fetched (200)  2023-10-05 20:45:53.404170
# 87855      data.*  fetched (200)  2023-10-05 20:25:24.678035
# 158406     data.*  fetched (200)  2023-10-04 21:14:12.260673
# 197383     data.*  fetched (200)  2023-10-04 20:19:48.772769
# 70693      data.*  fetched (200)  2023-10-05 20:01:11.008694
# 100462     data.*  fetched (200)  2023-09-29 16:48:29.594890
# 6663       data.*  fetched (200)  2023-10-03 20:58:56.737242
# 101041     data.*  fetched (200)  2023-09-29 16:49:47.240024
# 297626     data.*  fetched (200)  2023-09-29 15:56:03.395551
# 98876      data.*  fetched (200)  2023-09-29 16:47:40.313789
#
#                              query_type name  \
# 298802     Facebook:/<post-id>/comments  NaN
# 60898      Facebook:/<post-id>/comments  NaN
# 217365  Facebook:/<comment-id>/comments  NaN
# 43240      Facebook:/<post-id>/comments  NaN
# 15136   Facebook:/<comment-id>/comments  NaN
# 250171     Facebook:/<post-id>/comments  NaN
# 126085  Facebook:/<comment-id>/comments  NaN
# 179156     Facebook:/<post-id>/comments  NaN
# 239193  Facebook:/<comment-id>/comments  NaN
# 99690      Facebook:/<post-id>/comments  NaN
# 14507   Facebook:/<comment-id>/comments  NaN
# 145214     Facebook:/<post-id>/comments  NaN
# 11045   Facebook:/<comment-id>/comments  NaN
# 4652    Facebook:/<comment-id>/comments  NaN
# 165899  Facebook:/<comment-id>/comments  NaN
# 20937   Facebook:/<comment-id>/comments  NaN
# 249313     Facebook:/<post-id>/comments  NaN
# 183335  Facebook:/<comment-id>/comments  NaN
# 2067    Facebook:/<comment-id>/comments  NaN
# 64533      Facebook:/<post-id>/comments  NaN
# 48266   Facebook:/<comment-id>/comments  NaN
# 87855   Facebook:/<comment-id>/comments  NaN
# 158406  Facebook:/<comment-id>/comments  NaN
# 197383  Facebook:/<comment-id>/comments  NaN
# 70693   Facebook:/<comment-id>/comments  NaN
# 100462     Facebook:/<post-id>/comments  NaN
# 6663    Facebook:/<comment-id>/comments  NaN
# 101041     Facebook:/<post-id>/comments  NaN
# 297626     Facebook:/<post-id>/comments  NaN
# 98876      Facebook:/<post-id>/comments  NaN
#
#                                                   message  valid
# 298802                      Nicolás Mattos ya superala :v   True
# 60898                          Bien merecido a esa odiosa   True
# 217365  Se estrena en tu cumple Mi pequeña Marilyn Rivera   True
# 43240   Otra yarusi, espero que la gente no compre sus...   True
# 15136                  Así te imagino Gabriela Onque 😏😎 😂   True
# 250171                        Iván Pozo JAJAJAJAJA HOY 😳😳   True
# 126085                           MADAROID FUE MAS CABEZON   True
# 179156                              Allison Noblega Lovón   True
# 239193                 1 hora hablando de parche agg safo   True
# 99690   Diana Soto  Angie Martinez Becerra Sólo miren ...   True
# 14507              Andrea jajajaja asiii tiene que ser 😂😂   True
# 145214                           Juan Gillary Gutiérrez 😒   True
# 11045                 Hola vamos a bajar de Peso xd jajaj   True
# 4652    es porque la gente tiene cultura del facebook ...   True
# 165899  Danniel Benites Mansilla agradece que juego co...   True
# 20937   Definitivamente cuando dormimos juntas Crisbe ...   True
# 249313           Carolina Andrade mi amooo par su vestido   True
# 183335  Impe Que perfume puedo ponerme para ver las pa...   True
# 2067              Cerveza de queeee????? DE RANA PES FINO   True
# 64533                       Los limeños antiracistas?? 🙂🧐   True
# 48266                               Mejor papá nativas ..   True
# 87855   Me encanta todo lo que haces  ;gracias por com...   True
# 158406                              Cristina Quispe Rosas   True
# 197383                           Ya empezó mi novela jaja   True
# 70693                               Excelente propuesta 🤩   True
# 100462                              Alexander Farroñay😐😳🤣   True
# 6663                         micro abierto como tu potito   True
# 101041             Jannet Liz Sun Yomira Fernanda Cruz 🤣🤣   True
# 297626                          Durand S. Katherine xdddd   True
# 98876          Stefano yara mano ahora todo tiene sentido   True
