# %%
import sys
import pandas as pd 
import os 
import glob

# %%
MIN_CHAR_LENGHT = 20

# %%
csv_files = glob.glob(os.path.join(r"facebook/extraction-*/", "*.csv"))

# %%
#csv_files

# %%
df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
big_df = pd.concat(df_list, ignore_index=True)
# Out:
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)
# C:\Users\JairL\AppData\Local\Temp\ipykernel_46376\1999715855.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
df = big_df.dropna(subset=['message'])

# %%
df = df[df['message'].str.len()>=MIN_CHAR_LENGHT]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2985229 entries, 6 to 4966403
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   level         object
#  1   id            object
#  2   parent_id     object
#  3   object_id     object
#  4   object_type   object
#  5   object_key    object
#  6   query_status  object
#  7   query_time    object
#  8   query_type    object
#  9   name          object
#  10  message       object
#  11  path          float64
# dtypes: float64(1), object(11)
# memory usage: 296.1+ MB

# %%
df = df.drop_duplicates(subset=['message'], keep='first')

# %%
df
# Out:
#         level    id parent_id         object_id object_type object_key  \
# 6           1    14         2   630750614924803        data     data.*
# 7           1    15         2   630750614924803        data     data.*
# 8           1    16         2   630750614924803        data     data.*
# 10          1    18         2   630750614924803        data     data.*
# 14          1    22         2   630750614924803        data     data.*
# ...       ...   ...       ...               ...         ...        ...
# 4804475     1  8384         1  1487688164660839        data     data.*
# 4804481     1  8390         1  1487688164660839        data     data.*
# 4804486     1  8395         1  1487688164660839        data     data.*
# 4804487     1  8396         1  1487688164660839        data     data.*
# 4804489     1  8398         1  1487688164660839        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 4804475  fetched (200)  2023-10-14 21:56:23.810546
# 4804481  fetched (200)  2023-10-14 21:56:23.810546
# 4804486  fetched (200)  2023-10-14 21:56:23.810546
# 4804487  fetched (200)  2023-10-14 21:56:23.810546
# 4804489  fetched (200)  2023-10-14 21:56:23.810546
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 4804475  Facebook:/<comment-id>/comments  NaN
# 4804481  Facebook:/<comment-id>/comments  NaN
# 4804486  Facebook:/<comment-id>/comments  NaN
# 4804487  Facebook:/<comment-id>/comments  NaN
# 4804489  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN
# 7                                     estas en pasta causa   NaN
# 8        Puedo ver este video un millón de veces y no m...   NaN
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN
# ...                                                    ...   ...
# 4804475                             Silvia Palza Malabrigo   NaN
# 4804481                     Bruno Cafferata Elsa Castañeda   NaN
# 4804486    Marilyn L. Ticona atenti a esto y yo también. 😁   NaN
# 4804487  Itala Katherine Mendoza  es a él a quién le vi...   NaN
# 4804489                  William Zavaleta Garcia así pls 🙏   NaN
#
# [1942498 rows x 12 columns]

# %%
#exclude words
words = ['jaja','jajaja', 'jajajajajajja', 'jajajajajajaja','jajajajjajajajaja','Jajajajajajajajaja','jajajaja','jajajajjajajajaja', 'jajajajja','jijiji', 'saludo', 'saluda', 'xd', 'hola', 'zzz']
def remove_words(text):
    for x in words:
        text = text.lower().replace(x, '')
    if len(text)>=MIN_CHAR_LENGHT:
        return True
    return False

# %%
print(remove_words('Belén Sánchez Castillo jajajajaja'))
# Out:
# True

# %%
df
# Out:
#         level    id parent_id         object_id object_type object_key  \
# 6           1    14         2   630750614924803        data     data.*
# 7           1    15         2   630750614924803        data     data.*
# 8           1    16         2   630750614924803        data     data.*
# 10          1    18         2   630750614924803        data     data.*
# 14          1    22         2   630750614924803        data     data.*
# ...       ...   ...       ...               ...         ...        ...
# 4804475     1  8384         1  1487688164660839        data     data.*
# 4804481     1  8390         1  1487688164660839        data     data.*
# 4804486     1  8395         1  1487688164660839        data     data.*
# 4804487     1  8396         1  1487688164660839        data     data.*
# 4804489     1  8398         1  1487688164660839        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 4804475  fetched (200)  2023-10-14 21:56:23.810546
# 4804481  fetched (200)  2023-10-14 21:56:23.810546
# 4804486  fetched (200)  2023-10-14 21:56:23.810546
# 4804487  fetched (200)  2023-10-14 21:56:23.810546
# 4804489  fetched (200)  2023-10-14 21:56:23.810546
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 4804475  Facebook:/<comment-id>/comments  NaN
# 4804481  Facebook:/<comment-id>/comments  NaN
# 4804486  Facebook:/<comment-id>/comments  NaN
# 4804487  Facebook:/<comment-id>/comments  NaN
# 4804489  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN
# 7                                     estas en pasta causa   NaN
# 8        Puedo ver este video un millón de veces y no m...   NaN
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN
# ...                                                    ...   ...
# 4804475                             Silvia Palza Malabrigo   NaN
# 4804481                     Bruno Cafferata Elsa Castañeda   NaN
# 4804486    Marilyn L. Ticona atenti a esto y yo también. 😁   NaN
# 4804487  Itala Katherine Mendoza  es a él a quién le vi...   NaN
# 4804489                  William Zavaleta Garcia así pls 🙏   NaN
#
# [1942498 rows x 12 columns]

# %%
#remove rows that are too small when excluding the list.
df['valid'] = df['message'].apply(lambda row: remove_words(row))
df
# Out:
#         level    id parent_id         object_id object_type object_key  \
# 6           1    14         2   630750614924803        data     data.*
# 7           1    15         2   630750614924803        data     data.*
# 8           1    16         2   630750614924803        data     data.*
# 10          1    18         2   630750614924803        data     data.*
# 14          1    22         2   630750614924803        data     data.*
# ...       ...   ...       ...               ...         ...        ...
# 4804475     1  8384         1  1487688164660839        data     data.*
# 4804481     1  8390         1  1487688164660839        data     data.*
# 4804486     1  8395         1  1487688164660839        data     data.*
# 4804487     1  8396         1  1487688164660839        data     data.*
# 4804489     1  8398         1  1487688164660839        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 4804475  fetched (200)  2023-10-14 21:56:23.810546
# 4804481  fetched (200)  2023-10-14 21:56:23.810546
# 4804486  fetched (200)  2023-10-14 21:56:23.810546
# 4804487  fetched (200)  2023-10-14 21:56:23.810546
# 4804489  fetched (200)  2023-10-14 21:56:23.810546
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 4804475  Facebook:/<comment-id>/comments  NaN
# 4804481  Facebook:/<comment-id>/comments  NaN
# 4804486  Facebook:/<comment-id>/comments  NaN
# 4804487  Facebook:/<comment-id>/comments  NaN
# 4804489  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN   True
# 7                                     estas en pasta causa   NaN   True
# 8        Puedo ver este video un millón de veces y no m...   NaN   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN   True
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN   True
# ...                                                    ...   ...    ...
# 4804475                             Silvia Palza Malabrigo   NaN   True
# 4804481                     Bruno Cafferata Elsa Castañeda   NaN   True
# 4804486    Marilyn L. Ticona atenti a esto y yo también. 😁   NaN   True
# 4804487  Itala Katherine Mendoza  es a él a quién le vi...   NaN   True
# 4804489                  William Zavaleta Garcia así pls 🙏   NaN   True
#
# [1942498 rows x 13 columns]

# %%
df_false = df[df['valid']== False]
df_false
# Out:
#         level    id parent_id         object_id object_type object_key  \
# 106         1   114         3  3963455660362592        data     data.*
# 339         1   349         7   372233297036050        data     data.*
# 355         1   365         7   372233297036050        data     data.*
# 444         1   454         7   372233297036050        data     data.*
# 465         1   475         7   372233297036050        data     data.*
# ...       ...   ...       ...               ...         ...        ...
# 4799661     1  3570         1  1487688164660839        data     data.*
# 4800915     1  4824         1  1487688164660839        data     data.*
# 4800975     1  4884         1  1487688164660839        data     data.*
# 4801313     1  5222         1  1487688164660839        data     data.*
# 4804171     1  8080         1  1487688164660839        data     data.*
#
#           query_status                  query_time  \
# 106      fetched (200)  2023-10-03 20:29:35.809339
# 339      fetched (200)  2023-10-03 20:30:15.129249
# 355      fetched (200)  2023-10-03 20:30:15.537832
# 444      fetched (200)  2023-10-03 20:30:16.787158
# 465      fetched (200)  2023-10-03 20:30:17.108271
# ...                ...                         ...
# 4799661  fetched (200)  2023-10-14 21:52:10.395243
# 4800915  fetched (200)  2023-10-14 21:52:30.087387
# 4800975  fetched (200)  2023-10-14 21:52:30.777653
# 4801313  fetched (200)  2023-10-14 21:53:36.106850
# 4804171  fetched (200)  2023-10-14 21:56:18.861111
#
#                               query_type name                  message  path  \
# 106      Facebook:/<comment-id>/comments  NaN  Viktor VanDort jajaja 😂   NaN
# 339      Facebook:/<comment-id>/comments  NaN  Saludame  paaaaapiiiiii   NaN
# 355      Facebook:/<comment-id>/comments  NaN    Hola chavosorrrrr!!!!   NaN
# 444      Facebook:/<comment-id>/comments  NaN   Saludame porfa chavito   NaN
# 465      Facebook:/<comment-id>/comments  NaN    chavito me saludas c:   NaN
# ...                                  ...  ...                      ...   ...
# 4799661  Facebook:/<comment-id>/comments  NaN  NataliaReategui jajjaja   NaN
# 4800915  Facebook:/<comment-id>/comments  NaN  Jajaja, vengan a Mexico   NaN
# 4800975  Facebook:/<comment-id>/comments  NaN    Mayreli Chávez jaja 😎   NaN
# 4801313  Facebook:/<comment-id>/comments  NaN   Àlex Reig Jou jajjajaa   NaN
# 4804171  Facebook:/<comment-id>/comments  NaN    Estefanía Laureano xD   NaN
#
#          valid
# 106      False
# 339      False
# 355      False
# 444      False
# 465      False
# ...        ...
# 4799661  False
# 4800915  False
# 4800975  False
# 4801313  False
# 4804171  False
#
# [41822 rows x 13 columns]

# %%
df =df[df['valid']== True]

# %%
df
# Out:
#         level    id parent_id         object_id object_type object_key  \
# 6           1    14         2   630750614924803        data     data.*
# 7           1    15         2   630750614924803        data     data.*
# 8           1    16         2   630750614924803        data     data.*
# 10          1    18         2   630750614924803        data     data.*
# 14          1    22         2   630750614924803        data     data.*
# ...       ...   ...       ...               ...         ...        ...
# 4804475     1  8384         1  1487688164660839        data     data.*
# 4804481     1  8390         1  1487688164660839        data     data.*
# 4804486     1  8395         1  1487688164660839        data     data.*
# 4804487     1  8396         1  1487688164660839        data     data.*
# 4804489     1  8398         1  1487688164660839        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 4804475  fetched (200)  2023-10-14 21:56:23.810546
# 4804481  fetched (200)  2023-10-14 21:56:23.810546
# 4804486  fetched (200)  2023-10-14 21:56:23.810546
# 4804487  fetched (200)  2023-10-14 21:56:23.810546
# 4804489  fetched (200)  2023-10-14 21:56:23.810546
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 4804475  Facebook:/<comment-id>/comments  NaN
# 4804481  Facebook:/<comment-id>/comments  NaN
# 4804486  Facebook:/<comment-id>/comments  NaN
# 4804487  Facebook:/<comment-id>/comments  NaN
# 4804489  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN   True
# 7                                     estas en pasta causa   NaN   True
# 8        Puedo ver este video un millón de veces y no m...   NaN   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN   True
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN   True
# ...                                                    ...   ...    ...
# 4804475                             Silvia Palza Malabrigo   NaN   True
# 4804481                     Bruno Cafferata Elsa Castañeda   NaN   True
# 4804486    Marilyn L. Ticona atenti a esto y yo también. 😁   NaN   True
# 4804487  Itala Katherine Mendoza  es a él a quién le vi...   NaN   True
# 4804489                  William Zavaleta Garcia así pls 🙏   NaN   True
#
# [1900676 rows x 13 columns]

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900676 entries, 0 to 1900675
# Data columns (total 14 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   index         int64
#  1   level         object
#  2   id            object
#  3   parent_id     object
#  4   object_id     object
#  5   object_type   object
#  6   object_key    object
#  7   query_status  object
#  8   query_time    object
#  9   query_type    object
#  10  name          object
#  11  message       object
#  12  path          float64
#  13  valid         bool
# dtypes: bool(1), float64(1), int64(1), object(11)
# memory usage: 190.3+ MB

# %%
df.sample(30)
# Out:
#            index level      id parent_id         object_id object_type  \
# 798835   1985502     1  262325       326  2697971137099345        data
# 1438069  3279719     1  111430       158   801879203976487        data
# 112707    191446     1    1904         1   450574205864690        data
# 1019383  2464073     1   32446        83  1674414479739379        data
# 1059206  2513488     1   40199        14   799219147876782        data
# 1647569  3827478     1   21231        94   147335597289216        data
# 70637     128542     1    3801        12   306914903861430        data
# 654460   1795997     1   72820       167   878585739741686        data
# 166767    297969     1     594         1   284249033246886        data
# 1454619  3327759     1   14211        72   332939182530299        data
# 1502150  3402328     1   17970        49  3628368414154144        data
# 729604   1894245     1  171068       216   436557564064958        data
# 882430   2196922     1   40412        67  1017677199639339        data
# 1468341  3348722     1   35174       142   340255308328201        data
# 1593800  3637594     1   94681       187  4252033008172560        data
# 1802556  4657174     1   38160       229  3125940970790719        data
# 1341093  3067502     1   95885       159   370666081702576        data
# 138385    250791     1     203         1   810175507480839        data
# 1609322  3664116     1  121203       264   514238269110053        data
# 508757   1283663     1    1500        25   349209726017037        data
# 1137772  2606403     1  133114        39  1355573898302925        data
# 1368084  3110112     1  138495       201   301103962098453        data
# 832282   2037211     1   34644       260  1398367743619704        data
# 1009286  2448683     1   17056        16   962346214859780        data
# 1124098  2590117     1  116828        36   589825142685733        data
# 886232   2204351     1   47841        72   536755031926758        data
# 859544   2142918     1   12401        37  1927741560814261        data
# 1034752  2484082     1   10793         3   634471871566418        data
# 1581018  3610610     1   67697       143   253807169992584        data
# 316226    663499     1    2943         5   896918287152368        data
#
#         object_key   query_status                  query_time  \
# 798835      data.*  fetched (200)  2023-10-25 08:44:03.660652
# 1438069     data.*  fetched (200)  2023-10-25 18:13:40.863903
# 112707      data.*  fetched (200)  2023-09-29 16:58:32.461609
# 1019383     data.*  fetched (200)  2023-10-26 19:50:43.900482
# 1059206     data.*  fetched (200)  2023-10-25 20:30:18.869495
# 1647569     data.*  fetched (200)  2023-10-13 16:26:26.526974
# 70637       data.*  fetched (200)  2023-10-05 20:00:14.175726
# 654460      data.*  fetched (200)  2023-10-24 19:54:00.256429
# 166767      data.*  fetched (200)  2023-10-01 17:18:48.488588
# 1454619     data.*  fetched (200)  2023-10-23 21:07:00.891098
# 1502150     data.*  fetched (200)  2023-10-22 13:39:28.720827
# 729604      data.*  fetched (200)  2023-10-24 20:40:34.302643
# 882430      data.*  fetched (200)  2023-10-22 14:15:39.035407
# 1468341     data.*  fetched (200)  2023-10-23 21:16:11.256932
# 1593800     data.*  fetched (200)  2023-10-15 08:50:40.761140
# 1802556     data.*  fetched (200)  2023-10-14 19:05:18.567000
# 1341093     data.*  fetched (200)  2023-10-22 19:54:54.592704
# 138385      data.*  fetched (200)  2023-09-28 22:12:07.641625
# 1609322     data.*  fetched (200)  2023-10-15 08:58:19.690583
# 508757      data.*  fetched (200)  2023-10-12 01:08:14.131417
# 1137772     data.*  fetched (200)  2023-10-25 20:54:18.892335
# 1368084     data.*  fetched (200)  2023-10-22 20:07:15.148966
# 832282      data.*  fetched (200)  2023-10-15 09:55:18.559107
# 1009286     data.*  fetched (200)  2023-10-26 19:45:13.248681
# 1124098     data.*  fetched (200)  2023-10-25 20:49:59.651405
# 886232      data.*  fetched (200)  2023-10-22 14:17:42.120650
# 859544      data.*  fetched (200)  2023-10-17 22:44:08.400345
# 1034752     data.*  fetched (200)  2023-10-25 20:22:26.654105
# 1581018     data.*  fetched (200)  2023-10-15 08:41:43.359375
# 316226      data.*  fetched (200)  2023-10-09 20:45:33.003400
#
#                               query_type name  \
# 798835   Facebook:/<comment-id>/comments  NaN
# 1438069  Facebook:/<comment-id>/comments  NaN
# 112707      Facebook:/<post-id>/comments  NaN
# 1019383  Facebook:/<comment-id>/comments  NaN
# 1059206  Facebook:/<comment-id>/comments  NaN
# 1647569  Facebook:/<comment-id>/comments  NaN
# 70637    Facebook:/<comment-id>/comments  NaN
# 654460   Facebook:/<comment-id>/comments  NaN
# 166767   Facebook:/<comment-id>/comments  NaN
# 1454619  Facebook:/<comment-id>/comments  NaN
# 1502150  Facebook:/<comment-id>/comments  NaN
# 729604   Facebook:/<comment-id>/comments  NaN
# 882430   Facebook:/<comment-id>/comments  NaN
# 1468341  Facebook:/<comment-id>/comments  NaN
# 1593800  Facebook:/<comment-id>/comments  NaN
# 1802556  Facebook:/<comment-id>/comments  NaN
# 1341093  Facebook:/<comment-id>/comments  NaN
# 138385      Facebook:/<post-id>/comments  NaN
# 1609322  Facebook:/<comment-id>/comments  NaN
# 508757   Facebook:/<comment-id>/comments  NaN
# 1137772  Facebook:/<comment-id>/comments  NaN
# 1368084  Facebook:/<comment-id>/comments  NaN
# 832282   Facebook:/<comment-id>/comments  NaN
# 1009286  Facebook:/<comment-id>/comments  NaN
# 1124098  Facebook:/<comment-id>/comments  NaN
# 886232   Facebook:/<comment-id>/comments  NaN
# 859544   Facebook:/<comment-id>/comments  NaN
# 1034752  Facebook:/<comment-id>/comments  NaN
# 1581018  Facebook:/<comment-id>/comments  NaN
# 316226   Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path  valid
# 798835   ya te llegara tu cana...adicional usted tambie...   NaN   True
# 1438069  Ximena Encinas Angelina Cabrera Areli Hernande...   NaN   True
# 112707               Bairon R. Alarcón JAJAJAJA quien será   NaN   True
# 1019383                 Huevadas y toman tanta importancia   NaN   True
# 1059206                              Sarta de delincuentes   NaN   True
# 1647569                          Margareth Velazco Loza <3   NaN   True
# 70637    Bien por anteponerte a los gustos de tus herma...   NaN   True
# 654460                              Sigues ajustando 😂😂😂😂😂   NaN   True
# 166767   Lucy Lucy eres tan linda como el sol que nos i...   NaN   True
# 1454619                    Esto le falta a esta chica🧠🧠🧠🧠🧠   NaN   True
# 1502150  Si queremos romper estereotipos y esas vainas ...   NaN   True
# 729604   Buen trabajo willax .🇵🇪💪🏻estamos contigo .duel...   NaN   True
# 882430   Eso si va ser la gran sorpresa un mate de risa...   NaN   True
# 1468341  Ojalá ya se haya operado la Cuca porque parecí...   NaN   True
# 1593800  Eres lindo, tú si debes botarte como auténtico...   NaN   True
# 1802556                         Rosario Timana Chamichumbe   NaN   True
# 1341093  JAJAJAJAJAJAJAJAAJJAA  PERO LA SONRISA AL FINA...   NaN   True
# 138385   Los dos son inmaculadas tremendas bulgares sw ...   NaN   True
# 1609322  Anoche dormí viendo tu reportaje !!buenazooo v...   NaN   True
# 508757   Fracasa la dieta porque no cambias el chip de ...   NaN   True
# 1137772  DEMUESTRALO YA. PORQUE DAS TANTAS VUELTAS . TE...   NaN   True
# 1368084  George Torres Frank Js Socola Jairo Maza Chiro...   NaN   True
# 832282                             Alexander Panta Ccasani   NaN   True
# 1009286  No hay nada arriba😁es nuestra conciencia y nue...   NaN   True
# 1124098  Porq no juzgan ha keiko sinverguenzas fiscales...   NaN   True
# 886232   Chino Saludos DE ecuador lo maximo en comedia ...   NaN   True
# 859544                               Jsjaj si ps Iguallito   NaN   True
# 1034752                El pueblo quiere nueva constitución   NaN   True
# 1581018  Que viva la vida loca!!! Que viva la vida feli...   NaN   True
# 316226                            Ya estoy participando :*   NaN   True

# %%
#Slang Extraction

# %%
SENTENCE_LENGTH = 10000000 #limit of characters to extract
def extract_sentence(corpus, text):
    sentences = []
    for line in list(corpus):
        if (" "+text in line.lower()) & (len(line) <= SENTENCE_LENGTH):
#             print(line)
            sentences.append(line.strip().replace("\n"," "))
#             print('=============================================================================')
        
#     print(sentences)
    return sentences

# %%
df_slang = pd.read_csv(r'peruvian-slang.v1.csv', usecols = ['Jerga','tipo'])
df_slang
# Out:
#                           Jerga       tipo
# 0                            Pe      Jerga
# 1                            Oe      Jerga
# 2                       Lechero      Jerga
# 3                       Lenteja      Jerga
# 4               Tirarse la pera  expresión
# ...                         ...        ...
# 2339      Meter floro o florear  expresión
# 2340  Tus perras están ladrando  expresión
# 2341          Hacer una chancha  expresión
# 2342                Pitri mitri  expresión
# 2343        en la luna de paita  expresión
#
# [2344 rows x 2 columns]

# %%
data = []
slang_length = 3 #minimun length of characters of an slang

# %%
pd.set_option("max_colwidth", 300)

# %%
df_sample = df.sample(10_000)
df_sample = df_sample[['id', 'object_id', 'message']]
df_sample
# Out:
#              id         object_id  \
# 1056245   36622  5922144211147729
# 1573952   55421   738508037316677
# 483852     2268  1383937592012711
# 1273104   16145   668688510547070
# 919308   111523   429148945895486
# ...         ...               ...
# 59502      3588  1157451784658852
# 1790334   20022  1202481306760457
# 970187    23056  3521853364574962
# 1124423  117192   589825142685733
# 1187063  193231   453461103460178
#
#                                                                         message
# 1056245                                       Es mentira el pueblo llo respalda
# 1573952                           El ministro está ocupado defendiendo al burro
# 483852          Lugar de entrenamiento y costo porfavor y de que edades reciben
# 1273104                                          Ese cholo mena con anemia xddd
# 919308   Saludos 🤗 desde ESPAÑA, MADRID 🇪🇸, para Geraldine, Joaquín y Beatriz 😉
# ...                                                                         ...
# 59502                                Se le salió todo el tarrajeo de la cara 😄😄
# 1790334                            Por favor debe de decir los precios gracias.
# 970187                                   A la tia que vende huevitos pes jajaja
# 1124423                                         Pobre chica  q Dios  lo proteja
# 1187063                                             ..será el jefe del.canal...
#
# [10000 rows x 3 columns]

# %%
def find_slang(text):
    slangs = ""
    for i in df_slang.index:
        slang = df_slang['Jerga'][i].lower()
        if (len(slang)>slang_length):
            if " "+slang in text.lower():
                slangs += slang + ","
    return slangs

# %%
import psutil 
print('Physical Cores=', psutil.cpu_count(logical=False))
print('Logical Cores=',  psutil.cpu_count(logical=True))
# Out:
# Physical Cores= 8
# Logical Cores= 16

# %%
#to run in multple cores
#pip install swifter

# %%
import swifter

# %%
import pandas as pd

# this is an example of common operations you have to perform on text
# data to go from raw text to clean text you can use for modelling
def process_df_function(df):
    output_df = df.copy()
    # replace weird double quotes with normal ones
    output_df['slangs'] = output_df['message'].swifter.apply(lambda row: find_slang(row))
    return output_df

# %%
import multiprocessing
import numpy as np

NUM_CORES = 5

# split the raw dataframe into chunks
df_chunks = np.array_split(df_sample ,NUM_CORES)

# %%
#df_chunks

# %%
# use a pool to spawn multiple proecsses
# with multiprocessing.Pool(NUM_CORES) as pool:
#     processed_df = pd.concat(pool.map(process_df_function, df_chunks), ignore_index=True)

# %%
df_sample['slangs'] = df_sample['message'].swifter.apply(lambda row: find_slang(row))
df_sample
# Out:
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df_sample.sample(30)

# %%
#https://towardsdatascience.com/emojis-aid-social-media-sentiment-analysis-stop-cleaning-them-out-bb32a1e5fc8e

# %%
#https://queirozf.com/entries/pandas-for-large-data
