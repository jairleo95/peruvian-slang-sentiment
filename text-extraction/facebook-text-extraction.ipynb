# %%
import sys
import pandas as pd 
import os 
import glob

# %%
MIN_CHAR_LENGHT = 20

# %%
csv_files = glob.glob(os.path.join(r"facebook/extraction-3/", "*.csv"))

# %%
#csv_files

# %%
df_list = (pd.read_csv(file, sep = ';') for file in csv_files)

# %%
big_df = pd.concat(df_list, ignore_index=True)
# Out:
# /tmp/ipykernel_62186/1748436866.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   big_df = pd.concat(df_list, ignore_index=True)

# %%
df = big_df.dropna(subset=['message'])

# %%
df = df[df['message'].str.len()>=MIN_CHAR_LENGHT]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2021181 entries, 6 to 3364645
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   level         object
#  1   id            object
#  2   parent_id     float64
#  3   object_id     object
#  4   object_type   object
#  5   object_key    object
#  6   query_status  object
#  7   query_time    object
#  8   query_type    object
#  9   name          object
#  10  message       object
#  11  path          float64
# dtypes: float64(2), object(10)
# memory usage: 200.5+ MB

# %%
df = df.drop_duplicates(subset=['message'], keep='first')

# %%
df
# Out:
#         level      id  parent_id        object_id object_type object_key  \
# 6           1      14        2.0  630750614924803        data     data.*
# 7           1      15        2.0  630750614924803        data     data.*
# 8           1      16        2.0  630750614924803        data     data.*
# 10          1      18        2.0  630750614924803        data     data.*
# 14          1      22        2.0  630750614924803        data     data.*
# ...       ...     ...        ...              ...         ...        ...
# 3364637     1  277481      348.0  760076547815096        data     data.*
# 3364638     1  277482      348.0  760076547815096        data     data.*
# 3364639     1  277483      348.0  760076547815096        data     data.*
# 3364642     1  277486      348.0  760076547815096        data     data.*
# 3364645     1  277489      348.0  760076547815096        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 3364637  fetched (200)  2023-10-25 08:48:12.602153
# 3364638  fetched (200)  2023-10-25 08:48:12.602153
# 3364639  fetched (200)  2023-10-25 08:48:12.602153
# 3364642  fetched (200)  2023-10-25 08:48:12.602153
# 3364645  fetched (200)  2023-10-25 08:48:12.602153
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 3364637  Facebook:/<comment-id>/comments  NaN
# 3364638  Facebook:/<comment-id>/comments  NaN
# 3364639  Facebook:/<comment-id>/comments  NaN
# 3364642  Facebook:/<comment-id>/comments  NaN
# 3364645  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN
# 7                                     estas en pasta causa   NaN
# 8        Puedo ver este video un millón de veces y no m...   NaN
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN
# ...                                                    ...   ...
# 3364637               Maria Bazán Priscilla Bustíos Chávez   NaN
# 3364638                         ALexander Rojas Vargas 🤭🤭🤭   NaN
# 3364639       Lo que diria Melcochita: Despierta imbecil 🤣   NaN
# 3364642                          Ese inbecil esta muerto 💀   NaN
# 3364645                               Un lapo tirenlo 😂😂😂😂   NaN
#
# [1942498 rows x 12 columns]

# %%
#exclude words
words = ['jaja','jajaja', 'jajajajajajja', 'jajajajajajaja','jajajajjajajajaja','Jajajajajajajajaja','jajajaja','jajajajjajajajaja', 'jajajajja','jijiji', 'saludo', 'saluda', 'xd', 'hola', 'zzz']
def remove_words(text):
    for x in words:
        text = text.lower().replace(x, '')
    if len(text)>=MIN_CHAR_LENGHT:
        return True
    return False

# %%
print(remove_words('Belén Sánchez Castillo jajajajaja'))
# Out:
# True

# %%
df
# Out:
#         level      id  parent_id        object_id object_type object_key  \
# 6           1      14        2.0  630750614924803        data     data.*
# 7           1      15        2.0  630750614924803        data     data.*
# 8           1      16        2.0  630750614924803        data     data.*
# 10          1      18        2.0  630750614924803        data     data.*
# 14          1      22        2.0  630750614924803        data     data.*
# ...       ...     ...        ...              ...         ...        ...
# 3364637     1  277481      348.0  760076547815096        data     data.*
# 3364638     1  277482      348.0  760076547815096        data     data.*
# 3364639     1  277483      348.0  760076547815096        data     data.*
# 3364642     1  277486      348.0  760076547815096        data     data.*
# 3364645     1  277489      348.0  760076547815096        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 3364637  fetched (200)  2023-10-25 08:48:12.602153
# 3364638  fetched (200)  2023-10-25 08:48:12.602153
# 3364639  fetched (200)  2023-10-25 08:48:12.602153
# 3364642  fetched (200)  2023-10-25 08:48:12.602153
# 3364645  fetched (200)  2023-10-25 08:48:12.602153
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 3364637  Facebook:/<comment-id>/comments  NaN
# 3364638  Facebook:/<comment-id>/comments  NaN
# 3364639  Facebook:/<comment-id>/comments  NaN
# 3364642  Facebook:/<comment-id>/comments  NaN
# 3364645  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN
# 7                                     estas en pasta causa   NaN
# 8        Puedo ver este video un millón de veces y no m...   NaN
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN
# ...                                                    ...   ...
# 3364637               Maria Bazán Priscilla Bustíos Chávez   NaN
# 3364638                         ALexander Rojas Vargas 🤭🤭🤭   NaN
# 3364639       Lo que diria Melcochita: Despierta imbecil 🤣   NaN
# 3364642                          Ese inbecil esta muerto 💀   NaN
# 3364645                               Un lapo tirenlo 😂😂😂😂   NaN
#
# [1942498 rows x 12 columns]

# %%
#remove rows that are too small when excluding the list.
df['valid'] = df['message'].apply(lambda row: remove_words(row))
df
# Out:
#         level      id  parent_id        object_id object_type object_key  \
# 6           1      14        2.0  630750614924803        data     data.*
# 7           1      15        2.0  630750614924803        data     data.*
# 8           1      16        2.0  630750614924803        data     data.*
# 10          1      18        2.0  630750614924803        data     data.*
# 14          1      22        2.0  630750614924803        data     data.*
# ...       ...     ...        ...              ...         ...        ...
# 3364637     1  277481      348.0  760076547815096        data     data.*
# 3364638     1  277482      348.0  760076547815096        data     data.*
# 3364639     1  277483      348.0  760076547815096        data     data.*
# 3364642     1  277486      348.0  760076547815096        data     data.*
# 3364645     1  277489      348.0  760076547815096        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 3364637  fetched (200)  2023-10-25 08:48:12.602153
# 3364638  fetched (200)  2023-10-25 08:48:12.602153
# 3364639  fetched (200)  2023-10-25 08:48:12.602153
# 3364642  fetched (200)  2023-10-25 08:48:12.602153
# 3364645  fetched (200)  2023-10-25 08:48:12.602153
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 3364637  Facebook:/<comment-id>/comments  NaN
# 3364638  Facebook:/<comment-id>/comments  NaN
# 3364639  Facebook:/<comment-id>/comments  NaN
# 3364642  Facebook:/<comment-id>/comments  NaN
# 3364645  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN   True
# 7                                     estas en pasta causa   NaN   True
# 8        Puedo ver este video un millón de veces y no m...   NaN   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN   True
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN   True
# ...                                                    ...   ...    ...
# 3364637               Maria Bazán Priscilla Bustíos Chávez   NaN   True
# 3364638                         ALexander Rojas Vargas 🤭🤭🤭   NaN   True
# 3364639       Lo que diria Melcochita: Despierta imbecil 🤣   NaN   True
# 3364642                          Ese inbecil esta muerto 💀   NaN   True
# 3364645                               Un lapo tirenlo 😂😂😂😂   NaN   True
#
# [1942498 rows x 13 columns]

# %%
df_false = df[df['valid']== False]
df_false
# Out:
#         level      id  parent_id         object_id object_type object_key  \
# 106         1     114        3.0  3963455660362592        data     data.*
# 339         1     349        7.0   372233297036050        data     data.*
# 355         1     365        7.0   372233297036050        data     data.*
# 444         1     454        7.0   372233297036050        data     data.*
# 465         1     475        7.0   372233297036050        data     data.*
# ...       ...     ...        ...               ...         ...        ...
# 3364550     1  277394      348.0   760076547815096        data     data.*
# 3364603     1  277447      348.0   760076547815096        data     data.*
# 3364609     1  277453      348.0   760076547815096        data     data.*
# 3364623     1  277467      348.0   760076547815096        data     data.*
# 3364631     1  277475      348.0   760076547815096        data     data.*
#
#           query_status                  query_time  \
# 106      fetched (200)  2023-10-03 20:29:35.809339
# 339      fetched (200)  2023-10-03 20:30:15.129249
# 355      fetched (200)  2023-10-03 20:30:15.537832
# 444      fetched (200)  2023-10-03 20:30:16.787158
# 465      fetched (200)  2023-10-03 20:30:17.108271
# ...                ...                         ...
# 3364550  fetched (200)  2023-10-25 08:48:11.478111
# 3364603  fetched (200)  2023-10-25 08:48:12.308536
# 3364609  fetched (200)  2023-10-25 08:48:12.308536
# 3364623  fetched (200)  2023-10-25 08:48:12.602153
# 3364631  fetched (200)  2023-10-25 08:48:12.602153
#
#                               query_type name                      message  \
# 106      Facebook:/<comment-id>/comments  NaN      Viktor VanDort jajaja 😂
# 339      Facebook:/<comment-id>/comments  NaN      Saludame  paaaaapiiiiii
# 355      Facebook:/<comment-id>/comments  NaN        Hola chavosorrrrr!!!!
# 444      Facebook:/<comment-id>/comments  NaN       Saludame porfa chavito
# 465      Facebook:/<comment-id>/comments  NaN        chavito me saludas c:
# ...                                  ...  ...                          ...
# 3364550  Facebook:/<comment-id>/comments  NaN     jajajajjajaj tmre la cgd
# 3364603  Facebook:/<comment-id>/comments  NaN   Karyme JAJAJAJAJAJJA🤦🏻‍♂️🤣
# 3364609  Facebook:/<comment-id>/comments  NaN  jajajajaja No SE DUERMANNNN
# 3364623  Facebook:/<comment-id>/comments  NaN       El Wasap de JB jjajaja
# 3364631  Facebook:/<comment-id>/comments  NaN  Kevin Arroyo Nieto jajajaja
#
#          path  valid
# 106       NaN  False
# 339       NaN  False
# 355       NaN  False
# 444       NaN  False
# 465       NaN  False
# ...       ...    ...
# 3364550   NaN  False
# 3364603   NaN  False
# 3364609   NaN  False
# 3364623   NaN  False
# 3364631   NaN  False
#
# [41822 rows x 13 columns]

# %%
df =df[df['valid']== True]

# %%
df
# Out:
#         level      id  parent_id        object_id object_type object_key  \
# 6           1      14        2.0  630750614924803        data     data.*
# 7           1      15        2.0  630750614924803        data     data.*
# 8           1      16        2.0  630750614924803        data     data.*
# 10          1      18        2.0  630750614924803        data     data.*
# 14          1      22        2.0  630750614924803        data     data.*
# ...       ...     ...        ...              ...         ...        ...
# 3364637     1  277481      348.0  760076547815096        data     data.*
# 3364638     1  277482      348.0  760076547815096        data     data.*
# 3364639     1  277483      348.0  760076547815096        data     data.*
# 3364642     1  277486      348.0  760076547815096        data     data.*
# 3364645     1  277489      348.0  760076547815096        data     data.*
#
#           query_status                  query_time  \
# 6        fetched (200)  2023-10-03 20:29:29.755992
# 7        fetched (200)  2023-10-03 20:29:29.755992
# 8        fetched (200)  2023-10-03 20:29:29.755992
# 10       fetched (200)  2023-10-03 20:29:29.755992
# 14       fetched (200)  2023-10-03 20:29:29.755992
# ...                ...                         ...
# 3364637  fetched (200)  2023-10-25 08:48:12.602153
# 3364638  fetched (200)  2023-10-25 08:48:12.602153
# 3364639  fetched (200)  2023-10-25 08:48:12.602153
# 3364642  fetched (200)  2023-10-25 08:48:12.602153
# 3364645  fetched (200)  2023-10-25 08:48:12.602153
#
#                               query_type name  \
# 6        Facebook:/<comment-id>/comments  NaN
# 7        Facebook:/<comment-id>/comments  NaN
# 8        Facebook:/<comment-id>/comments  NaN
# 10       Facebook:/<comment-id>/comments  NaN
# 14       Facebook:/<comment-id>/comments  NaN
# ...                                  ...  ...
# 3364637  Facebook:/<comment-id>/comments  NaN
# 3364638  Facebook:/<comment-id>/comments  NaN
# 3364639  Facebook:/<comment-id>/comments  NaN
# 3364642  Facebook:/<comment-id>/comments  NaN
# 3364645  Facebook:/<comment-id>/comments  NaN
#
#                                                    message  path  valid
# 6             Las hijas de kingteka tienen buena coreo. GA   NaN   True
# 7                                     estas en pasta causa   NaN   True
# 8        Puedo ver este video un millón de veces y no m...   NaN   True
# 10       Valerie Nj  que fue con tu show? tas facturand...   NaN   True
# 14       Dicen que se vió esos pasitos Skeres en el ton...   NaN   True
# ...                                                    ...   ...    ...
# 3364637               Maria Bazán Priscilla Bustíos Chávez   NaN   True
# 3364638                         ALexander Rojas Vargas 🤭🤭🤭   NaN   True
# 3364639       Lo que diria Melcochita: Despierta imbecil 🤣   NaN   True
# 3364642                          Ese inbecil esta muerto 💀   NaN   True
# 3364645                               Un lapo tirenlo 😂😂😂😂   NaN   True
#
# [1900676 rows x 13 columns]

# %%
df = df.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900676 entries, 0 to 1900675
# Data columns (total 14 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   index         int64
#  1   level         object
#  2   id            object
#  3   parent_id     float64
#  4   object_id     object
#  5   object_type   object
#  6   object_key    object
#  7   query_status  object
#  8   query_time    object
#  9   query_type    object
#  10  name          object
#  11  message       object
#  12  path          float64
#  13  valid         bool
# dtypes: bool(1), float64(2), int64(1), object(10)
# memory usage: 190.3+ MB

# %%
df = df.sample(frac=1)

# %%
#Separate in chunks of 500k

# %%
df.to_csv('raw-data/facebook-comments.csv', index=False)

# %%
df_sample = pd.read_csv(r'raw-data/facebook-comments.csv', chunksize=500_000)

# %%
for i,chunk in enumerate(df_sample):
    chunk.to_csv('raw-data/tmp/chunk{}.csv'.format(i), index=False)

# %%
sd.
# Out:
#   Cell In[26], line 1
#     sd.
#        ^
# SyntaxError: invalid syntax

# %%
#Slang Extraction

# %%
SENTENCE_LENGTH = 10000000 #limit of characters to extract
def extract_sentence(corpus, text):
    sentences = []
    for line in list(corpus):
        if (" "+text in line.lower()) & (len(line) <= SENTENCE_LENGTH):
#             print(line)
            sentences.append(line.strip().replace("\n"," "))
#             print('=============================================================================')
        
#     print(sentences)
    return sentences

# %%
df_slang = pd.read_csv(r'peruvian-slang.v1.csv', usecols = ['Jerga','tipo'])
df_slang
# Out:
#                           Jerga       tipo
# 0                            Pe      Jerga
# 1                            Oe      Jerga
# 2                       Lechero      Jerga
# 3                       Lenteja      Jerga
# 4               Tirarse la pera  expresión
# ...                         ...        ...
# 2339      Meter floro o florear  expresión
# 2340  Tus perras están ladrando  expresión
# 2341          Hacer una chancha  expresión
# 2342                Pitri mitri  expresión
# 2343        en la luna de paita  expresión
#
# [2344 rows x 2 columns]

# %%
data = []
slang_length = 3 #minimun length of characters of an slang
#num_sample = 500_000

# %%
pd.set_option("max_colwidth", 300)

# %%
df = pd.read_csv(r'raw-data/tmp/chunk2.csv')

# %%
df
# Out:
#           index  level      id  parent_id         object_id object_type  \
# 0        343972      1    3897       17.0   849984533204876        data
# 1        338614      1     509        1.0   831288915117986        data
# 2       2376322      1   17325        1.0  1693898353972863        data
# 3       2244376      1   13732       66.0   509335297295531        data
# 4        265238      1   11317       18.0  3383359308403711        data
# ...         ...    ...     ...        ...               ...         ...
# 499995  3344343      1  257187      336.0   293170908318068        data
# 499996   199055      1   40395       21.0   613643633303283        data
# 499997  3353116      1  265960      325.0   219431976046544        data
# 499998  2396122      1    1574       19.0   242242804177894        data
# 499999  2435178      1    6258        3.0   634471871566418        data
#
#        object_key   query_status                  query_time  \
# 0          data.*  fetched (200)  2023-10-01 18:08:34.942541
# 1          data.*  fetched (200)  2023-09-25 22:00:24.679732
# 2          data.*  fetched (200)  2023-09-28 22:46:11.250016
# 3          data.*  fetched (200)  2023-10-25 17:43:10.961397
# 4          data.*  fetched (200)  2023-10-01 16:40:59.256866
# ...           ...            ...                         ...
# 499995     data.*  fetched (200)  2023-10-25 08:42:38.460756
# 499996     data.*  fetched (200)  2023-10-02 21:55:59.062307
# 499997     data.*  fetched (200)  2023-10-25 08:45:08.996466
# 499998     data.*  fetched (200)  2023-10-08 07:56:33.366096
# 499999     data.*  fetched (200)  2023-10-25 20:21:11.800963
#
#                              query_type  name  \
# 0       Facebook:/<comment-id>/comments   NaN
# 1          Facebook:/<post-id>/comments   NaN
# 2          Facebook:/<post-id>/comments   NaN
# 3       Facebook:/<comment-id>/comments   NaN
# 4       Facebook:/<comment-id>/comments   NaN
# ...                                 ...   ...
# 499995  Facebook:/<comment-id>/comments   NaN
# 499996  Facebook:/<comment-id>/comments   NaN
# 499997  Facebook:/<comment-id>/comments   NaN
# 499998  Facebook:/<comment-id>/comments   NaN
# 499999  Facebook:/<comment-id>/comments   NaN
#
#                                                                                                                                                                                                                                                                                                       message  \
# 0                                                                                                                                                                                                                                                           Giovany Aburto yo después de subir a plata jajaja
# 1                                                                                                                                                                                                                                                              Chino ese mayimbu así hechado parece una combi
# 2                                                                                                                                                                                                                                                               Liz Elena Cubilla Ferreira 😂😊 Arnaldo Alfonso
# 3                                                                                                                                                                                                                                             Omar Marquez  a mi nadie me va a decir que no diga dattebayo :(
# 4                                                                                                                                                                                                                                                                                 Darwin Botia  hahahahahahha
# ...                                                                                                                                                                                                                                                                                                       ...
# 499995                                                                                                                                                                                                                                                                         PERO DND ESTAN LAS AUTORIDADES
# 499996                                                                                                                                                                                                                                                          Lo mismo hizo  angie arizaga, se fue a Russia
# 499997  Se vee que ella tiene buena situación económica, porque ella misma no compra sus mascarillas y guantes y lo que quiere su padre y se los manda, para que publique Beto debe tener buenas influencias  .así como quizá pagaba para que le hagan pasar y no haga colas como las otras personas 🤷‍♀️🤷‍♀️
# 499998                                                                                                                                                                                                                                                                             que argentino no es picon?
# 499999                                                                                                                                                                                                                                                                        Esté hombre no sabe lo que dice
#
#         path  valid
# 0        NaN   True
# 1        NaN   True
# 2        NaN   True
# 3        NaN   True
# 4        NaN   True
# ...      ...    ...
# 499995   NaN   True
# 499996   NaN   True
# 499997   NaN   True
# 499998   NaN   True
# 499999   NaN   True
#
# [500000 rows x 14 columns]

# %%
df_sample = df.sample(frac=1)
df_sample = df_sample[['id', 'object_id', 'message']]
df_sample
# Out:
#             id         object_id  \
# 80950    31941   584550673788111
# 120413  129814   854405149070228
# 334769  242513  1055309035100251
# 301730     604  1027450215119148
# 421275   19244  2031319357080361
# ...        ...               ...
# 440899   40772   457128999094161
# 57977    32160  1031743523668828
# 171966  114794  1293572718059752
# 71929   210425  1093465671301043
# 236092   12724  1405489999547323
#
#                                                                                                                                                           message
# 80950                                                                                     Saludos  Chino risas Para la gente peruana Desde Los Angeles California
# 120413                                                                                                                 VOOOOOOOOOOOT44AAAAAAAAAAAALLLOOOOOOOOOOOO
# 334769  Esta declaración  los duele a los periodistas mermeleros las cosas claras ahora la prensa  dise xk es ministra jaja k pena k piensa cosas los periodistas
# 301730                                                                                                                                 Cabro más falso y corrupto
# 421275                                                                                                             Buenas noches. Hay adornos navideños de Minnie
# ...                                                                                                                                                           ...
# 440899                                                Obedezcan por favor! Se los pide un periodista que jamás cometió delitos y no tuvo que escapar del país 😂😂😂
# 57977                                                                                                                   Precio de las pantis y hasta k talla hay?
# 171966                                                                                                               Provecho chicos y Bendiciones para ustedes😇🙏
# 71929                                                                    En las cuerdas???  NO TIENEN MÁS QUE ACUSACIONES SIN PRUEBAS😁😁😁. TODO ESTÁ INVENTADO....
# 236092                                                                                                                  Eduardo Pecho la guisadaaa causaaa 🤙🏼🤙🏼🤙🏼
#
# [500000 rows x 3 columns]

# %%
def find_slang(text):
    slangs = ""
    for i in df_slang.index:
        slang = df_slang['Jerga'][i].lower()
        if (len(slang)>slang_length):
            if " "+slang in text.lower():
                slangs += slang + ","
    return slangs

# %%
#to run in multple cores
#pip install swifter

# %%
import swifter
# Out:
# /home/darkstar/anaconda3/envs/robertuito-env/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 13.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(

# %%
import pandas as pd

# this is an example of common operations you have to perform on text
# data to go from raw text to clean text you can use for modelling
def process_df_function(df):
    output_df = df.copy()
    # replace weird double quotes with normal ones
    output_df['slangs'] = output_df['message'].swifter.apply(lambda row: find_slang(row))
    return output_df

# %%
import psutil
print('Physical Cores=', psutil.cpu_count(logical=False))
print('Logical Cores=',  psutil.cpu_count(logical=True))
# Out:
# Physical Cores= 8
# Logical Cores= 16

# %%
#df_sample =  df_sample.sample(100)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500000 entries, 80950 to 236092
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         500000 non-null  int64
#  1   object_id  500000 non-null  int64
#  2   message    500000 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 15.3+ MB

# %%
import multiprocessing
import numpy as np

NUM_CORES = 10

# split the raw dataframe into chunks
df_chunks = np.array_split(df_sample ,NUM_CORES)

# %%
type(df_chunks)
# Out:
# list

# %%
#use a pool to spawn multiple proecsses
with multiprocessing.Pool(NUM_CORES) as pool:
    processed_df = pd.concat(pool.map(process_df_function, df_chunks), ignore_index=True)

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         500000 non-null  int64
#  1   object_id  500000 non-null  int64
#  2   message    500000 non-null  object
#  3   slangs     500000 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 15.3+ MB

# %%
processed_df.head(20)
# Out:
#         id         object_id  \
# 0    31941   584550673788111
# 1   129814   854405149070228
# 2   242513  1055309035100251
# 3      604  1027450215119148
# 4    19244  2031319357080361
# 5     7810   671083710518881
# 6    48423   610774273843508
# 7    16341   482056985907532
# 8    11985   449953136370217
# 9    21581  1413672002773630
# 10   38583   435289537107636
# 11   16980  2829070670711511
# 12   11590  1533813666713237
# 13    6274  1928301154050952
# 14   44819  1450069302079990
# 15  105315   515082346833082
# 16  245968  1364539347267199
# 17   33437   860440201517689
# 18   72812  1028911150640962
# 19  111928   493271432118814
#
#                                                                                                                                                                                                                                                                                                         message  \
# 0                                                                                                                                                                                                                                       Saludos  Chino risas Para la gente peruana Desde Los Angeles California
# 1                                                                                                                                                                                                                                                                    VOOOOOOOOOOOT44AAAAAAAAAAAALLLOOOOOOOOOOOO
# 2                                                                                                                                                     Esta declaración  los duele a los periodistas mermeleros las cosas claras ahora la prensa  dise xk es ministra jaja k pena k piensa cosas los periodistas
# 3                                                                                                                                                                                                                                                                                    Cabro más falso y corrupto
# 4                                                                                                                                                                                                                                                                Buenas noches. Hay adornos navideños de Minnie
# 5                                                                                                                                                                                                               Fabuloso !!chicas me encanta ver sus videos que espectacular todo y yo tambien algun día iré !!
# 6                                                                                                                                                                                           ANTAURO HUMALA presidente en el 2026 para poner en su lugar a estos periodistas mermeleros fujikeyquistas golpistas
# 7                                                                                                                                                                                                                                                                             Sussan Bravo nosotras jajjaja 🤣🤣😘
# 8                                                                                                                                                                                                                                 Mucha variedad en el Perú hermoso 💗 , donde se puede comer hasta los mercados
# 9                                                                                                                                                                                                                                                                                      Elianis Ramirez ahí está
# 10                                                                                                                                                                                                                                                                         Elizabeth Yupanqui Marquez me caso 💕
# 11  No conozco mucho el Perú pero si me gustó lo sincero que fue Gerardo y también por dar el informe a algunas personas ignorantes que ni sabia sobre este comedor popular como yo y sería bueno que apoyemos entre todos a ese comedor popular para que los de bajo recursos coman como personas que si te...
# 12                                                                                                                                                                                                                                                                  Denise Muñoz es lo que nos decía el profe 😱
# 13                                                                                                                                                                                                                                                                         Si me paso!!! Y es feo sentirse así.
# 14                                                                                                                                                                                                                                                                     Mejor dejs tu ropa y mañana lo recoges 🤪
# 15                                                                                                                                                                                                                                          Esto solo.pasa en las novelas pero lo hiso realidad bien hai sensei
# 16                                                                                                                                                                                                                                                                                 Que no lo vea Natalia malaga
# 17                                                                                                                                                                                                                                                           Jape ¿ya hiciste autorretratos? me gustaría verlo.
# 18                                                                                                                                                                                                                                                  Me encanto la visita a mi tierra   Guapo y alhaja Luciano 😀
# 19                                                                                                                                                                                                                                                   Fuera kriko ,  responde a tu juicio por lavado de activos.
#
#         slangs
# 0       chino,
# 1
# 2   mermelero,
# 3
# 4
# 5
# 6   mermelero,
# 7
# 8
# 9
# 10
# 11
# 12      profe,
# 13
# 14
# 15    novelas,
# 16
# 17
# 18
# 19

# %%
# %%time
# df_sample['slangs'] = df_sample['message'].swifter.apply(lambda row: find_slang(row))
# df_sample

# %%
df_filter = processed_df.copy()

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         500000 non-null  int64
#  1   object_id  500000 non-null  int64
#  2   message    500000 non-null  object
#  3   slangs     500000 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 15.3+ MB

# %%
df_filter = df_filter.astype({'slangs':'string'})

# %%
df_sort = df_filter.sort_values(by='slangs',ascending=True, na_position='last')
df_sort
# Out:
#             id         object_id  \
# 249999   15242   197193396563082
# 257737    8446   107174894058988
# 429304   35445  3453028881426633
# 257735   18901   634471871566418
# 257734   19231  2866144616739452
# ...        ...               ...
# 189640  157144  1169040173828016
# 145181  157076  1169040173828016
# 175359  156783  1169040173828016
# 341541  156769  1169040173828016
# 7864    111245  1241227906050053
#
#                                                                                                                                                                                                                                   message  \
# 249999                                                                                                                                                                                                Hermoso trabajo, felicitaciones 👏🤩🤩
# 257737                                                                                                                                                                               Jajjaajaja tus canciones en 1 solo vídeo 😂😂😂 Daniela
# 429304                                                                                                                                                  Jajajaja es como logo de la academia umbrella... Grandeeee toooooobiiiiii!!! ✌🏼🤗✨
# 257735                                                                                                                                                              Jajajaja Castillo momentos incomodo para el, por dentro comemé tierra
# 257734                                                                                                                                                                                                      La mejor opcion! Bien Diego 🤣
# ...                                                                                                                                                                                                                                   ...
# 189640                                                                                                     Debería el MTC de sensura a este canal que solo está lleno de odio y habla cochinadas no  respeta el horario al menor ( ñoña )
# 145181                                                                  Oye perra bende patria tu te sacas la ñoña si te yenas los bolsillos fasilmente engañanle al pueblo con tu conpiches fujimorista badura de periodista q pena x ti
# 175359                                                                                                  Ese lexico que usa esta periodista deja mucho q decir de su profesionalismo. Habla de ñoña, idiota, estupuda. Que barbaro .......
# 341541  latas de basura conforme periodistas , congresistas y gobernantes y usted misma lo dijo periodista vendida ,"no se saca la ñoña , si no se la come y la ñoña de los riquillos , estamos cansados de tanta basura de todos ustedes
# 7864                                                                                                                                        De piura a ayabaca son 5 horas en ómnibus, si vas en carro particular 4x4 la hacen en 4 horas
#
#                    slangs
# 249999
# 257737
# 429304
# 257735
# 257734
# ...                   ...
# 189640   ñoña,habla,cana,
# 145181        ñoña,perra,
# 175359  ñoña,profe,habla,
# 341541        ñoña,tanta,
# 7864             ómnibus,
#
# [500000 rows x 4 columns]

# %%
df_filter.to_csv('raw-data/facebook-comments-chunk2.csv', index=False)

# %%
# df_sort = df_sort[df_sort['slangs'].notnull()]
df_filter = df_sort[df_sort['slangs'] != '']

# %%
df_filter.head(30)
# Out:
#             id          object_id  \
# 461566   67234   1331938977643891
# 485058    9540    756124745443979
# 14550    32897   1833329350356708
# 198486  237158    578726176389319
# 159073  100426    716304292577262
# 377894   21969    587395386675812
# 54292   102298    152399463556909
# 144320     410    275543228626098
# 499579  131016    458486128723135
# 296052  137488    458486128723135
# 116082  104418    152399463556909
# 460188  101594    152399463556909
# 348812  104165    152399463556909
# 345745     450    240323671788212
# 266760   23106   1288696477893343
# 200464   11435    823725462538088
# 468405  101641    152399463556909
# 455828     896   2763483520391778
# 298998  153972    498963758147956
# 304437  133717    458486128723135
# 381349    9128   7031870890175942
# 66689    61430   1467069747129103
# 333502    2387  10154199458332476
# 264165   26451    719942449897523
# 183196  234583    787266132427161
# 14027     3882   2574707869436278
# 464155  238288    787266132427161
# 96278    81273   1012433866094691
# 61759    63638    772409053432999
# 298717    2478    868550809990922
#
#                                                                                                                                                                                                                                                                                                             message  \
# 461566                                                                                                                                                                                                                                           Materia dispuesta pa chupar un abrazo chicos me hacen reír a forro
# 485058  Hoy los TROLES están con chamba a forro en Youtube en facebook y todas las redes sociales pagados con nuestro dinero eso es lo triste de estos asnillos pero no cuentan ni valen su opinión no son nada ni chicha ni limonada pero si huelen mal muy mal será por Yenifer, antauro, Liliana, o Castillo ...
# 14550                                                                                                                                                                                                                                     Ese par es la kaggada cómo te relojean a forro ...me caen bien estos tios
# 198486                                                                                                                                                                                                                                                 Hazte un vídeo de la hija de ALAN GARCiA ese robaba a forro
# 464155                                                                                                                                                                                                                         Este Buter se cree achorado,buena señor abogado Benji,ese no conoce la Constitución.
# 96278                                                                            Nunca más narKkoterrorusmo!!! Nunca más Kkongresokk!!!! Nunca más vende patria nunca más traidores brutos y achorados nunca más y que se les cumpla la ley democrática pena capital para por fin seguir adelante y respirar La Paz
# 61759                                                                                                                                                                                                                                                                              Porky  " El bruto y achorado " 😆
# 298717                                                                                                                                                                                                                                                                              El premio achorado está en el 1
#
#                                               slangs
# 461566        a forro,chico,chup,chupar,forro,forro,
# 485058  a forro,culo,vale,chamba,chicha,forro,forro,
# 14550                           a forro,forro,forro,
# 198486                          a forro,forro,forro,
# 159073             a forro,jodido,habla,forro,forro,
# 377894                                      a naaaa,
# 54292                                       achicar,
# 144320                                      achicar,
# 499579                                      achicar,
# 296052                                      achicar,
# 116082                                      achicar,
# 460188                                      achicar,
# 348812                                      achicar,
# 345745                                      achicar,
# 266760                                      achicar,
# 200464                     achicar,anda,firme,vieja,
# 468405                    achicar,flaca,profe,palta,
# 455828                                 achicar,mano,
# 298998                             achicar,mariposa,
# 304437                               achicar,pelada,
# 381349                                 achicar,pera,
# 66689                                      achorado,
# 333502                                     achorado,
# 264165                                     achorado,
# 183196                                     achorado,
# 14027                                      achorado,
# 464155                                     achorado,
# 96278                                      achorado,
# 61759                                      achorado,
# 298717                                     achorado,

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129486 entries, 461566 to 7864
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         129486 non-null  int64
#  1   object_id  129486 non-null  int64
#  2   message    129486 non-null  object
#  3   slangs     129486 non-null  string
# dtypes: int64(2), object(1), string(1)
# memory usage: 4.9+ MB

# %%
df_filter['slangs_char_count'] = df_filter['slangs'].apply(lambda x: len(str(x)))
# Out:
# /tmp/ipykernel_62186/1825552138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filter['slangs_char_count'] = df_filter['slangs'].apply(lambda x: len(str(x)))

# %%
df_filter_sorted = df_filter.sort_values(by='slangs_char_count', ascending=False)

# %%
df_filter_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129486 entries, 390281 to 90888
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 129486 non-null  int64
#  1   object_id          129486 non-null  int64
#  2   message            129486 non-null  object
#  3   slangs             129486 non-null  string
#  4   slangs_char_count  129486 non-null  int64
# dtypes: int64(3), object(1), string(1)
# memory usage: 5.9+ MB

# %%
df_filter_sorted.head(50)
# Out:
#             id         object_id  \
# 390281  197290   453461103460178
# 218105   51949  1176370339239559
# 126797   82832   339963449951792
# 247768  245634   378313334261535
# 9349     23679  1039379953278196
# 397200  105276   884238275099746
# 50939    12417  4285629551472004
# 195709  144758   162676042396745
# 20512   148480   471999724024284
# 439018   26176   271043234281059
# 91962     4034  3618771325066671
# 211228   49107   610774273843508
# 370518  114767  1658929734203347
# 152442    5220  1452386251524364
# 281808  104448   884238275099746
# 249528     186   719336195404165
# 74554      646  1027450215119148
# 103817   28905  1166476386782020
# 413432   15537   257367190342953
# 491107   78173  4478873492237045
# 15104    48090  3072622483067821
# 220663  135329  1355573898302925
# 275722   25242  1236419637036259
# 228958    2773   887183551752351
# 212062   85506   374594726424813
# 218105     lechero,arroz,caldo,camote,chancho,choclo,crudo,cuero,de fresa,guarda,mano,paradero,picado,taza,tira,toque,vara,vieja,culantro,palta,pollo,polvo,
# 126797                                     arroz,chau,chifa,chita,chup,chupe,cola,ensalada,palla,picar,sopa,tamal,turro,chicha,chapa,chaufa,yuca,yucas,yuca,
# 247768                                                 aparato,chacra,chup,cola,comba,huevo,negociado,pinta,reales,roto,socio,vale,zángano,causa,habla,mono,
# 9349                                                      batida,cargo,cole,comercial,loco,meretriz,micro,muni,orto,perú libre,rondero,serenazgo,profe,mono,
# 397200                                                      asado,capo,chancho,chau,huérfanos,lomo,lomo saltado,pisco sour,vale,pisco,chaufa,gallina,turrón,
# 50939                                                       carajo,chibola,chico,chicote,huevo,maldito,mocoso,punto,suave,tira,profe,chibolos,chibolo,pucha,
# 195709                                                       bestia,caer,carrera,creído,entripado,inge,jodido,tanta,toque,vale,vuelta,zafar,al toque,trampa,
# 20512                                                             caro,chino,ferro,mano,minero,pega,punto,profe,botar,causa,habla,cancha,china,tranqui,papa,
# 439018                                                              arroz,camarón,cebiche,chocho,ensalada,olluquito,picar,relleno,serrano,tamal,verde,pollo,
# 91962                                                                chacra,ciudad blanca,depa,punto,terruco,terrucos,vivo,zapallo,blanca,seco,tranqui,papa,
# 211228                                                                   belga,cola,colorado,comercial,maduro,punto,tanta,vale,bomba,causa,mesopotamia,nica,
# 370518                                                                     caldo,chancho,chup,chupe,huevo,huevos,no pasa nada,picar,san martín,gallina,papa,
# 152442                                                                     mondongo,caldo,chicharrón,chup,chupe,colorado,pacha,pachamanca,palo,verde,chicha,
# 281808                                                                      chela,anda,capo,chifa,chino,picar,pisco sour,san martín,pisco,combi,pepa,turrón,
# 249528                                                                      chanca,chancaca,chup,chupe,cola,hermano,mano,palo,pelar,punto,agarre,tela,rubia,
# 74554                                                                         pelado,pendejos,piraña,pirañas,rata,san martín,willa,chibolos,pendejo,chibolo,
# 103817                                                                             campana,marinera,pacha,pachamanca,pescar,picar,pinta,punta,pollo,tranqui,
# 413432                                                                              chico,hincha,muni,pega,vivo,causa,jama,cabro,cancha,trampa,tranqui,pata,
# 491107                                                                               misio,chela,al polo,chup,chupe,hincha,plancito,vale,causa,chapa,chongo,
# 15104                                                                                chancho,chicharrón,colorado,humita,inge,pacha,pachamanca,trucha,chicha,
# 220663                                                                               coimas,cola,conos,hermano,mano,muni,ómnibus,rata,vale,causa,coima,tono,
# 275722                                                                                bestia,cola,comba,descansar,inge,pelar,plaga,vale,profe,levantar,papa,
# 228958                                                                                  bica,cloro,dañar,guarda,inge,mano,nota,ojal,planta,tira,tirar,causa,
# 212062                                                                                    calientito,cebiche,chancho,choclo,heladita,mica,tamal,chicha,seco,
# 378069                                                                                     cola,mancha,mano,tira,vale,profe,cabro,cancha,coima,jugador,pata,
# 405553                                                                                     chilindrina,arroz,chau,chilin,marciano,tigre,chicha,chaufa,china,
# 213346                                                                                     carrera,en algo,nota,punto,solapa,vuelta,profe,habla,cancha,tela,
# 15126                                                                                      socio,chévere,chibolos,habla,cojudo,combi,minimizar,chibolo,pata,
# 448683                                                                                      mondongo,caldo,chup,chupe,patas,patasca,sopa,verde,gallina,pata,
# 378205                                                                                       carajo,chino,comba,la hizo linda,maldito,rata,vago,profe,causa,
# 62227                                                                                         bola,frío,guarda,lomo,macho,mano,pito,puta madre,velador,jama,
# 446671                                                                                        chela,chau,chico,lomo,lomo saltado,tigre,buenazo,chaufa,pollo,
# 76975                                                                                          babosa,babosada,piraña,viejo,cancha,conchudo,plata,atorrante,
# 52844                                                                                           tanta,terruco,tuco,willa,cana,cancha,plata,pata,como cancha,
# 74780                                                                                           chino,depa,descansar,maldito,mano,resaca,viejo,vivo,batería,
# 499091                                                                                          anticucho,lobo,parado,patero,sobon,solapa,tanta,ya pe,profe,
# 494815                                                                                           boga,chico,cola,joyita,pasar piola,piola,blanca,cana,combi,
# 470687                                                                                           nomas,canchita,chico,gaseosa,inge,macha,solapa,combo,combo,
# 10247                                                                                             chup,chupamedias,maldito,perra,perras,punto,rata,calabaza,
# 40492                                                                                             chola,cholo,comercial,negro,raza,verde,zambo,habla,pituco,
# 422398                                                                                            choclo,emoliente,huérfanos,san martín,turro,buenazo,combi,
# 431543                                                                                            bestia,chico,chicote,comba,culo,fierro,machete,palo,profe,
# 39482                                                                                             cagada,cagar,chanca,concha,pelado,quemar,vale,verga,polvo,
# 382995                                                                                             chicharrón,chico,ensalada,no pasa nada,chicha,pollo,papa,
# 371114                                                                                             carrera,comercial,hueco,marcar,perú libre,profe,cayetano,
# 109991                                                                                             cola,pinta,rondero,senderista,vuelta,china,levantar,mono,
# 186777                                                                                             clarito,maja,seco de chabelo,tamal,verde,poto,palta,seco,
# 3601                                                                                                nola,patas,patasca,seco de chabelo,sopa,tigre,seco,pata,
# 103258                                                                                              chela,hacer la chancha,punta,puntas,chancha,pichanguita,
#
#         slangs_char_count
# 390281                148
# 218105                145
# 126797                113
# 247768                101
# 9349                   98
# 397200                 96
# 50939                  96
# 195709                 95
# 20512                  90
# 439018                 88
# 91962                  87
# 211228                 83
# 370518                 81
# 152442                 81
# 281808                 80
# 249528                 80
# 74554                  78
# 103817                 73
# 413432                 72
# 491107                 71
# 15104                  71
# 220663                 71
# 275722                 70
# 228958                 68
# 212062                 66
# 378069                 65
# 405553                 65
# 213346                 65
# 15126                  65
# 448683                 64
# 378205                 63
# 62227                  62
# 446671                 62
# 76975                  61
# 52844                  60
# 74780                  60
# 499091                 60
# 494815                 59
# 470687                 59
# 10247                  58
# 40492                  58
# 422398                 58
# 431543                 58
# 39482                  58
# 382995                 57
# 371114                 57
# 109991                 57
# 186777                 57
# 3601                   56
# 103258                 56

# %%
df_filter_sorted.to_csv('raw-data/filtered/facebook-comments-chunk2.csv', index=False)

# %%
#https://queirozf.com/entries/pandas-for-large-data

# %%
#https://towardsdatascience.com/emojis-aid-social-media-sentiment-analysis-stop-cleaning-them-out-bb32a1e5fc8e
